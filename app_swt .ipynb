# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import pandas as pd

from jupyter_dash import JupyterDash

#Import cleaned Dataset

effl_data = pd.read_csv('effluent.csv')
infl_data = pd.read_csv('influent_data.csv')

# %%
effl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67466 entries, 0 to 67465
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           67466 non-null  int64
#  1   TreatmentPlant       67466 non-null  object
#  2   SampleDateTime       67466 non-null  object
#  3   SampleValue          67466 non-null  float64
#  4   NameDeterminandName  67466 non-null  object
#  5   UnitsName            67466 non-null  object
#  6   Latitude             67466 non-null  float64
#  7   Longitude            67466 non-null  float64
#  8   Year                 67466 non-null  int64
#  9   Month                67466 non-null  int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 5.1+ MB

# %%
effl_plot = effl_data.drop(['Year', 'Unnamed: 0', 'Month'], axis = 1)

effl_plot.head()
# Out:
#   TreatmentPlant SampleDateTime  SampleValue        NameDeterminandName  \
# 0   Nuneaton STW     2015-08-13         1.90                  metformin
# 1   Nuneaton STW     2015-08-13         2.92  Biochemical Oxygen Demand
# 2   Nuneaton STW     2015-08-13         4.00         aluminium reactive
# 3   Nuneaton STW     2015-08-13         3.99     total suspended solids
# 4   Nuneaton STW     2015-08-13         5.05           nickel dissolved
#
#                 UnitsName   Latitude  Longitude
# 0    micrograms per litre  52.559107  -1.508319
# 1  milligrammes per litre  52.559107  -1.508319
# 2    micrograms per litre  52.559107  -1.508319
# 3  milligrammes per litre  52.559107  -1.508319
# 4    micrograms per litre  52.559107  -1.508319

# %%
effl_plot['Month_year'] = effl_data['Month'].astype(str) + effl_data['Year'].astype(str)

# %%
effl_plot.head()
# Out:
#   TreatmentPlant SampleDateTime  SampleValue        NameDeterminandName  \
# 0   Nuneaton STW     2015-08-13         1.90                  metformin
# 1   Nuneaton STW     2015-08-13         2.92  Biochemical Oxygen Demand
# 2   Nuneaton STW     2015-08-13         4.00         aluminium reactive
# 3   Nuneaton STW     2015-08-13         3.99     total suspended solids
# 4   Nuneaton STW     2015-08-13         5.05           nickel dissolved
#
#                 UnitsName   Latitude  Longitude Month_year
# 0    micrograms per litre  52.559107  -1.508319      82015
# 1  milligrammes per litre  52.559107  -1.508319      82015
# 2    micrograms per litre  52.559107  -1.508319      82015
# 3  milligrammes per litre  52.559107  -1.508319      82015
# 4    micrograms per litre  52.559107  -1.508319      82015

# %%
effl_plot = effl_plot.sort_values(by = ['SampleDateTime'])

# %%
mark_key = list(effl_plot.Month_year.unique())

# %%
mark_values = list(range(1,36))

# %%
slider_marks = dict(zip(mark_key, mark_values))

# %%
effl_plot['SliderMarks'] = effl_plot['Month_year'].map(slider_marks)

# %%
effl_plot
# Out:
#           TreatmentPlant SampleDateTime  SampleValue  \
# 18652  Kidderminster STW     2015-01-06        9.590
# 9173       Ambergate STW     2015-01-06        0.010
# 9172       Ambergate STW     2015-01-06        0.010
# 9171       Ambergate STW     2015-01-06        0.010
# 9170       Ambergate STW     2015-01-06        0.010
# ...                  ...            ...          ...
# 51036      Rye Meads STW     2017-12-01        0.920
# 51035      Rye Meads STW     2017-12-01        1.390
# 51034      Rye Meads STW     2017-12-01        0.280
# 51032      Rye Meads STW     2017-12-01        0.398
# 51026      Rye Meads STW     2017-12-01        0.180
#
#              NameDeterminandName               UnitsName   Latitude  \
# 18652               copper total    micrograms per litre  52.362425
# 9173                        PFOS    micrograms per litre  53.060479
# 9172        trixylenyl phosphate    micrograms per litre  53.060479
# 9171                    sulphide  milligrammes per litre  53.060479
# 9170               mercury total    micrograms per litre  53.060479
# ...                          ...                     ...        ...
# 51036                 ranitidine    micrograms per litre  51.768679
# 51035                  metformin    micrograms per litre  51.768679
# 51034              ciprofloxacin    micrograms per litre  51.768679
# 51032               azithromycin    micrograms per litre  51.768679
# 51026  ortho hydroxyatorvastatin    micrograms per litre  51.768679
#
#        Longitude Month_year  SliderMarks
# 18652  -2.257971      12015            1
# 9173   -1.472193      12015            1
# 9172   -1.472193      12015            1
# 9171   -1.472193      12015            1
# 9170   -1.472193      12015            1
# ...          ...        ...          ...
# 51036   0.015915     122017           35
# 51035   0.015915     122017           35
# 51034   0.015915     122017           35
# 51032   0.015915     122017           35
# 51026   0.015915     122017           35
#
# [67466 rows x 9 columns]

# %%
#Groupby date(months, TreatmentPlants, NameDeterninandName, sample Value: mean and max

# %%
dt = {'1': "Jan", '2':'Feb', '3':'Mar', '4':'Apr', '5':'May', '6':'Jun', '7':'Jul', '8':'Aug', '9':'Sep', '10':'Oct', '11':'Nov', '12':'Dec'}

# %%
dt
# Out:
# {'1': 'Jan',
#  '2': 'Feb',
#  '3': 'Mar',
#  '4': 'Apr',
#  '5': 'May',
#  '6': 'Jun',
#  '7': 'Jul',
#  '8': 'Aug',
#  '9': 'Sep',
#  '10': 'Oct',
#  '11': 'Nov',
#  '12': 'Dec'}

# %%
effl_df = effl_data.sort_values(by = ['SampleDateTime'])

# %%
effl_df
# Out:
#        Unnamed: 0     TreatmentPlant SampleDateTime  SampleValue  \
# 18652      200006  Kidderminster STW     2015-01-06        9.590
# 9173       116339      Ambergate STW     2015-01-06        0.010
# 9172       116338      Ambergate STW     2015-01-06        0.010
# 9171       116337      Ambergate STW     2015-01-06        0.010
# 9170       116336      Ambergate STW     2015-01-06        0.010
# ...           ...                ...            ...          ...
# 51036      473806      Rye Meads STW     2017-12-01        0.920
# 51035      473805      Rye Meads STW     2017-12-01        1.390
# 51034      473804      Rye Meads STW     2017-12-01        0.280
# 51032      473802      Rye Meads STW     2017-12-01        0.398
# 51026      473796      Rye Meads STW     2017-12-01        0.180
#
#              NameDeterminandName               UnitsName   Latitude  \
# 18652               copper total    micrograms per litre  52.362425
# 9173                        PFOS    micrograms per litre  53.060479
# 9172        trixylenyl phosphate    micrograms per litre  53.060479
# 9171                    sulphide  milligrammes per litre  53.060479
# 9170               mercury total    micrograms per litre  53.060479
# ...                          ...                     ...        ...
# 51036                 ranitidine    micrograms per litre  51.768679
# 51035                  metformin    micrograms per litre  51.768679
# 51034              ciprofloxacin    micrograms per litre  51.768679
# 51032               azithromycin    micrograms per litre  51.768679
# 51026  ortho hydroxyatorvastatin    micrograms per litre  51.768679
#
#        Longitude  Year  Month
# 18652  -2.257971  2015      1
# 9173   -1.472193  2015      1
# 9172   -1.472193  2015      1
# 9171   -1.472193  2015      1
# 9170   -1.472193  2015      1
# ...          ...   ...    ...
# 51036   0.015915  2017     12
# 51035   0.015915  2017     12
# 51034   0.015915  2017     12
# 51032   0.015915  2017     12
# 51026   0.015915  2017     12
#
# [67466 rows x 10 columns]

# %%
 effl_plot['Month'] = effl_df['Month'].astype('str')

# %%
effl_plot['Year']=effl_df['Year'].astype('str')

# %%
effl_plot['Month'] = effl_plot['Month'].map(dt)

# %%
effl_plot
# Out:
#           TreatmentPlant SampleDateTime  SampleValue  \
# 18652  Kidderminster STW     2015-01-06        9.590
# 9173       Ambergate STW     2015-01-06        0.010
# 9172       Ambergate STW     2015-01-06        0.010
# 9171       Ambergate STW     2015-01-06        0.010
# 9170       Ambergate STW     2015-01-06        0.010
# ...                  ...            ...          ...
# 51036      Rye Meads STW     2017-12-01        0.920
# 51035      Rye Meads STW     2017-12-01        1.390
# 51034      Rye Meads STW     2017-12-01        0.280
# 51032      Rye Meads STW     2017-12-01        0.398
# 51026      Rye Meads STW     2017-12-01        0.180
#
#              NameDeterminandName               UnitsName   Latitude  \
# 18652               copper total    micrograms per litre  52.362425
# 9173                        PFOS    micrograms per litre  53.060479
# 9172        trixylenyl phosphate    micrograms per litre  53.060479
# 9171                    sulphide  milligrammes per litre  53.060479
# 9170               mercury total    micrograms per litre  53.060479
# ...                          ...                     ...        ...
# 51036                 ranitidine    micrograms per litre  51.768679
# 51035                  metformin    micrograms per litre  51.768679
# 51034              ciprofloxacin    micrograms per litre  51.768679
# 51032               azithromycin    micrograms per litre  51.768679
# 51026  ortho hydroxyatorvastatin    micrograms per litre  51.768679
#
#        Longitude Month_year  SliderMarks Month  Year
# 18652  -2.257971      12015            1   Jan  2015
# 9173   -1.472193      12015            1   Jan  2015
# 9172   -1.472193      12015            1   Jan  2015
# 9171   -1.472193      12015            1   Jan  2015
# 9170   -1.472193      12015            1   Jan  2015
# ...          ...        ...          ...   ...   ...
# 51036   0.015915     122017           35   Dec  2017
# 51035   0.015915     122017           35   Dec  2017
# 51034   0.015915     122017           35   Dec  2017
# 51032   0.015915     122017           35   Dec  2017
# 51026   0.015915     122017           35   Dec  2017
#
# [67466 rows x 11 columns]

# %%
effl_plot['Month_year'] = effl_plot['Month']+ " " + effl_plot['Year']

# %%
effl_plot
# Out:
#           TreatmentPlant SampleDateTime  SampleValue  \
# 18652  Kidderminster STW     2015-01-06        9.590
# 9173       Ambergate STW     2015-01-06        0.010
# 9172       Ambergate STW     2015-01-06        0.010
# 9171       Ambergate STW     2015-01-06        0.010
# 9170       Ambergate STW     2015-01-06        0.010
# ...                  ...            ...          ...
# 51036      Rye Meads STW     2017-12-01        0.920
# 51035      Rye Meads STW     2017-12-01        1.390
# 51034      Rye Meads STW     2017-12-01        0.280
# 51032      Rye Meads STW     2017-12-01        0.398
# 51026      Rye Meads STW     2017-12-01        0.180
#
#              NameDeterminandName               UnitsName   Latitude  \
# 18652               copper total    micrograms per litre  52.362425
# 9173                        PFOS    micrograms per litre  53.060479
# 9172        trixylenyl phosphate    micrograms per litre  53.060479
# 9171                    sulphide  milligrammes per litre  53.060479
# 9170               mercury total    micrograms per litre  53.060479
# ...                          ...                     ...        ...
# 51036                 ranitidine    micrograms per litre  51.768679
# 51035                  metformin    micrograms per litre  51.768679
# 51034              ciprofloxacin    micrograms per litre  51.768679
# 51032               azithromycin    micrograms per litre  51.768679
# 51026  ortho hydroxyatorvastatin    micrograms per litre  51.768679
#
#        Longitude Month_year  SliderMarks Month  Year
# 18652  -2.257971   Jan 2015            1   Jan  2015
# 9173   -1.472193   Jan 2015            1   Jan  2015
# 9172   -1.472193   Jan 2015            1   Jan  2015
# 9171   -1.472193   Jan 2015            1   Jan  2015
# 9170   -1.472193   Jan 2015            1   Jan  2015
# ...          ...        ...          ...   ...   ...
# 51036   0.015915   Dec 2017           35   Dec  2017
# 51035   0.015915   Dec 2017           35   Dec  2017
# 51034   0.015915   Dec 2017           35   Dec  2017
# 51032   0.015915   Dec 2017           35   Dec  2017
# 51026   0.015915   Dec 2017           35   Dec  2017
#
# [67466 rows x 11 columns]

# %%
x = effl_plot.SliderMarks.unique()

y = effl_plot.Month_year.unique()

# %%
marks = dict(zip(x, y))

# %%
keys = list(range(1, 36, 3))
keys
# Out:
# [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34]

# %%
marking = {k: marks[k] for k in keys}

# %%
marking
# Out:
# {1: 'Jan 2015',
#  4: 'Apr 2015',
#  7: 'Jul 2015',
#  10: 'Oct 2015',
#  13: 'Jan 2016',
#  16: 'Apr 2016',
#  19: 'Jul 2016',
#  22: 'Oct 2016',
#  25: 'Jan 2017',
#  28: 'Apr 2017',
#  31: 'Jul 2017',
#  34: 'Oct 2017'}

# %%
effl_plot = effl_plot.drop(['Year', 'Month'], axis = 1)

# %%
effl_plot['NameDeterminandName']=effl_plot['NameDeterminandName'].str.upper()

# %%
effl_plot
# Out:
#           TreatmentPlant SampleDateTime  SampleValue  \
# 18652  Kidderminster STW     2015-01-06        9.590
# 9173       Ambergate STW     2015-01-06        0.010
# 9172       Ambergate STW     2015-01-06        0.010
# 9171       Ambergate STW     2015-01-06        0.010
# 9170       Ambergate STW     2015-01-06        0.010
# ...                  ...            ...          ...
# 51036      Rye Meads STW     2017-12-01        0.920
# 51035      Rye Meads STW     2017-12-01        1.390
# 51034      Rye Meads STW     2017-12-01        0.280
# 51032      Rye Meads STW     2017-12-01        0.398
# 51026      Rye Meads STW     2017-12-01        0.180
#
#              NameDeterminandName               UnitsName   Latitude  \
# 18652               COPPER TOTAL    micrograms per litre  52.362425
# 9173                        PFOS    micrograms per litre  53.060479
# 9172        TRIXYLENYL PHOSPHATE    micrograms per litre  53.060479
# 9171                    SULPHIDE  milligrammes per litre  53.060479
# 9170               MERCURY TOTAL    micrograms per litre  53.060479
# ...                          ...                     ...        ...
# 51036                 RANITIDINE    micrograms per litre  51.768679
# 51035                  METFORMIN    micrograms per litre  51.768679
# 51034              CIPROFLOXACIN    micrograms per litre  51.768679
# 51032               AZITHROMYCIN    micrograms per litre  51.768679
# 51026  ORTHO HYDROXYATORVASTATIN    micrograms per litre  51.768679
#
#        Longitude Month_year  SliderMarks
# 18652  -2.257971   Jan 2015            1
# 9173   -1.472193   Jan 2015            1
# 9172   -1.472193   Jan 2015            1
# 9171   -1.472193   Jan 2015            1
# 9170   -1.472193   Jan 2015            1
# ...          ...        ...          ...
# 51036   0.015915   Dec 2017           35
# 51035   0.015915   Dec 2017           35
# 51034   0.015915   Dec 2017           35
# 51032   0.015915   Dec 2017           35
# 51026   0.015915   Dec 2017           35
#
# [67466 rows x 9 columns]

# %%
effl_plot.to_csv('effluent_df.csv')

# %%
#Build app

#app = dash.Dash(__name__, meta_tags=[{"name": "viewport", "content": "width=device-width"}])
app = JupyterDash(__name__, meta_tags=[{"name": "viewport", "content": "width=device-width"}])


app.layout = html.Div([
    html.Div([
        html.Div([
            html.H3()
        ], 
            className="one-third column"),
        
        html.Div([
            html.H3("UK Sewage Treatment Quality", style={"margin-bottom": "0px", 'color': 'white'}),
            html.H6("Interactive Web Visualisation App", style={"margin-top": "0px", 'color': '#ff8a8a'})
        ], 
            className="one-half column", id="title"),
        
        html.Div([
            html.H3()
        ], 
            className="one-third column")       
      
    ], id="header", className="row flex-display", style={"margin-bottom": "25px"}),
    
    html.Div([
        html.Div([
            html.P('Select Parameter:', className='fix_label', style={'color': 'white'}),
            
            dcc.Dropdown(id='parameters',
                                  multi=False,
                                  clearable=True,
                                  value='Biochemical Oxygen Demand',
                                  placeholder='Select...',
                                  options=[{'label': c, 'value': c}
                                           for c in (effl_data['NameDeterminandName'].unique())], className='dcc_compon'),
        
        ], className="create_container five columns", id="cross-filter-options"),
        
        html.Div([
            html.P('Select Treatment Plants (5 max):', className='fix_label', style={'color': 'white'}),
            
            dcc.Dropdown(id='swt',
                                  multi=True,
                                  clearable=True,
                                  value='Nuneaton STW',
                                  placeholder='Select...',
                                  options=[{'label': c, 'value': c}
                                           for c in (effl_data['TreatmentPlant'].unique())], className='dcc_compon'),
        
        ], className="create_container six columns", id="cross-filter-options1")
    ])

])

app.run_server(mode='jupyterlab', port = 8050)

# %%
#app._terminate_server_for_port("localhost", 8050)

# %%
fig_dims = (10,16)

fig, ax = plt.subplots(figsize = fig_dims)
sn.scatterplot(data = effl, x ='Longitude', y = 'Latitude', ax = ax)
# Out:
# <AxesSubplot:xlabel='uwwLongitude', ylabel='uwwLatitude'>

# %%
#clean string in column and change it to uppercase
location['uwwName'] = location['uwwName'].str.upper().str.replace("WWTP", "").str.replace("STW", "").str.replace("WWTW", "").str.replace("\xA0", "").str.replace("WWTP", "").str.replace(" ", "")
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#location['uwwName'] = location['uwwName'].str.replace("WWTP", "")
#location['uwwName'] = location['uwwName'].str.replace("STW", "")
#location['uwwName'] = location['uwwName'].str.replace("\xa0", "")
#location['uwwName'] = location['uwwName'].str.title()

# %%
#Check and Remove null calues
location.isnull().sum().sum()
# Out:
# 3

# %%
location = location.dropna()

# %%
#location.to_csv('map_tp.csv')

# %%
location = location.sort_values('uwwName')

# %%
list(location.uwwLatitude)
# Out:
# [51.8258406,
#  56.62291,
#  51.85116013,
#  52.40106044,
#  51.65255524,
#  51.65255524,
#  57.07269,
#  53.64540284,
#  52.63276755,
#  52.04221213,
#  53.56555812,
#  53.59205912,
#  53.73729427,
#  56.07334,
#  52.63996186,
#  52.20800996,
#  52.36469307,
#  53.30389347,
#  51.24685784,
#  51.26661959,
#  57.23882,
#  53.26033041,
#  53.10761666,
#  57.49957,
#  55.78012,
#  56.106669999999994,
#  51.56202428,
#  57.69106,
#  55.41231292,
#  51.07269825,
#  52.73369321,
#  53.10428191,
#  53.59145825,
#  52.98088308,
#  51.15283331,
#  53.41018471,
#  56.148630000000004,
#  52.34346603,
#  52.46313692,
#  51.58402072,
#  56.621190000000006,
#  53.06039514,
#  55.32323485,
#  54.42782771,
#  51.16823177,
#  51.77075588,
#  51.70561723,
#  51.17308929,
#  55.2195,
#  54.97396,
#  54.2615,
#  54.731,
#  53.03570466,
#  52.25670871,
#  54.58315854,
#  51.69526458,
#  51.40045217,
#  55.946740000000005,
#  52.50351384,
#  55.907819999999994,
#  54.365,
#  52.74516172,
#  53.53215812,
#  51.40612204,
#  52.75997092,
#  53.01250991,
#  51.9350711,
#  51.15338513,
#  50.92841519,
#  52.13373944,
#  53.47095541,
#  51.2773761,
#  54.19349548,
#  52.95768604,
#  54.75477034,
#  52.5798912,
#  52.51611166,
#  56.300219999999996,
#  53.0626072,
#  57.209740000000004,
#  57.553000000000004,
#  50.77259144,
#  51.82670409,
#  52.79308175,
#  52.98075045,
#  52.29143548,
#  53.1861385,
#  52.90876589,
#  53.50389424,
#  53.04921486,
#  56.06576999999999,
#  57.056630000000006,
#  55.202,
#  54.742,
#  54.501999999999995,
#  55.049,
#  54.84,
#  55.049,
#  54.472,
#  54.396,
#  54.56,
#  52.39796006,
#  52.13582396,
#  51.72300647,
#  54.357,
#  52.05886478,
#  57.05328000000001,
#  57.6724,
#  50.93422068,
#  52.2688558,
#  53.81358859,
#  52.64171624,
#  54.53834851,
#  53.92808299,
#  53.57566678,
#  53.55827648,
#  51.08928707,
#  52.75843426,
#  54.10682269,
#  52.42018034,
#  53.81549208,
#  52.761401899999996,
#  53.69674952,
#  51.98118735,
#  51.17552688,
#  53.8304077,
#  52.77357704,
#  51.58793954,
#  51.2918907,
#  53.24272228,
#  52.08977827,
#  53.12879029,
#  51.41217105,
#  55.9159,
#  50.91859267,
#  54.78283391,
#  52.45681939,
#  54.28520338,
#  52.13165329,
#  52.48589839,
#  52.92310433,
#  52.71440753,
#  52.38547368,
#  54.622,
#  53.01659467,
#  51.54916766,
#  52.19226624,
#  53.92164179,
#  51.60966644,
#  51.18524736,
#  50.47652323,
#  51.75084533,
#  55.76539997,
#  53.18536725,
#  53.83819377,
#  51.88655459,
#  51.15961194,
#  51.11820581,
#  53.12679282,
#  51.02653534,
#  52.15506766,
#  55.61591,
#  52.10620289,
#  51.61979469,
#  53.48573655,
#  54.62445112,
#  53.08398111,
#  51.01184142,
#  53.821192700000005,
#  53.14707191,
#  53.83992192,
#  53.39796474,
#  52.52882775,
#  52.54115828,
#  52.5200584,
#  54.90427479,
#  54.67887463,
#  52.48342902,
#  51.05262137,
#  51.85396659,
#  50.94236381,
#  53.759545200000005,
#  55.87161,
#  56.26296,
#  50.7396798,
#  52.10015843,
#  55.890280000000004,
#  55.667530000000006,
#  56.76257,
#  56.58546,
#  51.75220264,
#  50.82612669,
#  52.02501036,
#  52.0180029,
#  51.78852315,
#  55.13366599,
#  56.01461,
#  51.89052632,
#  50.47185807,
#  50.47404998,
#  53.22620548,
#  53.53833716,
#  53.51341046,
#  56.0085,
#  51.11947952,
#  54.09643934,
#  52.48798462,
#  50.81535143,
#  52.94919352,
#  55.798019999999994,
#  52.94873411,
#  52.2281806,
#  53.20115863,
#  52.20252084,
#  52.76608465,
#  50.75491231,
#  50.76740734,
#  51.87855329,
#  54.72709584,
#  53.36667668,
#  51.35924429,
#  56.27019,
#  51.41938865,
#  52.22449426,
#  52.02007194,
#  51.43887346,
#  53.844658700000004,
#  51.34203165,
#  50.82173159,
#  53.33668215,
#  51.86909466,
#  52.49645925,
#  52.31489429,
#  54.94105199,
#  52.79798039,
#  53.90497502,
#  52.44570889,
#  51.95939001,
#  53.49875779,
#  54.43164814,
#  56.722269999999995,
#  51.93965973,
#  52.02586438,
#  51.47774046,
#  52.51659782,
#  51.14097231,
#  54.07018331,
#  50.71351981,
#  53.55667845,
#  51.82064101,
#  51.51060443,
#  52.84086501,
#  52.33726311,
#  51.39100981,
#  52.03828423,
#  51.9427099,
#  50.82370988,
#  51.93186355,
#  53.35942512,
#  52.31316242,
#  52.18757821,
#  54.95264797,
#  52.3800141,
#  53.58135741,
#  52.54808188,
#  51.10418755,
#  51.80543179,
#  52.28839667,
#  50.479733700000004,
#  52.00126943,
#  53.15270559,
#  50.81350977,
#  52.21703529999999,
#  52.1528477,
#  52.4747709,
#  52.45031474,
#  51.93938542,
#  51.80849217,
#  50.97014712,
#  51.41233855,
#  53.90957083,
#  51.21580871,
#  52.94673803,
#  51.62452762,
#  53.81208829,
#  52.66858341,
#  53.61299525,
#  50.87580406,
#  51.17855991,
#  52.7764424,
#  52.82646314,
#  53.64831373,
#  52.29340567,
#  53.56652534,
#  52.27746346,
#  55.211000000000006,
#  51.10020544,
#  53.24937535,
#  52.16918445,
#  52.72419761,
#  51.83998287,
#  53.13238848,
#  53.49452878,
#  56.2374,
#  50.496177,
#  51.44168778,
#  50.49605928,
#  53.03431253,
#  51.32814636,
#  55.15673582,
#  50.23008896,
#  52.23428479,
#  50.6191468,
#  51.32814324,
#  51.1480969,
#  52.67555481,
#  51.29526239,
#  51.51154114,
#  55.762809999999995,
#  51.47718054,
#  51.41943607,
#  52.08373402,
#  53.668531200000004,
#  54.89976687,
#  54.59380668,
#  51.8366599,
#  54.12992516,
#  50.21762196,
#  54.725,
#  55.687940000000005,
#  51.74175797,
#  51.80583074,
#  51.08467828,
#  54.707,
#  52.85348775,
#  54.939530000000005,
#  53.58267944,
#  54.07932387,
#  55.50405,
#  54.37625354,
#  52.96762305,
#  51.68422833,
#  51.93080532,
#  52.02942006,
#  53.33507585,
#  50.90350231,
#  51.63843452,
#  51.20141629999999,
#  51.87027292,
#  50.74005907,
#  51.25889506,
#  51.38597095,
#  52.46409278,
#  52.93390920000001,
#  51.26953368,
#  53.05904547,
#  53.50592314,
#  52.19512853,
#  51.73229243,
#  51.92217731,
#  53.85710021,
#  51.40223506,
#  51.68589069,
#  53.19302077,
#  54.85931421,
#  53.26740808,
#  51.35508918,
#  50.82866943,
#  51.12141078,
#  50.72630681,
#  51.46214745,
#  54.65347246,
#  51.72330437,
#  51.44127109,
#  52.05096119,
#  51.93895802,
#  51.34096425,
#  51.58058046,
#  53.65385697,
#  50.74151875,
#  50.60272458,
#  51.81351275,
#  52.51230189,
#  51.8237657,
#  51.67123234,
#  51.8098175,
#  52.07797131,
#  54.911,
#  53.15508846,
#  53.60297289999999,
#  54.50438984,
#  53.50777475,
#  52.38182231,
#  51.40934729,
#  52.94010103,
#  52.04810055,
#  53.85901297,
#  52.02509281,
#  53.27410296,
#  51.71773032,
#  54.531000000000006,
#  54.66732003,
#  52.63129553,
#  51.85909598,
#  54.37624451,
#  51.8744294,
#  53.6261009,
#  55.6641,
#  51.77826141,
#  51.23916008,
#  51.43466949,
#  53.15612025,
#  53.85130743,
#  52.08437054,
#  53.27837429,
#  50.73331833,
#  51.5074103,
#  50.48078881,
#  51.43161909,
#  56.37076999999999,
#  52.36699997,
#  53.16825864,
#  53.0950976,
#  53.21655208,
#  57.57271,
#  54.88903082,
#  54.632,
#  51.87664455,
#  52.49193311,
#  50.64713075,
#  50.79048661,
#  56.84215,
#  52.98207316,
#  52.91476656,
#  52.75685672,
#  52.71914768,
#  52.56113766,
#  56.54741,
#  55.79773,
#  52.36034278,
#  52.75443929,
#  51.45379371,
#  56.087680000000006,
#  51.24425193,
#  55.44791,
#  55.11090211,
#  51.09634129,
#  51.14443775,
#  53.03914246,
#  52.42411324,
#  54.75899999999999,
#  50.79277274,
#  51.51804619,
#  53.2630002,
#  53.11013452,
#  50.88272924,
#  51.64471003,
#  56.359359999999995,
#  53.66157057,
#  52.92965253,
#  53.15373161,
#  54.84915964,
#  52.10244265,
#  52.91720089,
#  51.79130774,
#  54.071999999999996,
#  53.66183145,
#  51.07807026,
#  52.66568479,
#  53.60429632,
#  51.72194043,
#  51.88994698,
#  50.99961333,
#  53.24952992,
#  53.563130799999996,
#  51.65572141,
#  50.84790823,
#  55.052,
#  56.32225,
#  51.73674248,
#  51.62809699,
#  54.92162,
#  56.02001,
#  55.83379,
#  55.834990000000005,
#  55.315780000000004,
#  55.908280000000005,
#  55.08829,
#  55.0884,
#  54.85147479,
#  53.16143935,
#  53.52829847,
#  54.03231946,
#  54.49828568,
#  50.3563266,
#  53.713297100000005,
#  52.27775744,
#  50.59288916,
#  54.71722805,
#  52.21864835,
#  51.96223049,
#  53.02715432,
#  52.66131415,
#  50.6173245,
#  53.49091749,
#  53.18700769,
#  53.80170645,
#  56.02457,
#  52.90641789,
#  52.68408352,
#  51.35105598,
#  53.67556104,
#  51.61922435,
#  57.59349,
#  53.36791668,
#  54.88411362,
#  52.37056057,
#  51.3039137,
#  51.66612422,
#  52.50703899,
#  52.74697781,
#  56.16065,
#  54.5306,
#  53.54476942,
#  53.54702486,
#  52.89749185,
#  52.72550166,
#  55.0385,
#  50.71097727,
#  51.63823265,
#  51.24155529,
#  57.86764,
#  55.55976,
#  51.11339544,
#  52.61192951,
#  54.333999999999996,
#  50.98320435,
#  54.799,
#  51.63662987,
#  52.0321732,
#  53.99792291,
#  52.25294853,
#  54.415,
#  54.531000000000006,
#  53.29598823,
#  55.43646,
#  51.47456823,
#  54.3676,
#  57.33205,
#  52.96862648,
#  53.467273600000006,
#  55.99201,
#  56.1824,
#  52.32544943,
#  56.01984,
#  54.931999999999995,
#  53.38400165,
#  53.30435192,
#  54.543,
#  55.97249,
#  55.92864,
#  55.77168,
#  51.90577568,
#  54.78383048,
#  54.80095644,
#  54.74171276,
#  54.75601159,
#  52.79138301,
#  53.30575165,
#  55.7516,
#  53.922126600000006,
#  51.93091047,
#  52.57172532,
#  54.10901322,
#  51.96507935,
#  50.78451336,
#  52.98351638,
#  55.89832,
#  51.3911703,
#  50.91268134,
#  51.39036548,
#  52.45477587,
#  50.85699169,
#  52.8320902,
#  50.95890954,
#  53.24483117,
#  51.21654524,
#  54.9744,
#  51.25060134,
#  51.46501384,
#  53.47241401,
#  52.86399993,
#  51.202231700000006,
#  51.141168,
#  52.77390232,
#  55.97062,
#  53.19571621,
#  53.71133629,
#  51.90675888,
#  52.04566016,
#  54.16954796,
#  53.75130509,
#  53.26280012,
#  52.90140395,
#  57.364619999999995,
#  52.22798669,
#  53.52749241,
#  51.19066681,
#  52.39764791,
#  52.38389777,
#  52.66624932,
#  53.08436002,
#  54.358000000000004,
#  51.6826623,
#  53.550283400000005,
#  50.42015747,
#  55.89218,
#  51.38172141,
#  54.77459613,
#  52.87780761,
#  57.66078,
#  51.14124651,
#  52.10036738,
#  50.69173254,
#  50.61509925,
#  52.32639358,
#  53.49399864,
#  51.70186763,
#  52.82282219,
#  56.10885,
#  50.14985556,
#  50.82593493,
#  51.66614875,
#  53.05596263,
#  51.22543861,
#  53.09863446,
#  56.06182,
#  55.824040000000004,
#  51.32246585,
#  50.82497258,
#  51.15390775,
#  51.95089411,
#  51.85866331,
#  55.30004619,
#  52.48825783,
#  50.78435516,
#  50.80586802,
#  54.66728362,
#  51.87151887,
#  54.21544835,
#  52.86835553,
#  51.84859905,
#  54.67913118,
#  52.97940266,
#  54.375,
#  54.10720036,
#  52.54539277,
#  51.30106552,
#  53.91032298,
#  53.24404673,
#  52.01751967,
#  50.72562034,
#  57.62433000000001,
#  54.20997292,
#  52.72453242,
#  50.91863459,
#  51.10039643,
#  56.64134,
#  53.54502158,
#  52.49359207,
#  57.61541,
#  55.761540000000004,
#  56.82839,
#  50.34653377,
#  52.12358811,
#  52.21083367,
#  51.77572,
#  52.94015311,
#  52.32118808,
#  57.69087,
#  53.06853074,
#  53.01985044,
#  51.23659209,
#  53.22796404,
#  53.37753166,
#  55.606609999999996,
#  52.14273874,
#  53.87832257,
#  54.992,
#  51.578246899999996,
#  53.72654923,
#  54.373999999999995,
#  51.03104932,
#  55.261019999999995,
#  51.14065058,
#  53.45903884,
#  52.10963759,
#  54.5895,
#  56.279819999999994,
#  53.44750765,
#  51.8433571,
#  51.201886,
#  51.23698012,
#  53.71851935,
#  55.840090000000004,
#  51.54180582,
#  52.87367538,
#  52.54692005,
#  51.65436973,
#  54.16773478,
#  52.97363592,
#  57.32244,
#  54.06241377,
#  51.44346303,
#  54.48017069,
#  52.07399823,
#  52.01415048,
#  51.86674083,
#  51.89984527,
#  52.18110505,
#  52.57044425,
#  50.95161568,
#  51.77202484,
#  52.06416901,
#  53.29902865,
#  52.00116928,
#  51.10281728,
#  52.63945131,
#  53.29306913,
#  52.59441161,
#  53.09414773,
#  54.988240000000005,
#  53.58057889,
#  53.5800443,
#  51.04679815,
#  52.75995479,
#  52.15456181,
#  56.3674,
#  51.25476434,
#  50.51671674,
#  52.34801251,
#  51.76152536,
#  55.960440000000006,
#  52.03504561,
#  51.21717192,
#  55.68497012,
#  50.87434834,
#  50.85253373,
#  52.33663855,
#  53.6978777,
#  51.935388200000006,
#  54.96729746,
#  53.77603861,
#  51.32531912,
#  55.79439,
#  52.11847762,
#  52.86870797,
#  52.40872221,
#  53.51550045,
#  51.81918213,
#  54.01892289,
#  53.96741074,
#  55.86469,
#  54.64130404,
#  51.31597292,
#  52.1346881,
#  51.93744555,
#  53.42163396,
#  51.08510283,
#  52.1607729,
#  51.80391626,
#  53.32199048,
#  52.21797807,
#  51.79293298,
#  52.07649643,
#  55.43156,
#  51.053365,
#  53.47846036,
#  53.38111226,
#  52.08189784,
#  53.40174568,
#  52.89837638,
#  51.16967794,
#  53.04972002,
#  53.01163748,
#  50.57444379,
#  50.93073054,
#  52.99360395,
#  53.7165877,
#  55.98347,
#  53.26645353,
#  50.09620259,
#  53.762508200000006,
#  52.502955299999996,
#  54.89813905,
#  50.94048161,
#  51.55067702,
#  51.36205357,
#  51.76925899,
#  53.70940369,
#  53.32769326,
#  54.97275634,
#  51.92495321,
#  53.530450699999996,
#  54.11598822,
#  52.44138024,
#  53.71177801,
#  51.64176578,
#  51.62181177,
#  53.54293057,
#  54.1985,
#  52.52925997,
#  54.55465315,
#  51.95941975,
#  52.81840623,
#  53.55555456,
#  53.3718831,
#  52.81314044,
#  54.20105736,
#  53.82795098,
#  53.20480261,
#  53.60041466,
#  51.19097426,
#  50.80429697,
#  52.90623542,
#  53.50849239,
#  53.29866016,
#  52.08678659,
#  50.80185648,
#  51.99873244,
#  53.1151292,
#  52.89763935,
#  53.65261109,
#  54.77666298,
#  51.17842517,
#  53.18997224,
#  53.88080663,
#  50.51441133,
#  51.05508648,
#  51.137453,
#  53.59394754,
#  54.85098719,
#  53.73336008,
#  53.40360569,
#  53.68245824,
#  53.74502678,
#  51.41173127,
#  54.18477133,
#  52.32269918,
#  57.45101,
#  51.10309042,
#  52.56655675,
#  51.54522561,
#  53.11876117,
#  53.39349386,
#  53.45029206,
#  53.7960694,
#  51.06468141,
#  52.67796396,
#  51.00120531,
#  51.20876198,
#  52.95090331,
#  53.93149469,
#  50.94300867,
#  53.61790818,
#  51.66652506,
#  54.14845096,
#  52.864484,
#  53.18419919,
#  57.340309999999995,
#  55.93605,
#  57.27328000000001,
#  57.27328000000001,
#  50.48926471,
#  52.03345693,
#  53.42413281,
#  56.04226,
#  54.47,
#  52.35147634,
#  52.40599278,
#  51.51559825,
#  51.84108397,
#  50.38478052,
#  51.25592371,
#  51.78614561,
#  55.495090000000005,
#  54.253,
#  52.08594346,
#  53.57125131,
#  51.33131926,
#  52.84592492,
#  53.86722302,
#  57.55365,
#  54.71608422,
#  55.60429,
#  57.24508,
#  52.1317038,
#  54.31041692,
#  50.63630246,
#  54.523,
#  52.41032609,
#  54.61372333,
#  52.62745924,
#  53.70750086,
#  51.41686425,
#  52.86661712,
#  52.53521619,
#  52.36153357,
#  53.09382625,
#  51.73255046,
#  53.00058388,
#  54.063,
#  56.02946,
#  54.473,
#  54.02683684,
#  54.4,
#  54.957,
#  52.33691457,
#  52.27675475,
#  51.85276881,
#  56.06469,
#  52.15381539,
#  50.26806954,
#  51.34517183,
#  53.26591018,
#  52.77514958,
#  51.05880047,
#  52.01758097,
#  51.67394769,
#  52.20705554,
#  57.07931,
#  54.63399999999999,
#  56.0117,
#  52.87036758,
#  56.211569999999995,
#  51.40157105,
#  52.43757741,
#  53.0891313,
#  54.19523408,
#  54.16196642,
#  54.26195308,
#  54.48757196,
#  56.11809,
#  55.38186999999999,
#  59.00731,
#  56.659769999999995,
#  53.4744105,
#  54.0050429,
#  52.34408876,
#  54.82849106,
#  53.3156171,
#  53.21619444,
#  53.54581836,
#  50.28493256,
#  55.863890000000005,
#  52.42701025,
#  52.10848492,
#  55.674009999999996,
#  54.02152757,
#  54.81486655,
#  51.73302901,
#  55.14572,
#  52.56746517,
#  51.03946558,
#  53.22651792,
#  50.22299491,
#  55.82088,
#  54.848,
#  51.68099498,
#  50.64043505,
#  56.839180000000006,
#  50.86435138,
#  52.10237899,
#  51.2948669,
#  53.11870393,
#  53.10526572,
#  51.31047535,
#  51.696790299999996,
#  52.03078479,
#  51.25243564,
#  53.77159342,
#  53.74747031,
#  53.08295574,
#  54.30609514,
#  52.70103424,
#  53.48660365,
#  51.92735414,
#  52.21187749,
#  51.22464592,
#  52.21849028,
#  55.64655,
#  51.99691122,
#  56.62935,
#  53.88334533,
#  56.19198000000001,
#  54.29841766,
#  53.68209379,
#  52.7135321,
#  50.82146353,
#  51.35113929,
#  ...]

# %%
#clean string in column and change it to uppercase
swt_data['TreatmentPlant'] = swt_data['TreatmentPlant'].str.upper().str.replace("STW", "").str.replace("-", "").str.replace(" ", "")

# %%
swt_data.sort_values('TreatmentPlant')
# Out:
#        SampleDateTime TreatmentPlant SampleDateTime.1  SampleLocationName  \
# 213548     2016-05-12       ABINGDON       2016-05-12  Treatment Effluent
# 213515     2016-05-12       ABINGDON       2016-05-12  Treatment Effluent
# 213516     2016-05-12       ABINGDON       2016-05-12  Treatment Effluent
# 213517     2016-05-12       ABINGDON       2016-05-12  Treatment Effluent
# 213518     2016-05-12       ABINGDON       2016-05-12  Treatment Effluent
# ...               ...            ...              ...                 ...
# 541626     2018-08-05   YADDLETHORPE       2018-08-05  Treatment Effluent
# 541625     2018-08-05   YADDLETHORPE       2018-08-05  Treatment Effluent
# 541624     2018-11-14   YADDLETHORPE       2018-11-14  Treatment Effluent
# 541630     2018-08-05   YADDLETHORPE       2018-08-05  Treatment Effluent
# 456155     2018-06-28   YADDLETHORPE       2018-06-28  Treatment Effluent
#
#         SampleValue           NameDeterminandName               UnitsName  \
# 213548       0.0005                         BDE28    micrograms per litre
# 213515      26.0000  total oxidised nitrogen as N  milligrammes per litre
# 213516       9.0000     Biochemical Oxygen Demand  milligrammes per litre
# 213517      12.0000        Chemical Oxygen Demand  milligrammes per litre
# 213518       1.0000         total phosphorus as P  milligrammes per litre
# ...             ...                           ...                     ...
# 541626      42.5000                iron dissolved    micrograms per litre
# 541625       0.0010             mercury dissolved    micrograms per litre
# 541624       0.0005                        BDE 99    micrograms per litre
# 541630      15.2000            aluminium reactive    micrograms per litre
# 456155     155.0000                       calcium  milligrammes per litre
#
#        BelowMinReading  Year  Month
# 213548             Yes  2016      5
# 213515              No  2016      5
# 213516              No  2016      5
# 213517              No  2016      5
# 213518              No  2016      5
# ...                ...   ...    ...
# 541626              No  2018      8
# 541625             Yes  2018      8
# 541624             Yes  2018     11
# 541630              No  2018      8
# 456155              No  2018      6
#
# [638123 rows x 10 columns]

# %%
#swt_data.to_csv('ukwri_cleaned.csv')

# %%
#Extract names of sites from location data and edit the strings for consistency

sites = location.uwwName.unique()
s_names = []

for site in sites:
  site = site.replace(" ", "")
  
  if len(site) >= 9:
            site= site[:12]
  else:
    site = site
    
  s_names.append(site)

sites = list(sites)

s_names = list(s_names)

# %%
type(sites)
# Out:
# list

# %%
site_edited = dict(zip(sites, s_names))

# %%
len(site_edited)
# Out:
# 1860

# %%
site_edited = dict(sorted(site_edited.items()))

# %%
site_edited
# Out:
# {'ABERBAIDENBEHINDHOPYARDFARM': 'ABERBAIDENBE',
#  'ABERFELDY': 'ABERFELDY',
#  'ABERGAVENNY': 'ABERGAVENNY',
#  'ABERYYTH': 'ABERYYTH',
#  'ABINGDON': 'ABINGDON',
#  'ABINGDON(OXON)': 'ABINGDON(OXO',
#  'ABOYNE': 'ABOYNE',
#  'ACKWORTH': 'ACKWORTH',
#  'ACLE': 'ACLE',
#  'ADPARADPARCEREDIGION': 'ADPARADPARCE',
#  'ADWICK-LE-STREETANDCARCROFT': 'ADWICK-LE-ST',
#  'AINSDALE': 'AINSDALE',
#  'AIREDALE': 'AIREDALE',
#  'AIRTH': 'AIRTH',
#  'ALBRIGHTON': 'ALBRIGHTON',
#  'ALCESTER': 'ALCESTER',
#  'ALCONBURY': 'ALCONBURY',
#  'ALDERLEYEDGE': 'ALDERLEYEDGE',
#  'ALDERSHOT,ALDERSHOT,HANTS"': 'ALDERSHOT,AL',
#  'ALDERSHOTMILITARY': 'ALDERSHOTMIL',
#  'ALFORD': 'ALFORD',
#  'ALFRETON': 'ALFRETON',
#  'ALLANFEARN,INVERNESS': 'ALLANFEARN,I',
#  'ALLERSS.T.W.': 'ALLERSS.T.W.',
#  'ALLOA': 'ALLOA',
#  'ALMONDSBURY': 'ALMONDSBURY',
#  'ALNESS&INVERGORDON': 'ALNESS&INVER',
#  'ALNWICK': 'ALNWICK',
#  'ALRESFORD': 'ALRESFORD',
#  'ALREWAS': 'ALREWAS',
#  'ALSAGER': 'ALSAGER',
#  'ALTHORPE': 'ALTHORPE',
#  'ALTON': 'ALTON',
#  'ALTON,ALTON,HAMPSHIRE"': 'ALTON,ALTON,',
#  'ALTRINCHAM': 'ALTRINCHAM',
#  'ALVA': 'ALVA',
#  'ALVECHURCH': 'ALVECHURCH',
#  'ALVELEY': 'ALVELEY',
#  'ALVESTON': 'ALVESTON',
#  'ALYTH': 'ALYTH',
#  'AMBERGATE': 'AMBERGATE',
#  'AMBLE': 'AMBLE',
#  'AMBLESIDE': 'AMBLESIDE',
#  'AMESBURY': 'AMESBURY',
#  'AMMANFORD': 'AMMANFORD',
#  'AMPNEYSTPETER,AMPNEYSTPETE"': 'AMPNEYSTPETE',
#  'ANDOVER': 'ANDOVER',
#  'ANNANDALEWATERMSAS.T.W.': 'ANNANDALEWAT',
#  'ANNANKENZIELSS.T.W.': 'ANNANKENZIEL',
#  'ANNESBOROUGH': 'ANNESBOROUGH',
#  'ANTRIM(MILLTOWN)': 'ANTRIM(MILLT',
#  'ANWICK': 'ANWICK',
#  'AOODBANK': 'AOODBANK',
#  'APPLEBY': 'APPLEBY',
#  'APPLETON,ABINGDON,OXON"': 'APPLETON,ABI',
#  'ARBORFIELD,ARBORFIELD,BERKS"': 'ARBORFIELD,A',
#  'ARDOCHS.T.W.': 'ARDOCHS.T.W.',
#  'ARLEY': 'ARLEY',
#  'ARMADALE': 'ARMADALE',
#  'ARMAGH': 'ARMAGH',
#  'ARMITAGE': 'ARMITAGE',
#  'ARMTHORPE': 'ARMTHORPE',
#  'ASCOT': 'ASCOT',
#  'ASFORDBY': 'ASFORDBY',
#  'ASHBOURNE': 'ASHBOURNE',
#  'ASHBROOK': 'ASHBROOK',
#  'ASHFORD': 'ASHFORD',
#  'ASHINGTON,LONDONROAD"': 'ASHINGTON,LO',
#  'ASHTON': 'ASHTON',
#  'ASHTON-UNDER-LYNE': 'ASHTON-UNDER',
#  'ASHVALE,STRATFORDROAD,NORTH"': 'ASHVALE,STRA',
#  'ASKAM-IN-FURNESS': 'ASKAM-IN-FUR',
#  'ASLOCKTON': 'ASLOCKTON',
#  'ASPATRIA': 'ASPATRIA',
#  'ATHERSTONE': 'ATHERSTONE',
#  'ATTLEBOROUGH': 'ATTLEBOROUGH',
#  'AUCHTERARDER': 'AUCHTERARDER',
#  'AUDLEY': 'AUDLEY',
#  'AVIEMORE': 'AVIEMORE',
#  'AVOCH': 'AVOCH',
#  'AXMINSTER': 'AXMINSTER',
#  'AYLESBURY,RABANSLANE,AYLESBU"': 'AYLESBURY,RA',
#  'AYLSHAM': 'AYLSHAM',
#  'B/AUFES': 'B/AUFES',
#  'BADWELLASH': 'BADWELLASH',
#  'BAKEWELL': 'BAKEWELL',
#  'BALA': 'BALA',
#  'BALBY': 'BALBY',
#  'BALDERTON': 'BALDERTON',
#  'BALFRON': 'BALFRON',
#  'BALLATER': 'BALLATER',
#  'BALLYCASTLE': 'BALLYCASTLE',
#  'BALLYCLARE': 'BALLYCLARE',
#  'BALLYGOWAN': 'BALLYGOWAN',
#  'BALLYKELLY': 'BALLYKELLY',
#  'BALLYMENA(TULLAGHGARLEY)': 'BALLYMENA(TU',
#  'BALLYMONEY(GLENSTALL)': 'BALLYMONEY(G',
#  'BALLYNACOR': 'BALLYNACOR',
#  'BALLYNAHINCH': 'BALLYNAHINCH',
#  'BALLYRICKARD': 'BALLYRICKARD',
#  'BALSALLCOMMON': 'BALSALLCOMMO',
#  'BALSHAM': 'BALSHAM',
#  'BAMPTON,BAMPTON,OXON"': 'BAMPTON,BAMP',
#  'BANBRIDGE': 'BANBRIDGE',
#  'BANBURY,SPITALFARM,BANBURY,"': 'BANBURY,SPIT',
#  'BANCHORY': 'BANCHORY',
#  'BANFFMACDUFF-MORAYPFI': 'BANFFMACDUFF',
#  'BARCOMBENEW': 'BARCOMBENEW',
#  'BARHILL': 'BARHILL',
#  'BARLBY(WASMISSPELTBALBY)': 'BARLBY(WASMI',
#  'BARLESTONE': 'BARLESTONE',
#  'BARNARDCASTLE': 'BARNARDCASTL',
#  'BARNOLDSWICK': 'BARNOLDSWICK',
#  'BARNSLEY(DARTON)': 'BARNSLEY(DAR',
#  'BARNSLEY(LUNDWOOD)': 'BARNSLEY(LUN',
#  'BARNSTAPLE': 'BARNSTAPLE',
#  'BARROW&QUORN': 'BARROW&QUORN',
#  'BARROW-IN-FURNESS': 'BARROW-IN-FU',
#  'BARSTON': 'BARSTON',
#  'BARTON': 'BARTON',
#  'BARTON-UNDER-NEEDWOOD': 'BARTON-UNDER',
#  'BARTON-UPON-HUMBER': 'BARTON-UPON-',
#  'BARTONLECLAY': 'BARTONLECLAY',
#  'BARTONSTACEY': 'BARTONSTACEY',
#  'BARWICK': 'BARWICK',
#  'BASCHURCH': 'BASCHURCH',
#  'BASILDON': 'BASILDON',
#  'BASINGSTOKE,WILDMOOR,BASINGST"': 'BASINGSTOKE,',
#  'BASLOW': 'BASLOW',
#  'BASSINGBOURN': 'BASSINGBOURN',
#  'BASSINGHAM': 'BASSINGHAM',
#  'BATH': 'BATH',
#  'BATHGATE': 'BATHGATE',
#  'BATTLE,MARLEYLANE,BATTLE"': 'BATTLE,MARLE',
#  'BEARPARK': 'BEARPARK',
#  'BECCLES': 'BECCLES',
#  'BEDALE': 'BEDALE',
#  'BEDFORD': 'BEDFORD',
#  'BEDWORTH': 'BEDWORTH',
#  'BEESTON': 'BEESTON',
#  'BELAUGH': 'BELAUGH',
#  'BELBROUGHTON': 'BELBROUGHTON',
#  'BELFAST': 'BELFAST',
#  'BELPER': 'BELPER',
#  'BENFLEET': 'BENFLEET',
#  'BENHALL': 'BENHALL',
#  'BENRHYDDING': 'BENRHYDDING',
#  'BENSON,HENLEYROAD,BENSON,OX"': 'BENSON,HENLE',
#  'BENTLEY': 'BENTLEY',
#  'BEREALSTON': 'BEREALSTON',
#  'BERKHAMSTEDSEWAGEWORKS,BULLBEGGA"': 'BERKHAMSTEDS',
#  'BERWICK': 'BERWICK',
#  'BETHESDA': 'BETHESDA',
#  'BEVERLEY': 'BEVERLEY',
#  'BICESTER,BICESTER,OXON"': 'BICESTER,BIC',
#  'BIDBOROUGH': 'BIDBOROUGH',
#  'BIDDENDEN': 'BIDDENDEN',
#  'BIDDULPH': 'BIDDULPH',
#  'BIDEFORD/NORTHAM': 'BIDEFORD/NOR',
#  'BIDFORDONAVON': 'BIDFORDONAVO',
#  'BIGGARS.T.W.': 'BIGGARS.T.W.',
#  'BIGGLESWADE': 'BIGGLESWADE',
#  'BILLERICAY': 'BILLERICAY',
#  'BILLINGESOUTH': 'BILLINGESOUT',
#  'BILLINGHAM': 'BILLINGHAM',
#  'BILLINGHAY': 'BILLINGHAY',
#  'BILLINGSHURST': 'BILLINGSHURS',
#  'BILLINGTON': 'BILLINGTON',
#  'BILSTHORPE': 'BILSTHORPE',
#  'BINGLEY': 'BINGLEY',
#  'BIRKENHEADANDWALLASEY': 'BIRKENHEADAN',
#  'BIRMINGHAM&BLACKCOUNTRYNO.1(MINWORTH)': 'BIRMINGHAM&B',
#  'BIRMINGHAM&BLACKCOUNTRYNO.3(WILLENHALL)': 'BIRMINGHAM&B',
#  'BIRMINGHAMEAST(COLESHILL)': 'BIRMINGHAMEA',
#  'BIRTLEY': 'BIRTLEY',
#  'BISHOPAUCKLAND': 'BISHOPAUCKLA',
#  'BISHOPSCASTLE': 'BISHOPSCASTL',
#  'BISHOPSLYDEARD': 'BISHOPSLYDEA',
#  'BISHOPSSTORTFORD,BISHOP\'SSTO"': 'BISHOPSSTORT',
#  'BISHOPSWALTHAMNEW': 'BISHOPSWALTH',
#  'BLACKBURN': 'BLACKBURN',
#  'BLACKFORD': 'BLACKFORD',
#  'BLACKHEATH': 'BLACKHEATH',
#  'BLACKMINSTER': 'BLACKMINSTER',
#  'BLACKRIDGE': 'BLACKRIDGE',
#  'BLACKWOODS.T.W.': 'BLACKWOODS.T',
#  'BLAIRATHOLL': 'BLAIRATHOLL',
#  'BLAIRGOWRIE': 'BLAIRGOWRIE',
#  'BLAKENEY': 'BLAKENEY',
#  'BLANDFORDFORUM': 'BLANDFORDFOR',
#  'BLOCKLEY': 'BLOCKLEY',
#  'BLOXHAM,BLOXHAM,OXON"': 'BLOXHAM,BLOX',
#  'BLUESTONELEISURECANASTON': 'BLUESTONELEI',
#  'BLYTH': 'BLYTH',
#  "BO'NESS": "BO'NESS",
#  'BOCKING': 'BOCKING',
#  'BODMIN(NANSTALLON)': 'BODMIN(NANST',
#  'BODMIN(SCARLETTSWELL)': 'BODMIN(SCARL',
#  'BOLSOVER': 'BOLSOVER',
#  'BOLTON': 'BOLTON',
#  'BOLTONONDEARNE': 'BOLTONONDEAR',
#  'BONNYBRIDGE': 'BONNYBRIDGE',
#  'BORDON,BORDON,HANTS"': 'BORDON,BORDO',
#  'BOROUGHBRIDGE': 'BOROUGHBRIDG',
#  'BORTH': 'BORTH',
#  'BOSHAM': 'BOSHAM',
#  'BOSTON': 'BOSTON',
#  'BOTHWELLBANKS.T.W.': 'BOTHWELLBANK',
#  'BOTTESFORD': 'BOTTESFORD',
#  'BOTTISHAM': 'BOTTISHAM',
#  'BOUGHTON': 'BOUGHTON',
#  'BOURN': 'BOURN',
#  'BOURNE': 'BOURNE',
#  'BOURNEMOUTH(HOLDENHURST)': 'BOURNEMOUTH(',
#  'BOURNEMOUTH(KINSON)': 'BOURNEMOUTH(',
#  'BOURTON-ON-THE-WATER,BOURTON-O"': 'BOURTON-ON-T',
#  'BOWBURN': 'BOWBURN',
#  'BOWDEN': 'BOWDEN',
#  'BOWERHILL': 'BOWERHILL',
#  'BOWHOUSE': 'BOWHOUSE',
#  'BOX': 'BOX',
#  'BOZEAT': 'BOZEAT',
#  'BRACKLEY': 'BRACKLEY',
#  'BRACKNELL,HAZELWOODLANE,BINF"': 'BRACKNELL,HA',
#  'BRADFORDESHOLT': 'BRADFORDESHO',
#  'BRADFORDONAVON': 'BRADFORDONAV',
#  'BRADNINCH': 'BRADNINCH',
#  'BRADWELL': 'BRADWELL',
#  'BRAINTREE': 'BRAINTREE',
#  'BRAMCOTE/WOLVEY': 'BRAMCOTE/WOL',
#  'BRAMPTON': 'BRAMPTON',
#  'BRANCOTE': 'BRANCOTE',
#  'BRANDESBURTON': 'BRANDESBURTO',
#  'BRANDON': 'BRANDON',
#  'BRANTHAM': 'BRANTHAM',
#  'BRANTON': 'BRANTON',
#  'BRAYSTONES': 'BRAYSTONES',
#  'BRECHIN': 'BRECHIN',
#  'BRECONBRECONBRECONPOWYS': 'BRECONBRECON',
#  'BREDON': 'BREDON',
#  'BRIDGEND': 'BRIDGEND',
#  'BRIDGNORTH': 'BRIDGNORTH',
#  'BRIDGWATER': 'BRIDGWATER',
#  'BRIDLINGTON': 'BRIDLINGTON',
#  'BRIDPORT': 'BRIDPORT',
#  'BRIGG': 'BRIGG',
#  'BRIGHTLINGSEA': 'BRIGHTLINGSE',
#  'BRISTOL': 'BRISTOL',
#  'BRISTON': 'BRISTON',
#  'BRIXWORTH': 'BRIXWORTH',
#  'BROADSTAIRS/MARGATEOUTCSM(WEATHERLEESB)': 'BROADSTAIRS/',
#  'BROADWAY': 'BROADWAY',
#  'BROADWELL,BROADWELL,OXON"': 'BROADWELL,BR',
#  'BROCKENHURST': 'BROCKENHURST',
#  'BROCKHAMPTON': 'BROCKHAMPTON',
#  'BROMBOROUGH': 'BROMBOROUGH',
#  'BROMSGROVE': 'BROMSGROVE',
#  'BROMYARDBROMYARD': 'BROMYARDBROM',
#  'BROOMHAUGH': 'BROOMHAUGH',
#  'BROUGHTON': 'BROUGHTON',
#  'BROUGHTONASTLEY': 'BROUGHTONAST',
#  'BRUTON': 'BRUTON',
#  'BRYNMAWRBLACKROCKBRYNMAWR': 'BRYNMAWRBLAC',
#  'BUCKDEN': 'BUCKDEN',
#  'BUCKFASTLEIGH': 'BUCKFASTLEIG',
#  'BUCKINGHAM': 'BUCKINGHAM',
#  'BUCKLEY': 'BUCKLEY',
#  'BUDE': 'BUDE',
#  'BUGBROOKE': 'BUGBROOKE',
#  'BUILTHWELLS': 'BUILTHWELLS',
#  'BULKINGTON': 'BULKINGTON',
#  'BUNGAY': 'BUNGAY',
#  'BUNTINGFORD,ASPENDENLANE,BUN"': 'BUNTINGFORD,',
#  'BURFORD,OXON"': 'BURFORD,OXON',
#  'BURGESSHILL': 'BURGESSHILL',
#  'BURGHFIELD,BURGHFIELD,BERKS"': 'BURGHFIELD,B',
#  'BURLEY/MENSTON': 'BURLEY/MENST',
#  'BURNHAM-ON-SEA/HIGHBRIDGE': 'BURNHAM-ON-S',
#  'BURNHAMMARKET': 'BURNHAMMARKE',
#  'BURNHAMONCROUCH': 'BURNHAMONCRO',
#  'BURNLEY': 'BURNLEY',
#  'BURNTWOOD': 'BURNTWOOD',
#  'BURSCOUGH': 'BURSCOUGH',
#  'BURSLEDON': 'BURSLEDON',
#  'BURSTOW': 'BURSTOW',
#  'BURTONONTHEWOLDS': 'BURTONONTHEW',
#  'BURTONONTRENT': 'BURTONONTREN',
#  'BURTONSTATHER': 'BURTONSTATHE',
#  'BURWELL': 'BURWELL',
#  'BURY': 'BURY',
#  'BURYST.EDMUNDS': 'BURYST.EDMUN',
#  'BUSHMILLS': 'BUSHMILLS',
#  'BUTLEIGH': 'BUTLEIGH',
#  'BUXTON': 'BUXTON',
#  'BYFIELD,BYFIELD,NORTHANTS"': 'BYFIELD,BYFI',
#  'BYLAUGH': 'BYLAUGH',
#  'CADDINGTON': 'CADDINGTON',
#  'CAERNARFON': 'CAERNARFON',
#  'CAISTOR': 'CAISTOR',
#  'CALLANDER': 'CALLANDER',
#  'CALLINGTON': 'CALLINGTON',
#  'CALNE': 'CALNE',
#  'CALSTOCK': 'CALSTOCK',
#  'CALVERTON': 'CALVERTON',
#  'CAMBERLEY,CAMBERLEY,SURREY"': 'CAMBERLEY,CA',
#  'CAMBOIS': 'CAMBOIS',
#  'CAMBORNE/REDRUTH': 'CAMBORNE/RED',
#  'CAMBRIDGE': 'CAMBRIDGE',
#  'CAMELFORD': 'CAMELFORD',
#  'CAMVALLEY': 'CAMVALLEY',
#  'CANNINGTON': 'CANNINGTON',
#  'CANNOCK': 'CANNOCK',
#  'CANTERBURY': 'CANTERBURY',
#  'CANVEYISLAND,CANVEYISLAND,E"': 'CANVEYISLAND',
#  'CARBARNSS.T.W.': 'CARBARNSS.T.',
#  'CARDIFF': 'CARDIFF',
#  'CARDIFF(WEST)ANDBARRY(COGMOORS)': 'CARDIFF(WEST',
#  'CARDIGAN': 'CARDIGAN',
#  'CARLETON': 'CARLETON',
#  'CARLISLE': 'CARLISLE',
#  'CARLTON&REDMARSHALL': 'CARLTON&REDM',
#  'CARMARTHEN': 'CARMARTHEN',
#  'CARNFORTH': 'CARNFORTH',
#  'CARNONDOWNS': 'CARNONDOWNS',
#  'CARRICKFERGUS': 'CARRICKFERGU',
#  'CARSTAIRSJUNCTIONS.T.W.': 'CARSTAIRSJUN',
#  'CARTERTON,CARTERTON,OXON"': 'CARTERTON,CA',
#  'CASSINGTON,YARNTONROAD,CASSI"': 'CASSINGTON,Y',
#  'CASTLECARY': 'CASTLECARY',
#  'CASTLEDERG': 'CASTLEDERG',
#  'CASTLEDONINGTON': 'CASTLEDONING',
#  'CASTLEDOUGLASS.T.W.': 'CASTLEDOUGLA',
#  'CASTLETON': 'CASTLETON',
#  'CATON': 'CATON',
#  'CATRINEHOLMS.T.W.': 'CATRINEHOLMS',
#  'CATTERICK': 'CATTERICK',
#  'CEFNMAWRHEOLBERWYNCEFNMAWR': 'CEFNMAWRHEOL',
#  'CHALGROVE,CHALGROVE,OXON"': 'CHALGROVE,CH',
#  'CHALTON': 'CHALTON',
#  'CHANTRY': 'CHANTRY',
#  'CHAPEL-EN-LE-FRITH': 'CHAPEL-EN-LE',
#  'CHARD': 'CHARD',
#  'CHARFIELD': 'CHARFIELD',
#  'CHARING': 'CHARING',
#  'CHARLBURY,CHARLBURY,OXON"': 'CHARLBURY,CH',
#  'CHARMOUTH': 'CHARMOUTH',
#  'CHARTHAM': 'CHARTHAM',
#  'CHATHAMANDGILLINGHAM': 'CHATHAMANDGI',
#  'CHATTERIS': 'CHATTERIS',
#  'CHECKLEY': 'CHECKLEY',
#  'CHEDDAR': 'CHEDDAR',
#  'CHEDDLETON': 'CHEDDLETON',
#  'CHEESEBOTTOM': 'CHEESEBOTTOM',
#  'CHELLINGTON': 'CHELLINGTON',
#  'CHELMSFORD': 'CHELMSFORD',
#  'CHELTENHAM': 'CHELTENHAM',
#  'CHERRYBURTON': 'CHERRYBURTON',
#  'CHERTSEY,LYNELANE,CHERTSEY,"': 'CHERTSEY,LYN',
#  'CHESHAM,BUCKS"': 'CHESHAM,BUCK',
#  'CHESTER': 'CHESTER',
#  'CHESTER-LE-STREET': 'CHESTER-LE-S',
#  'CHESTERFIELD': 'CHESTERFIELD',
#  'CHEWSTOKE': 'CHEWSTOKE',
#  'CHICHESTER': 'CHICHESTER',
#  'CHIDDINGFOLD': 'CHIDDINGFOLD',
#  'CHIDEOCK': 'CHIDEOCK',
#  'CHIEVELEY,CHIEVELEY,BERKS"': 'CHIEVELEY,CH',
#  'CHILTON(WINDLESTONE)': 'CHILTON(WIND',
#  'CHINNOR,CHINNOR,OXON"': 'CHINNOR,CHIN',
#  'CHIPPENHAM': 'CHIPPENHAM',
#  'CHIPPINGCAMPDEN': 'CHIPPINGCAMP',
#  'CHIPPINGNORTON,WORCESTERROAD"': 'CHIPPINGNORT',
#  'CHOBHAM': 'CHOBHAM',
#  'CHOLSEY,CHOLSEY,WALLINGFORD,"': 'CHOLSEY,CHOL',
#  'CHORLEY': 'CHORLEY',
#  'CHRISTCHURCH': 'CHRISTCHURCH',
#  'CHUDLEIGH': 'CHUDLEIGH',
#  'CHURCHHANBOROUGH,CHURCHHANBO"': 'CHURCHHANBOR',
#  'CHURCHSTRETTON': 'CHURCHSTRETT',
#  'CINDERFORDCRUMPMEADOW': 'CINDERFORDCR',
#  'CIRENCESTER,CIRENCESTER,GLOS"': 'CIRENCESTER,',
#  'CLACTON': 'CLACTON',
#  'CLARE': 'CLARE',
#  'CLAUDY': 'CLAUDY',
#  'CLAYCROSS': 'CLAYCROSS',
#  'CLAYTONWEST,DENBYDALE"': 'CLAYTONWEST,',
#  'CLEATOR': 'CLEATOR',
#  'CLEETHORPES': 'CLEETHORPES',
#  'CLEOBURYMORTIMER': 'CLEOBURYMORT',
#  'CLEVEDON/NAILSEA/YATTON': 'CLEVEDON/NAI',
#  'CLEYNEXTTHESEA': 'CLEYNEXTTHES',
#  'CLIFTON': 'CLIFTON',
#  'CLITHEROE': 'CLITHEROE',
#  'CLOPHILL': 'CLOPHILL',
#  'CLOWNE': 'CLOWNE',
#  'COALEY': 'COALEY',
#  'COALISLAND': 'COALISLAND',
#  'COCKERMOUTH': 'COCKERMOUTH',
#  'CODSALL': 'CODSALL',
#  'COGGESHALL': 'COGGESHALL',
#  'COLBURN': 'COLBURN',
#  'COLCHESTER': 'COLCHESTER',
#  'COLDHIENDLEY': 'COLDHIENDLEY',
#  'COLDSTREAM': 'COLDSTREAM',
#  'COLEFORD': 'COLEFORD',
#  'COLERNE': 'COLERNE',
#  'COLLINGHAM': 'COLLINGHAM',
#  'COLNE': 'COLNE',
#  'COLWALL': 'COLWALL',
#  'COLWYNBAY/LLANDUDNO': 'COLWYNBAY/LL',
#  'COLYTON&COLYFORD': 'COLYTON&COLY',
#  'COMPTON,COO"': 'COMPTON,COO"',
#  'COMPTONANDMARLDON': 'COMPTONANDMA',
#  'COMPTONBASSETT': 'COMPTONBASSE',
#  'COMRIE': 'COMRIE',
#  'CONEYWESTON': 'CONEYWESTON',
#  'CONGLETON': 'CONGLETON',
#  'CONINGSBY': 'CONINGSBY',
#  'CONNAHSQUAY': 'CONNAHSQUAY',
#  'CONONBRIDGE': 'CONONBRIDGE',
#  'CONSETT': 'CONSETT',
#  'COOKSTOWN': 'COOKSTOWN',
#  'COPFORD': 'COPFORD',
#  'CORBY': 'CORBY',
#  'CORFECASTLE': 'CORFECASTLE',
#  'CORFEMULLEN': 'CORFEMULLEN',
#  'CORPACH': 'CORPACH',
#  'CORWEN': 'CORWEN',
#  'COTGRAVE': 'COTGRAVE',
#  'COTONPARK': 'COTONPARK',
#  'COTTESMORE': 'COTTESMORE',
#  'COUNTESTHORPE': 'COUNTESTHORP',
#  'COUPARANGUS': 'COUPARANGUS',
#  'COURSINGTONS.T.W.': 'COURSINGTONS',
#  'COVENTRY': 'COVENTRY',
#  'COWBIT': 'COWBIT',
#  'COWBRIDGECOWBRIDGEVALEOFGLA': 'COWBRIDGECOW',
#  'COWIE,STIRLING': 'COWIE,STIRLI',
#  'COXHEATH': 'COXHEATH',
#  'COYLTONS.T.W.(JOPPAS.T.W.)': 'COYLTONS.T.W',
#  'CRAMLINGTON': 'CRAMLINGTON',
#  'CRANBROOK': 'CRANBROOK',
#  'CRANLEIGH,CRANLEIGH,SURREY"': 'CRANLEIGH,CR',
#  'CRANWELL': 'CRANWELL',
#  'CRAVENARMS': 'CRAVENARMS',
#  'CREAGH': 'CREAGH',
#  'CREDITON': 'CREDITON',
#  'CREIGIAUSEW': 'CREIGIAUSEW',
#  'CRESWELL': 'CRESWELL',
#  'CREWE': 'CREWE',
#  'CREWKERNEEAST': 'CREWKERNEEAS',
#  'CRICKLADE,CRICKLADE,WILTS"': 'CRICKLADE,CR',
#  'CRIEFF': 'CRIEFF',
#  'CROFTON': 'CROFTON',
#  'CROMER': 'CROMER',
#  'CROMWELL': 'CROMWELL',
#  'CROOKHALL': 'CROOKHALL',
#  'CROPTHORNEHEATH': 'CROPTHORNEHE',
#  'CROPWELLBISHOP': 'CROPWELLBISH',
#  'CROSSHANDSS': 'CROSSHANDSS',
#  'CROSSMAGLEN(LISCALGOT)': 'CROSSMAGLEN(',
#  'CROSTON': 'CROSTON',
#  'CROWBOROUGH': 'CROWBOROUGH',
#  'CROWLAND': 'CROWLAND',
#  'CROWLE': 'CROWLE',
#  'CRYNANT': 'CRYNANT',
#  'CUBLINGTON': 'CUBLINGTON',
#  'CUCKFIELD': 'CUCKFIELD',
#  'CUDDINGTON': 'CUDDINGTON',
#  'CUDWORTH': 'CUDWORTH',
#  'CULHAM,CULHAM,CLIFTONHAMPDEN"': 'CULHAM,CULHA',
#  'CULLOMPTON': 'CULLOMPTON',
#  'CULMORE': 'CULMORE',
#  'CUPAR': 'CUPAR',
#  'CWMGWRCH': 'CWMGWRCH',
#  'CYNONVALLEY': 'CYNONVALLEY',
#  'DALBEATTIES.T.W.': 'DALBEATTIES.',
#  'DALDERSE': 'DALDERSE',
#  'DALDOWIES.T.W.': 'DALDOWIES.T.',
#  'DALMARNOCKS.T.W.': 'DALMARNOCKS.',
#  'DALMELLINGTONS.T.W.': 'DALMELLINGTO',
#  'DALMUIRPFI-DALMUIR': 'DALMUIRPFI-D',
#  'DALSCONES.T.W.(NEW)': 'DALSCONES.T.',
#  'DALSCONES.T.W.(OLD)': 'DALSCONES.T.',
#  'DALSTON': 'DALSTON',
#  'DANESMOORWPCWORKSFINALEFFLUENT': 'DANESMOORWPC',
#  'DARFIELD': 'DARFIELD',
#  'DARLEY': 'DARLEY',
#  'DARLINGTON': 'DARLINGTON',
#  'DARTMOUTH': 'DARTMOUTH',
#  'DARWEN': 'DARWEN',
#  'DAVENTRY': 'DAVENTRY',
#  'DAWLISH': 'DAWLISH',
#  'DEARHAM': 'DEARHAM',
#  'DEBENHAM': 'DEBENHAM',
#  'DEDHAM': 'DEDHAM',
#  'DEE': 'DEE',
#  'DEEPINGS': 'DEEPINGS',
#  'DELABOLE': 'DELABOLE',
#  'DENABY': 'DENABY',
#  'DENBIGH': 'DENBIGH',
#  'DENHOLME': 'DENHOLME',
#  'DENNY': 'DENNY',
#  'DERBY': 'DERBY',
#  'DEREHAM': 'DEREHAM',
#  'DEVIZES': 'DEVIZES',
#  'DEWSBURYANDBATLEY': 'DEWSBURYANDB',
#  'DIDCOT,FOXHALLROAD,DIDCOT,O"': 'DIDCOT,FOXHA',
#  'DINGWALL': 'DINGWALL',
#  'DINNINGTON': 'DINNINGTON',
#  'DIPTON': 'DIPTON',
#  'DISS': 'DISS',
#  'DITTON': 'DITTON',
#  'DODDINGHURST': 'DODDINGHURST',
#  'DODDINGTON': 'DODDINGTON',
#  'DOLGELLAUST': 'DOLGELLAUST',
#  'DOLLAR': 'DOLLAR',
#  'DONAGHMORE': 'DONAGHMORE',
#  'DONCASTER(BENTLEY)': 'DONCASTER(BE',
#  'DONCASTER(SANDALL)': 'DONCASTER(SA',
#  'DONINGTON': 'DONINGTON',
#  'DONISTHORPE': 'DONISTHORPE',
#  'DONNEYBREWER': 'DONNEYBREWER',
#  'DORCHESTER': 'DORCHESTER',
#  'DORCHESTER(OXON)': 'DORCHESTER(O',
#  'DORKING,PIXHAMLANE,DORKING,"': 'DORKING,PIXH',
#  'DORNOCH': 'DORNOCH',
#  'DOUGLASS.T.W.': 'DOUGLASS.T.W',
#  'DOVER/FOLKSTONE': 'DOVER/FOLKST',
#  'DOWNHAMMARKET': 'DOWNHAMMARKE',
#  'DOWNPATRICK': 'DOWNPATRICK',
#  'DOWNTON': 'DOWNTON',
#  'DRAPERSTOWN': 'DRAPERSTOWN',
#  'DRAYTON,DRAYTON,OXON"': 'DRAYTON,DRAY',
#  'DREFACH/VELI': 'DREFACH/VELI',
#  'DRIFFIELD': 'DRIFFIELD',
#  'DROITWICH': 'DROITWICH',
#  'DROMORE': 'DROMORE',
#  'DROMORE,TYRONE': 'DROMORE,TYRO',
#  'DRONFIELD': 'DRONFIELD',
#  'DRONGANS.T.W.': 'DRONGANS.T.W',
#  'DROPEWESTBURYHOMESGLAMORGAN': 'DROPEWESTBUR',
#  'DRUMANESS': 'DRUMANESS',
#  'DRUMNADROCHIT': 'DRUMNADROCHI',
#  'DUFFIELD': 'DUFFIELD',
#  'DUKINFIELD': 'DUKINFIELD',
#  'DUNBAR(SOUTH)': 'DUNBAR(SOUTH',
#  'DUNBLANE': 'DUNBLANE',
#  'DUNCHURCH': 'DUNCHURCH',
#  'DUNFERMLINE': 'DUNFERMLINE',
#  'DUNGIVEN': 'DUNGIVEN',
#  'DUNHAMMASSEY': 'DUNHAMMASSEY',
#  'DUNHOLME': 'DUNHOLME',
#  'DUNMURRY': 'DUNMURRY',
#  'DUNNSWOODS.T.W.': 'DUNNSWOODS.T',
#  'DUNOON': 'DUNOON',
#  'DUNS': 'DUNS',
#  'DUNSTABLE': 'DUNSTABLE',
#  'DURHAM(BARKERSHAUGH)': 'DURHAM(BARKE',
#  'DURHAM(BELMONT)': 'DURHAM(BELMO',
#  'DURHAM(BROWNEY)': 'DURHAM(BROWN',
#  'DURHAMCOLLEGES(UNIVERSITY)': 'DURHAMCOLLEG',
#  'DYFFRYNARDUDWY': 'DYFFRYNARDUD',
#  'DYSERTH': 'DYSERTH',
#  'EAGLESHAMS.T.W.': 'EAGLESHAMS.T',
#  'EARBY': 'EARBY',
#  'EARLSCOLNE': 'EARLSCOLNE',
#  'EARLSHILTON': 'EARLSHILTON',
#  'EASINGWOLD': 'EASINGWOLD',
#  'EASTBERGHOLT': 'EASTBERGHOLT',
#  'EASTBOURNE': 'EASTBOURNE',
#  'EASTBRIDGFORD': 'EASTBRIDGFOR',
#  'EASTCALDER': 'EASTCALDER',
#  'EASTCHURCH': 'EASTCHURCH',
#  'EASTCOKER': 'EASTCOKER',
#  'EASTHAMPSTEADPARK': 'EASTHAMPSTEA',
#  'EASTHARLING': 'EASTHARLING',
#  'EASTHASTINGS,BEXHILL"': 'EASTHASTINGS',
#  'EASTLEAKE': 'EASTLEAKE',
#  'EASTLEIGH': 'EASTLEIGH',
#  'EASTMARKHAM': 'EASTMARKHAM',
#  'EASTPECKHAM': 'EASTPECKHAM',
#  'EASTRIGGSS.T.W.': 'EASTRIGGSS.T',
#  'EASTRY': 'EASTRY',
#  'EASTSHEFFORD,EASTSHEFFORD,B"': 'EASTSHEFFORD',
#  'ECCLES': 'ECCLES',
#  'ECCLESHALL': 'ECCLESHALL',
#  'EDENBRIDGE': 'EDENBRIDGE',
#  'EDENVALE': 'EDENVALE',
#  'EDGMOND': 'EDGMOND',
#  'EDINBURGH,SEAFIELD': 'EDINBURGH,SE',
#  'EDWINSTOWE': 'EDWINSTOWE',
#  'EGGBOROUGH': 'EGGBOROUGH',
#  'EIGHASHGREEN': 'EIGHASHGREEN',
#  'EIGNOUTFALLWORKSROADHFD': 'EIGNOUTFALLW',
#  'ELDMIRE': 'ELDMIRE',
#  'ELLERKER': 'ELLERKER',
#  'ELLESMEREPORT': 'ELLESMEREPOR',
#  'ELLESMEREWHARFMEADOW': 'ELLESMEREWHA',
#  'ELLON': 'ELLON',
#  'ELMSWELL': 'ELMSWELL',
#  'ELSECAR,LUNDHULLANDWOMBWELL"': 'ELSECAR,LUND',
#  'ELSTEAD,ELSTEAD,SURREY"': 'ELSTEAD,ELST',
#  'ELY': 'ELY',
#  'ELYNEW': 'ELYNEW',
#  'EMPINGHAM': 'EMPINGHAM',
#  'ENDON': 'ENDON',
#  'ENNISKILLEN': 'ENNISKILLEN',
#  'EPPING,FIDDLERSHAMLET,EPPING"': 'EPPING,FIDDL',
#  'EPWORTH': 'EPWORTH',
#  'ERNESETTLEANDSALTASH': 'ERNESETTLEAN',
#  'ERSKINES.T.W.': 'ERSKINES.T.W',
#  'ESHER,FARMROAD,ESHER,SURREY"': 'ESHER,FARMRO',
#  'ESHWINNING': 'ESHWINNING',
#  'ETWALL': 'ETWALL',
#  'EVANTON': 'EVANTON',
#  'EVERCREECH': 'EVERCREECH',
#  'EVESHAM': 'EVESHAM',
#  'EXETER': 'EXETER',
#  'EXMOUTH': 'EXMOUTH',
#  'EYE': 'EYE',
#  'FAILSWORTH': 'FAILSWORTH',
#  'FAIRFORD,FAIRFORD,GLOS"': 'FAIRFORD,FAI',
#  'FAKENHAM': 'FAKENHAM',
#  'FALLIN': 'FALLIN',
#  'FALMOUTH': 'FALMOUTH',
#  'FAREHAMANDGOSPORT,HAMBLE,HEDGEEND(PEELCOMMON)"': 'FAREHAMANDGO',
#  'FARINGDON,OXON"': 'FARINGDON,OX',
#  'FARNDON': 'FARNDON',
#  'FARNHAM,FARNHAM,SURREY"': 'FARNHAM,FARN',
#  'FARNSFIELD': 'FARNSFIELD',
#  'FASLANE': 'FASLANE',
#  'FAULDHOUSE': 'FAULDHOUSE',
#  'FAVERSHAM': 'FAVERSHAM',
#  'FAWLEY,CALSHOT,BLACKFIELD"': 'FAWLEY,CALSH',
#  'FELBRIDGE': 'FELBRIDGE',
#  'FELIXSTOWE': 'FELIXSTOWE',
#  'FELSTED': 'FELSTED',
#  'FELTON': 'FELTON',
#  'FELTWELL': 'FELTWELL',
#  'FENITON': 'FENITON',
#  'FERNDOWN/VERWOOD/WESTMOORS/STIVES': 'FERNDOWN/VER',
#  'FERRYHILL(CHILTONLANE)': 'FERRYHILL(CH',
#  'FFAIRFACHFFAIRFACHCARMS': 'FFAIRFACHFFA',
#  'FILEY': 'FILEY',
#  'FINDERN': 'FINDERN',
#  'FINSTOCK,FINSTOCK,OXON"': 'FINSTOCK,FIN',
#  'FISHBURN': 'FISHBURN',
#  'FISHTOFT': 'FISHTOFT',
#  'FIVEMILETOWN': 'FIVEMILETOWN',
#  'FLAMBOROUGH': 'FLAMBOROUGH',
#  'FLECKNEY': 'FLECKNEY',
#  'FLEET,FLEET,HANTS"': 'FLEET,FLEET,',
#  'FLEETWOODANDBLACKPOOL(FLEETWOODMARSH)': 'FLEETWOODAND',
#  'FLINT': 'FLINT',
#  'FLITWICK': 'FLITWICK',
#  'FLUXTON': 'FLUXTON',
#  'FOCHABERS': 'FOCHABERS',
#  'FOLKTON': 'FOLKTON',
#  'FORD': 'FORD',
#  'FORDINGBRIDGE': 'FORDINGBRIDG',
#  'FORESTROW': 'FORESTROW',
#  'FORFARNEW': 'FORFARNEW',
#  'FORMBY': 'FORMBY',
#  'FORNCETTEND': 'FORNCETTEND',
#  'FORRES': 'FORRES',
#  'FORTHS.T.W.': 'FORTHS.T.W.',
#  'FORTWILLIAMNEW': 'FORTWILLIAMN',
#  'FOWEY': 'FOWEY',
#  'FOXTON': 'FOXTON',
#  'FRAMLINGHAM': 'FRAMLINGHAM',
#  'FRAMPTON': 'FRAMPTON',
#  'FRANKTON': 'FRANKTON',
#  'FRASERBURGH-ABERDEENPFI': 'FRASERBURGH-',
#  'FRITCHLEY': 'FRITCHLEY',
#  'FROGHALL': 'FROGHALL',
#  'FROME': 'FROME',
#  'GAERWEN': 'GAERWEN',
#  'GAINSBOROUGH': 'GAINSBOROUGH',
#  'GALASHIELS': 'GALASHIELS',
#  'GAMLINGAY': 'GAMLINGAY',
#  'GARSTANG': 'GARSTANG',
#  'GARVAGH': 'GARVAGH',
#  'GERRARDSCROSS,GERRARDSCROSS,"': 'GERRARDSCROS',
#  'GILBERDYKE&STADDLETHORPESPS': 'GILBERDYKE&S',
#  'GILFORD': 'GILFORD',
#  'GILLINGHAM': 'GILLINGHAM',
#  'GIRVANS.T.W.': 'GIRVANS.T.W.',
#  'GLASTONBURY': 'GLASTONBURY',
#  'GLAZEBURY': 'GLAZEBURY',
#  'GLEMSFORD': 'GLEMSFORD',
#  'GLENAVY': 'GLENAVY',
#  'GLENEAGLES': 'GLENEAGLES',
#  'GLOSSOP': 'GLOSSOP',
#  'GLOUCESTERNETHERIDGE': 'GLOUCESTERNE',
#  'GODALMING,UNSTEAD,GODALMING,"': 'GODALMING,UN',
#  'GODSTONE': 'GODSTONE',
#  'GOOLE': 'GOOLE',
#  'GOREBRIDGE': 'GOREBRIDGE',
#  'GORING,GORING,OXON"': 'GORING,GORIN',
#  'GOSBERTON': 'GOSBERTON',
#  'GOSPELEND': 'GOSPELEND',
#  'GOWERTON': 'GOWERTON',
#  'GRANGE-OVER-SANDS': 'GRANGE-OVER-',
#  'GRANTHAM': 'GRANTHAM',
#  'GRANTOWNONSPEY': 'GRANTOWNONSP',
#  'GRASSINGTON': 'GRASSINGTON',
#  'GRAVESEND': 'GRAVESEND',
#  'GREATAYTON': 'GREATAYTON',
#  'GREATCHESTERFORD': 'GREATCHESTER',
#  'GREATCORNARD': 'GREATCORNARD',
#  'GREATDUNMOW': 'GREATDUNMOW',
#  'GREATEASTON': 'GREATEASTON',
#  'GREATFINBOROUGH': 'GREATFINBORO',
#  'GREATGLEN': 'GREATGLEN',
#  'GREATTORRINGTON': 'GREATTORRING',
#  'GREATTOTHAM': 'GREATTOTHAM',
#  'GREATWALDINGFIELD': 'GREATWALDING',
#  'GREATWARFORD': 'GREATWARFORD',
#  'GREATWENHAM': 'GREATWENHAM',
#  'GREATWISHFORD': 'GREATWISHFOR',
#  'GREATYARMOUTH(CAISTER)': 'GREATYARMOUT',
#  'GREENFIELD': 'GREENFIELD',
#  'GRENDON': 'GRENDON',
#  'GRESFORD': 'GRESFORD',
#  'GRETNAS.T.W.': 'GRETNAS.T.W.',
#  'GRIMETHORPE': 'GRIMETHORPE',
#  'GRIMSBY': 'GRIMSBY',
#  'GRIMSTEAD': 'GRIMSTEAD',
#  'GRIMSTON': 'GRIMSTON',
#  'GTBARFORD': 'GTBARFORD',
#  'GUARDBRIDGE': 'GUARDBRIDGE',
#  'GUILDFORD,GUILDFORD,SURREY"': 'GUILDFORD,GU',
#  'GUNNISLAKE': 'GUNNISLAKE',
#  'HADDENHAM': 'HADDENHAM',
#  'HADDENHAM(AYLESBURY)': 'HADDENHAM(AY',
#  'HADDINGTON': 'HADDINGTON',
#  'HADLEIGH': 'HADLEIGH',
#  'HADLOW': 'HADLOW',
#  'HAGGERSTONCASTLECARAVANPARK': 'HAGGERSTONCA',
#  'HAILSHAMNORTH': 'HAILSHAMNORT',
#  'HAILSHAMSOUTH': 'HAILSHAMSOUT',
#  'HALESWORTH': 'HALESWORTH',
#  'HALIFAX': 'HALIFAX',
#  'HALSTEAD': 'HALSTEAD',
#  'HALTWHISTLE': 'HALTWHISTLE',
#  'HAMBLETON': 'HAMBLETON',
#  'HAMHILL': 'HAMHILL',
#  'HAMILTONS.T.W.': 'HAMILTONS.T.',
#  'HANSLOPE': 'HANSLOPE',
#  'HARBY': 'HARBY',
#  'HARLESTON': 'HARLESTON',
#  'HARLINGTON': 'HARLINGTON',
#  'HARPENDEN,HARPENDEN,HERTS"': 'HARPENDEN,HA',
#  'HARROGATENORTH': 'HARROGATENOR',
#  'HARROGATESOUTH': 'HARROGATESOU',
#  'HARTHILLS.T.W.': 'HARTHILLS.T.',
#  'HARTLEPOOL': 'HARTLEPOOL',
#  'HARTLEYWINTNEY,HARTLEYWINTNE"': 'HARTLEYWINTN',
#  'HARVINGTON': 'HARVINGTON',
#  'HARWICH': 'HARWICH',
#  'HARWORTH': 'HARWORTH',
#  'HASLEMERE': 'HASLEMERE',
#  'HASLINGFIELD': 'HASLINGFIELD',
#  'HATFIELDHEATH,HATFIELDHEATH,"': 'HATFIELDHEAT',
#  'HATHERSAGE': 'HATHERSAGE',
#  'HAUGHLEY': 'HAUGHLEY',
#  'HAVERFORDWEST': 'HAVERFORDWES',
#  'HAVERHILL': 'HAVERHILL',
#  'HAWICK': 'HAWICK',
#  'HAWKHURSTNORTH': 'HAWKHURSTNOR',
#  'HAXEY': 'HAXEY',
#  'HAYFIELD': 'HAYFIELD',
#  'HAYONWYESEWAGETREATMENTWORKS': 'HAYONWYESEWA',
#  'HAZELGROVE': 'HAZELGROVE',
#  'HEACHAM': 'HEACHAM',
#  'HEADCORN': 'HEADCORN',
#  'HEAGE': 'HEAGE',
#  'HEANOR': 'HEANOR',
#  'HEATHFIELD': 'HEATHFIELD',
#  'HEATHFIELD,HORHAM"': 'HEATHFIELD,H',
#  'HECKINGTON': 'HECKINGTON',
#  'HEDON': 'HEDON',
#  'HELENSBURGHS.T.W.': 'HELENSBURGHS',
#  'HELSBY': 'HELSBY',
#  'HELSTON': 'HELSTON',
#  'HEMINGBROUGH': 'HEMINGBROUGH',
#  'HEMPNALL': 'HEMPNALL',
#  'HENDON': 'HENDON',
#  'HENFIELD': 'HENFIELD',
#  'HENLEY': 'HENLEY',
#  'HERNEBAY': 'HERNEBAY',
#  'HERTFORD': 'HERTFORD',
#  'HESKETHBANK': 'HESKETHBANK',
#  'HESWALLSEWAGETREATMENTWORKS': 'HESWALLSEWAG',
#  'HEXHAM': 'HEXHAM',
#  'HEYFORD': 'HEYFORD',
#  'HIBALDSTOW': 'HIBALDSTOW',
#  'HIGHBENTHAM': 'HIGHBENTHAM',
#  'HIGHLEY': 'HIGHLEY',
#  'HIGHROYD': 'HIGHROYD',
#  'HIGHWORTH,PENTYLANDSLANE,HIG"': 'HIGHWORTH,PE',
#  'HIGHWYCOMBE': 'HIGHWYCOMBE',
#  'HILLHOUSE': 'HILLHOUSE',
#  'HILLTOWN': 'HILLTOWN',
#  'HINCKLEY': 'HINCKLEY',
#  'HINDERWELL': 'HINDERWELL',
#  'HITCHIN': 'HITCHIN',
#  'HIXON': 'HIXON',
#  'HMPLINDHOLME&MOORLAND': 'HMPLINDHOLME',
#  'HODSOCK': 'HODSOCK',
#  'HOLBEACH': 'HOLBEACH',
#  'HOLME': 'HOLME',
#  'HOLMEONSPALDINGMOOR': 'HOLMEONSPALD',
#  'HOLMESCHAPEL': 'HOLMESCHAPEL',
#  'HOLMFIRTH': 'HOLMFIRTH',
#  'HOLMWOOD': 'HOLMWOOD',
#  'HOLSWORTHY': 'HOLSWORTHY',
#  'HOLT': 'HOLT',
#  'HOLTONLECLAY': 'HOLTONLECLAY',
#  'HOLYHEAD': 'HOLYHEAD',
#  'HONEYBOURNE': 'HONEYBOURNE',
#  'HONITON': 'HONITON',
#  'HOOKNORTON,HOOKNORTON,OXON"': 'HOOKNORTON,H',
#  'HOPE': 'HOPE',
#  'HORBLING': 'HORBLING',
#  'HORBURY': 'HORBURY',
#  'HORDENANDPETERLEE': 'HORDENANDPET',
#  'HORLEY': 'HORLEY',
#  'HORNCASTLE': 'HORNCASTLE',
#  'HORNSEA': 'HORNSEA',
#  'HORRABRIDGE': 'HORRABRIDGE',
#  'HORSHAM': 'HORSHAM',
#  'HORSMONDEN,TONBRIDGE,KENT"': 'HORSMONDEN,T',
#  'HORWICH': 'HORWICH',
#  'HOUGHTON-LE-SPRING': 'HOUGHTON-LE-',
#  'HOWDEN': 'HOWDEN',
#  'HOYLAKE(NORTHWIRRAL[MEOLS])': 'HOYLAKE(NORT',
#  'HUDDERSFIELD': 'HUDDERSFIELD',
#  'HULL': 'HULL',
#  'HUNGERFORD,HUNGERFORD,BERKS"': 'HUNGERFORD,H',
#  'HUNMANBY': 'HUNMANBY',
#  'HUNTINGDON': 'HUNTINGDON',
#  'HUNTLY': 'HUNTLY',
#  'HURDCOTT': 'HURDCOTT',
#  'HURLEY': 'HURLEY',
#  'HUTHWAITE': 'HUTHWAITE',
#  'HUYTON': 'HUYTON',
#  'HYDE': 'HYDE',
#  'HYNDBURN': 'HYNDBURN',
#  'HYTHE': 'HYTHE',
#  'IBSTOCK': 'IBSTOCK',
#  'ILCHESTER': 'ILCHESTER',
#  'ILFRACOMBE': 'ILFRACOMBE',
#  'ILKESTON': 'ILKESTON',
#  'ILKLEY': 'ILKLEY',
#  'ILMINSTER': 'ILMINSTER',
#  'IMMINGHAM': 'IMMINGHAM',
#  'INGATESTONE': 'INGATESTONE',
#  'INGLETONETWEFFLUENTFROMLANDTREATMNT': 'INGLETONETWE',
#  'INGOLDISTHORPE': 'INGOLDISTHOR',
#  'INGOLDMELLS': 'INGOLDMELLS',
#  'INSCH': 'INSCH',
#  'INVERCLYDEW.W.T.SERVICE': 'INVERCLYDEW.',
#  'INVERURIE': 'INVERURIE',
#  'INVERURIENEW': 'INVERURIENEW',
#  'IPPLEPEN&TORBRYAN': 'IPPLEPEN&TOR',
#  'IPSWICH': 'IPSWICH',
#  'IRLAM': 'IRLAM',
#  'IRONMILLBAY': 'IRONMILLBAY',
#  'IRVINESTOWN': 'IRVINESTOWN',
#  'ISLEHAM': 'ISLEHAM',
#  'ISLIP': 'ISLIP',
#  'IVER,IVER,BUCKS"': 'IVER,IVER,BU',
#  'IVINGHOE': 'IVINGHOE',
#  'IVYBRIDGE': 'IVYBRIDGE',
#  'IVYDOWNLANEEASTOAKLEY': 'IVYDOWNLANEE',
#  'JAYWICK': 'JAYWICK',
#  'JEDBURGH': 'JEDBURGH',
#  'KEADY': 'KEADY',
#  'KEDINGTON': 'KEDINGTON',
#  'KEELBY': 'KEELBY',
#  'KEEVIL': 'KEEVIL',
#  'KEGWORTH': 'KEGWORTH',
#  'KEIGHLEYMARLEY': 'KEIGHLEYMARL',
#  'KEITH': 'KEITH',
#  'KELLOE': 'KELLOE',
#  'KELSO': 'KELSO',
#  'KEMNAY': 'KEMNAY',
#  'KEMPSEY': 'KEMPSEY',
#  'KENDAL': 'KENDAL',
#  'KENTONANDSTARCROSS': 'KENTONANDSTA',
#  'KESH': 'KESH',
#  'KESSINGLAND': 'KESSINGLAND',
#  'KESWICK': 'KESWICK',
#  'KETTON': 'KETTON',
#  'KEYINGHAM': 'KEYINGHAM',
#  'KEYNSHAM': 'KEYNSHAM',
#  'KEYWORTH': 'KEYWORTH',
#  'KIBWORTH': 'KIBWORTH',
#  'KIDDERMINSTER': 'KIDDERMINSTE',
#  'KIDSGROVE': 'KIDSGROVE',
#  'KIDWELLYWASTEWATERTREATMENTWORKS': 'KIDWELLYWAST',
#  'KILBURN': 'KILBURN',
#  'KILKEEL': 'KILKEEL',
#  'KILLEARN,': 'KILLEARN,',
#  'KILLINCHY': 'KILLINCHY',
#  'KILLINGHALL': 'KILLINGHALL',
#  'KILLYLEAGH': 'KILLYLEAGH',
#  'KILREA': 'KILREA',
#  'KILSBY': 'KILSBY',
#  'KIMBOLTON': 'KIMBOLTON',
#  'KIMPTON': 'KIMPTON',
#  'KINCARDINE': 'KINCARDINE',
#  'KINETON': 'KINETON',
#  'KINGSBRIDGE': 'KINGSBRIDGE',
#  'KINGSCLERE,KINGSCLERE,HANTS"': 'KINGSCLERE,K',
#  'KINGSLEY': 'KINGSLEY',
#  'KINGSLYNN': 'KINGSLYNN',
#  'KINGSSOMBOURNEOUTCSMDATA': 'KINGSSOMBOUR',
#  'KINGSSUTTON,KINGSSUTTON,NOR"': 'KINGSSUTTON,',
#  'KINGSTONBAGPUIZE': 'KINGSTONBAGP',
#  'KINGTONWATERLOOROADKINGTON': 'KINGTONWATER',
#  'KINGUSSIE': 'KINGUSSIE',
#  'KINNEGAR': 'KINNEGAR',
#  'KINNEILKERSE': 'KINNEILKERSE',
#  'KINOULTON': 'KINOULTON',
#  'KINROSS': 'KINROSS',
#  'KINTBURY': 'KINTBURY',
#  'KINVER': 'KINVER',
#  'KIRKBY-IN-ASHFIELD': 'KIRKBY-IN-AS',
#  'KIRKBYLONSDALEHUMUSTANKEFFLUENT': 'KIRKBYLONSDA',
#  'KIRKBYMALZEARD': 'KIRKBYMALZEA',
#  'KIRKBYMOORSIDE': 'KIRKBYMOORSI',
#  'KIRKBYSTEPHEN': 'KIRKBYSTEPHE',
#  'KIRKCALDY': 'KIRKCALDY',
#  'KIRKCONNELS.T.W.': 'KIRKCONNELS.',
#  'KIRKWALLHEADOFWORK': 'KIRKWALLHEAD',
#  'KIRRIEMUIR': 'KIRRIEMUIR',
#  'KIRTONINLINDSEY': 'KIRTONINLIND',
#  'KNARESBOROUGH': 'KNARESBOROUG',
#  'KNIGHTON': 'KNIGHTON',
#  'KNITSLEY': 'KNITSLEY',
#  'KNUTSFORD': 'KNUTSFORD',
#  'L/FRPG': 'L/FRPG',
#  'LACEBY': 'LACEBY',
#  'LADOCKVALLEY': 'LADOCKVALLEY',
#  'LAIGHPARKS.T.W.': 'LAIGHPARKS.T',
#  'LAKENHEATH': 'LAKENHEATH',
#  'LAMPETER': 'LAMPETER',
#  'LANARKS.T.W.': 'LANARKS.T.W.',
#  'LANCASTER(STODDAY)': 'LANCASTER(ST',
#  'LANCHESTER': 'LANCHESTER',
#  'LANGDONBEGELLYPEMBROKESHIRE': 'LANGDONBEGEL',
#  'LANGHOLMS.T.W.': 'LANGHOLMS.T.',
#  'LANGLEY': 'LANGLEY',
#  'LANGPORT': 'LANGPORT',
#  'LANGWITH': 'LANGWITH',
#  'LANNERSTDAY': 'LANNERSTDAY',
#  'LARGSS.T.W.': 'LARGSS.T.W.',
#  'LARNE': 'LARNE',
#  'LATCHINGDON': 'LATCHINGDON',
#  'LAUNCESTON': 'LAUNCESTON',
#  'LAURENCEKIRK': 'LAURENCEKIRK',
#  'LAVANT': 'LAVANT',
#  'LAVENHAMF/E': 'LAVENHAMF/E',
#  'LAVINGTON': 'LAVINGTON',
#  'LAVISTER': 'LAVISTER',
#  'LAWTONGATE': 'LAWTONGATE',
#  'LEATHERHEAD': 'LEATHERHEAD',
#  'LECHLADE,LECHLADE,GLOS"': 'LECHLADE,LEC',
#  'LEDBURY': 'LEDBURY',
#  'LEEDS': 'LEEDS',
#  'LEEDS(KNOSTROP)': 'LEEDS(KNOSTR',
#  'LEEDS(LEMONROYD)': 'LEEDS(LEMONR',
#  'LEEK': 'LEEK',
#  'LEEMINGBAR': 'LEEMINGBAR',
#  'LEICESTER': 'LEICESTER',
#  'LEIGH': 'LEIGH',
#  'LEIGHTONLINSLADE': 'LEIGHTONLINS',
#  'LEISTON': 'LEISTON',
#  'LENHAM': 'LENHAM',
#  'LEOMINSTERSOUTHERNAVENUE': 'LEOMINSTERSO',
#  'LESMAHAGOWS.T.W.': 'LESMAHAGOWS.',
#  'LETCHWORTH': 'LETCHWORTH',
#  'LETHAMWTP': 'LETHAMWTP',
#  'LEVEN': 'LEVEN',
#  'LEVENVALLEY,LEVENMOUTH': 'LEVENVALLEY,',
#  'LEYBURN': 'LEYBURN',
#  'LEYLAND': 'LEYLAND',
#  'LICHFIELD': 'LICHFIELD',
#  'LIDSEY': 'LIDSEY',
#  'LIGHTWATER': 'LIGHTWATER',
#  'LIMAVADY': 'LIMAVADY',
#  'LINCLUDENS.T.W.': 'LINCLUDENS.T',
#  'LINCOLN': 'LINCOLN',
#  'LINGFIELD': 'LINGFIELD',
#  'LINLITHGOW': 'LINLITHGOW',
#  'LINTON': 'LINTON',
#  'LINTONONOUSE': 'LINTONONOUSE',
#  ...}

# %%
#location_clean = location.replace(site_edited)

# %%
#location_clean

# %%
sites1 = swt_data.TreatmentPlant.unique()
s_names1 = []

for site in sites1:
    if len(site) >= 9:
            site= site[:12]
    else:
        site = site
    
    s_names1.append(site)

sites1 = list(sites1)

s_names1 = list(s_names1)

# %%
site_edited1 = dict(zip(sites1, s_names1))

# %%
len(site_edited1)
# Out:
# 595

# %%
site_edited1 = dict(sorted(site_edited1.items()))

# %%
site_edited1
# Out:
# {'ABINGDON': 'ABINGDON',
#  'ACLE': 'ACLE',
#  'ADWICK': 'ADWICK',
#  'AFAN': 'AFAN',
#  'AINSDALE': 'AINSDALE',
#  'ALCONBURY': 'ALCONBURY',
#  'ALDERLEYEDGE': 'ALDERLEYEDGE',
#  'ALDERMASTON': 'ALDERMASTON',
#  'ALDERSHOT': 'ALDERSHOT',
#  'ALDWARKE': 'ALDWARKE',
#  'ALFORD': 'ALFORD',
#  'ALFRETON': 'ALFRETON',
#  'ALSAGER': 'ALSAGER',
#  'ALTON': 'ALTON',
#  'ALTRINCHAM': 'ALTRINCHAM',
#  'ALVECHURCH': 'ALVECHURCH',
#  'AMBERGATE': 'AMBERGATE',
#  'AMBLESIDE': 'AMBLESIDE',
#  'ANCASTER': 'ANCASTER',
#  'AOODBANK': 'AOODBANK',
#  'APPLETON': 'APPLETON',
#  'ARBORFIELD': 'ARBORFIELD',
#  'ARMTHORPE': 'ARMTHORPE',
#  'ASCOT': 'ASCOT',
#  'ASHFORD': 'ASHFORD',
#  'ASHTON': 'ASHTON',
#  'ASHVALE': 'ASHVALE',
#  'ASPATRIA': 'ASPATRIA',
#  'ATTLEBOROUGH': 'ATTLEBOROUGH',
#  'AYCLIFFE': 'AYCLIFFE',
#  'AYLESBURY': 'AYLESBURY',
#  'AYLESFORD': 'AYLESFORD',
#  'AYLSHAM': 'AYLSHAM',
#  'BALBY': 'BALBY',
#  'BALSALLCOMMON': 'BALSALLCOMMO',
#  'BARLESTONE': 'BARLESTONE',
#  'BARNHURST': 'BARNHURST',
#  'BARNOLDSWICK': 'BARNOLDSWICK',
#  'BARROW': 'BARROW',
#  'BARTON': 'BARTON',
#  'BARTONLECLAY': 'BARTONLECLAY',
#  'BARWICK': 'BARWICK',
#  'BASINGSTOKE': 'BASINGSTOKE',
#  'BASSINGBOURN': 'BASSINGBOURN',
#  'BATTLE': 'BATTLE',
#  'BECKTON': 'BECKTON',
#  'BEDDINGTON': 'BEDDINGTON',
#  'BEDWORTH': 'BEDWORTH',
#  'BENHALL': 'BENHALL',
#  'BENSON': 'BENSON',
#  'BENTLEY': 'BENTLEY',
#  'BERKHAMSTED': 'BERKHAMSTED',
#  'BETHERSDEN': 'BETHERSDEN',
#  'BEVERLEY': 'BEVERLEY',
#  'BICESTER': 'BICESTER',
#  'BIDBOROUGH': 'BIDBOROUGH',
#  'BIDDENDEN': 'BIDDENDEN',
#  'BIDDULPH': 'BIDDULPH',
#  'BILLINGHURST': 'BILLINGHURST',
#  'BILSTHORPE': 'BILSTHORPE',
#  'BIRTLEY': 'BIRTLEY',
#  'BISHOPSSTORTFORD': 'BISHOPSSTORT',
#  'BLACKBIRDS': 'BLACKBIRDS',
#  'BLACKBURNMEADOWS': 'BLACKBURNMEA',
#  'BLACKMINSTER': 'BLACKMINSTER',
#  'BLAGDON': 'BLAGDON',
#  'BLYTON': 'BLYTON',
#  'BOCKING': 'BOCKING',
#  'BODMIN': 'BODMIN',
#  'BOLTON': 'BOLTON',
#  'BOMEREHEATH': 'BOMEREHEATH',
#  'BORDON': 'BORDON',
#  'BOTTESFORD': 'BOTTESFORD',
#  'BOTTISHAM': 'BOTTISHAM',
#  'BOURNE': 'BOURNE',
#  'BOURTON': 'BOURTON',
#  'BOWBURN': 'BOWBURN',
#  'BOWERHILL': 'BOWERHILL',
#  'BRACKLEYNEW': 'BRACKLEYNEW',
#  'BRACKNELL': 'BRACKNELL',
#  'BRAINTREE': 'BRAINTREE',
#  'BRAITHWELL': 'BRAITHWELL',
#  'BRANTON': 'BRANTON',
#  'BRENTWOOD': 'BRENTWOOD',
#  'BRIGG': 'BRIGG',
#  'BRIXWORTH': 'BRIXWORTH',
#  'BROADHOLME': 'BROADHOLME',
#  'BROADWAY': 'BROADWAY',
#  'BROMSGROVE': 'BROMSGROVE',
#  'BROUGHTON': 'BROUGHTON',
#  'BULKINGTON': 'BULKINGTON',
#  'BUNGAY': 'BUNGAY',
#  'BUNTINGFORD': 'BUNTINGFORD',
#  'BURGHFIELD': 'BURGHFIELD',
#  'BURNLEY': 'BURNLEY',
#  'BURNTWOOD': 'BURNTWOOD',
#  'BURSCOUGH': 'BURSCOUGH',
#  'BURSTOW': 'BURSTOW',
#  'BURTONOW': 'BURTONOW',
#  'BURWELL': 'BURWELL',
#  'BURY': 'BURY',
#  'BYFIELD': 'BYFIELD',
#  'CALLINGTON': 'CALLINGTON',
#  'CALVERTON': 'CALVERTON',
#  'CAMBERLEY': 'CAMBERLEY',
#  'CAMBRIDGE': 'CAMBRIDGE',
#  'CANNOCK': 'CANNOCK',
#  'CANWICK': 'CANWICK',
#  'CARLETON': 'CARLETON',
#  'CARLISLE': 'CARLISLE',
#  'CASTLECARY': 'CASTLECARY',
#  'CASTLEDONINGTON': 'CASTLEDONING',
#  'CAWTHORNE': 'CAWTHORNE',
#  'CAYTHORPE': 'CAYTHORPE',
#  'CHADLINGTON': 'CHADLINGTON',
#  'CHALGROVE': 'CHALGROVE',
#  'CHALTON': 'CHALTON',
#  'CHANTRY': 'CHANTRY',
#  'CHAPELENLEFRITH': 'CHAPELENLEFR',
#  'CHEDBURGH': 'CHEDBURGH',
#  'CHERRYBURTON': 'CHERRYBURTON',
#  'CHERTSEY': 'CHERTSEY',
#  'CHESHAM': 'CHESHAM',
#  'CHESTERLESTREET': 'CHESTERLESTR',
#  'CHEWSTOKE': 'CHEWSTOKE',
#  'CHIEVELEY': 'CHIEVELEY',
#  'CHILTON': 'CHILTON',
#  'CHILTONW': 'CHILTONW',
#  'CHINNOR': 'CHINNOR',
#  'CHOBHAM': 'CHOBHAM',
#  'CHOLSEY': 'CHOLSEY',
#  'CHORLEY': 'CHORLEY',
#  'CHURCHHANBOROUGH': 'CHURCHHANBOR',
#  'CHURCHSTRETTON': 'CHURCHSTRETT',
#  'CIRENCESTER': 'CIRENCESTER',
#  'CLAVERING': 'CLAVERING',
#  'CLAYCROSS': 'CLAYCROSS',
#  'CLAYMILLS': 'CLAYMILLS',
#  'CLAYTONWEST': 'CLAYTONWEST',
#  'CLEATOR': 'CLEATOR',
#  'CLITHEROE': 'CLITHEROE',
#  'CLIVE': 'CLIVE',
#  'CLOWNE': 'CLOWNE',
#  'COALEY': 'COALEY',
#  'COCKERMOUTH': 'COCKERMOUTH',
#  'COGGESHALL': 'COGGESHALL',
#  'COLWALL': 'COLWALL',
#  'CONEYWESTON': 'CONEYWESTON',
#  'CONGLETON': 'CONGLETON',
#  'CONSETT': 'CONSETT',
#  'CORBY': 'CORBY',
#  'COTONPARK': 'COTONPARK',
#  'COTTESMORE': 'COTTESMORE',
#  'COTTONVALLEY': 'COTTONVALLEY',
#  'CRANBROOK': 'CRANBROOK',
#  'CRANLEIGH': 'CRANLEIGH',
#  'CRAWLEY': 'CRAWLEY',
#  'CRESWELL': 'CRESWELL',
#  'CREWE': 'CREWE',
#  'CREWKERNEE': 'CREWKERNEE',
#  'CROOKHALL': 'CROOKHALL',
#  'CROSCOMBE': 'CROSCOMBE',
#  'CROWBOROUGH': 'CROWBOROUGH',
#  'CROWLE': 'CROWLE',
#  'CROXTONKERRIAL': 'CROXTONKERRI',
#  'CUDWORTH': 'CUDWORTH',
#  'CULHAM': 'CULHAM',
#  'DARLEY': 'DARLEY',
#  'DAVYHULME': 'DAVYHULME',
#  'DEEPINGS': 'DEEPINGS',
#  'DERBY': 'DERBY',
#  'DEREHAM': 'DEREHAM',
#  'DEVIZES': 'DEVIZES',
#  'DIDCOT': 'DIDCOT',
#  'DISS': 'DISS',
#  'DODDINGHURST': 'DODDINGHURST',
#  'DONISTHORPE': 'DONISTHORPE',
#  'DORCHESTER': 'DORCHESTER',
#  'DRIFFIELD': 'DRIFFIELD',
#  'DROITWICH': 'DROITWICH',
#  'DRONFIELD': 'DRONFIELD',
#  'DUKINFIELD': 'DUKINFIELD',
#  'DULLINGHAM': 'DULLINGHAM',
#  'DUNHOLME': 'DUNHOLME',
#  'DUNSTABLE': 'DUNSTABLE',
#  'DUXFORD': 'DUXFORD',
#  'EASINGWOLD': 'EASINGWOLD',
#  'EASTBRIDGFORD': 'EASTBRIDGFOR',
#  'EASTHAMPSTEADPK': 'EASTHAMPSTEA',
#  'EASTHARLING': 'EASTHARLING',
#  'EASTMARKHAM': 'EASTMARKHAM',
#  'ECCLES': 'ECCLES',
#  'EDENBRIDGE': 'EDENBRIDGE',
#  'EDENVALEEASTGRINSTEAD': 'EDENVALEEAST',
#  'EDGMOND': 'EDGMOND',
#  'EDWINSTOWE': 'EDWINSTOWE',
#  'EGGBOROUGH': 'EGGBOROUGH',
#  'EGRINSTEAD': 'EGRINSTEAD',
#  'EPPING': 'EPPING',
#  'ESHWINNING': 'ESHWINNING',
#  'ETWALL': 'ETWALL',
#  'EVERCREECH': 'EVERCREECH',
#  'FAILSWORTH': 'FAILSWORTH',
#  'FARNHAM': 'FARNHAM',
#  'FARNSFIELD': 'FARNSFIELD',
#  'FAZAKERLEY': 'FAZAKERLEY',
#  'FELBRIDGE': 'FELBRIDGE',
#  'FERNHURST': 'FERNHURST',
#  'FINDERN': 'FINDERN',
#  'FINSTOCK': 'FINSTOCK',
#  'FLEET': 'FLEET',
#  'FLITWICK': 'FLITWICK',
#  'FORMBY': 'FORMBY',
#  'FORNHAM': 'FORNHAM',
#  'FOXTONCAMBS': 'FOXTONCAMBS',
#  'FRADDON': 'FRADDON',
#  'FRAMLINGHAM': 'FRAMLINGHAM',
#  'FRAMPTON': 'FRAMPTON',
#  'FROME': 'FROME',
#  'GARFORTH': 'GARFORTH',
#  'GARSTANG': 'GARSTANG',
#  'GERRARDSCROSS': 'GERRARDSCROS',
#  'GLOSSOP': 'GLOSSOP',
#  'GODDARDSGREEN': 'GODDARDSGREE',
#  'GOOSEBECK': 'GOOSEBECK',
#  'GREATAYTON': 'GREATAYTON',
#  'GREATBILLING': 'GREATBILLING',
#  'GREATTOTHAM': 'GREATTOTHAM',
#  'GREATWORTH': 'GREATWORTH',
#  'GRENDON': 'GRENDON',
#  'GRESFORD': 'GRESFORD',
#  'GTGADDESDEN': 'GTGADDESDEN',
#  'GTWARFORD': 'GTWARFORD',
#  'GWENNAP(LANNERSTDAY)': 'GWENNAP(LANN',
#  'HADDENHAM': 'HADDENHAM',
#  'HAILSHAMNORTH': 'HAILSHAMNORT',
#  'HAILSHAMSOUTH': 'HAILSHAMSOUT',
#  'HALSTEADLANGLEY': 'HALSTEADLANG',
#  'HANSLOPE': 'HANSLOPE',
#  'HARESTOCK': 'HARESTOCK',
#  'HARPENDEN': 'HARPENDEN',
#  'HARTLEYWINTNEY': 'HARTLEYWINTN',
#  'HARVINGTON': 'HARVINGTON',
#  'HATFIELDHEATH': 'HATFIELDHEAT',
#  'HAVERHILL': 'HAVERHILL',
#  'HAYDEN': 'HAYDEN',
#  'HAZELGROVE': 'HAZELGROVE',
#  'HEACHAM': 'HEACHAM',
#  'HEAGE': 'HEAGE',
#  'HEANOR': 'HEANOR',
#  'HELSTON': 'HELSTON',
#  'HEMPNALL': 'HEMPNALL',
#  'HENLEY': 'HENLEY',
#  'HIBALDSTOW': 'HIBALDSTOW',
#  'HIGHWORTH': 'HIGHWORTH',
#  'HILLAM': 'HILLAM',
#  'HILLHOUSE': 'HILLHOUSE',
#  'HINCKLEY': 'HINCKLEY',
#  'HITCHIN': 'HITCHIN',
#  'HIXON': 'HIXON',
#  'HOCKFORD': 'HOCKFORD',
#  'HODSOCK': 'HODSOCK',
#  'HODTHORPE': 'HODTHORPE',
#  'HOGSMILL': 'HOGSMILL',
#  'HOGSMILLB': 'HOGSMILLB',
#  'HOLBEACH': 'HOLBEACH',
#  'HOLLOWELL': 'HOLLOWELL',
#  'HOLMWOOD': 'HOLMWOOD',
#  'HOLSWORTHY(DERRITON)': 'HOLSWORTHY(D',
#  'HONEYBOURNE': 'HONEYBOURNE',
#  'HORNCASTLE': 'HORNCASTLE',
#  'HORNTON': 'HORNTON',
#  'HORSHAMNEW': 'HORSHAMNEW',
#  'HORSMONDEN': 'HORSMONDEN',
#  'HORWICH': 'HORWICH',
#  'HOWDON': 'HOWDON',
#  'HUDDERSFIELD': 'HUDDERSFIELD',
#  'HUDDERSFIELDA': 'HUDDERSFIELD',
#  'HURLEY': 'HURLEY',
#  'HUSTLEDOWN': 'HUSTLEDOWN',
#  'HUYTON': 'HUYTON',
#  'HYDE': 'HYDE',
#  'HYNDBURN': 'HYNDBURN',
#  'IBSTOCK': 'IBSTOCK',
#  'ICKLESHAM': 'ICKLESHAM',
#  'ILCHESTER': 'ILCHESTER',
#  'ILKESTON': 'ILKESTON',
#  'ILMINSTER': 'ILMINSTER',
#  'INGOLDISTHORPE': 'INGOLDISTHOR',
#  'IRLAM': 'IRLAM',
#  'ISLEHAM': 'ISLEHAM',
#  'IVERNORTH': 'IVERNORTH',
#  'IWERNEMINSTER': 'IWERNEMINSTE',
#  'KEELBY': 'KEELBY',
#  'KELLOE': 'KELLOE',
#  'KENDAL': 'KENDAL',
#  'KESWICK': 'KESWICK',
#  'KEYNSHAM': 'KEYNSHAM',
#  'KIBWORTH': 'KIBWORTH',
#  'KIDDERMINSTER': 'KIDDERMINSTE',
#  'KILSBY': 'KILSBY',
#  'KINETON': 'KINETON',
#  'KINGSCLERE': 'KINGSCLERE',
#  'KINGSSUTTON': 'KINGSSUTTON',
#  'KINSON': 'KINSON',
#  'KIRKBY': 'KIRKBY',
#  'KIRTONINLINDSEY': 'KIRTONINLIND',
#  'KNARESBOROUGH': 'KNARESBOROUG',
#  'KNITSLEY': 'KNITSLEY',
#  'KNOSTROP': 'KNOSTROP',
#  'KNUTSFORD': 'KNUTSFORD',
#  'LACEBY': 'LACEBY',
#  'LANCHESTER': 'LANCHESTER',
#  'LEADENHAM': 'LEADENHAM',
#  'LEEK': 'LEEK',
#  'LEIGH': 'LEIGH',
#  'LEMONROYD': 'LEMONROYD',
#  'LETCHWORTH': 'LETCHWORTH',
#  'LEVEN': 'LEVEN',
#  'LEYBURN': 'LEYBURN',
#  'LEYLAND': 'LEYLAND',
#  'LIDSEY': 'LIDSEY',
#  'LIGHTWATER': 'LIGHTWATER',
#  'LINCOLN': 'LINCOLN',
#  'LISKEARD(LODGEHILL)': 'LISKEARD(LOD',
#  'LLANGEFNI': 'LLANGEFNI',
#  'LOGGERHEADS': 'LOGGERHEADS',
#  'LONGHOPE': 'LONGHOPE',
#  'LONGSTRATTON': 'LONGSTRATTON',
#  'LOOE': 'LOOE',
#  'LOUGHBOROUGH': 'LOUGHBOROUGH',
#  'LOUTH': 'LOUTH',
#  'LOWERGORNAL': 'LOWERGORNAL',
#  'LUNDWOOD': 'LUNDWOOD',
#  'LUTON': 'LUTON',
#  'LYDD': 'LYDD',
#  'LYNDHURST': 'LYNDHURST',
#  'MABLETHORPE': 'MABLETHORPE',
#  'MAIDENHEAD': 'MAIDENHEAD',
#  'MALTBY': 'MALTBY',
#  'MANSFIELD': 'MANSFIELD',
#  'MAPLELODGE': 'MAPLELODGE',
#  'MARCHINGTON': 'MARCHINGTON',
#  'MAREHAY': 'MAREHAY',
#  'MARKETHARBOROUGH': 'MARKETHARBOR',
#  'MARKETRASEN': 'MARKETRASEN',
#  'MARKETWEIGHTON': 'MARKETWEIGHT',
#  'MARLOW': 'MARLOW',
#  'MARSTONGRANTHAM': 'MARSTONGRANT',
#  'MARSTONMORETAINE': 'MARSTONMORET',
#  'MARTOCK': 'MARTOCK',
#  'MEARE': 'MEARE',
#  'MELBOURN': 'MELBOURN',
#  'MELBOURNE': 'MELBOURNE',
#  'MELBOURNEYW': 'MELBOURNEYW',
#  'MELTHAM': 'MELTHAM',
#  'MELTONMOWBRAY': 'MELTONMOWBRA',
#  'MENAGWINS(STAUSTELL)': 'MENAGWINS(ST',
#  'MERIDEN': 'MERIDEN',
#  'MERRIOTT': 'MERRIOTT',
#  'MERSTHAM': 'MERSTHAM',
#  'MIDDLETONCHENEY': 'MIDDLETONCHE',
#  'MIDDLEWICH': 'MIDDLEWICH',
#  'MILLGREEN': 'MILLGREEN',
#  'MILTON': 'MILTON',
#  'MILTONUNDERWYCHWOOD': 'MILTONUNDERW',
#  'MINWORTH': 'MINWORTH',
#  'MOBBERLEY': 'MOBBERLEY',
#  'MORETONINMARSH': 'MORETONINMAR',
#  'MOSSLEY': 'MOSSLEY',
#  'NAFFERTON': 'NAFFERTON',
#  'NANTWICH': 'NANTWICH',
#  'NEAVESLANE': 'NEAVESLANE',
#  'NEILEY': 'NEILEY',
#  'NETTLEHAM': 'NETTLEHAM',
#  'NEWBURY': 'NEWBURY',
#  'NEWBURYLANECUCKFIELD': 'NEWBURYLANEC',
#  'NEWMARKET': 'NEWMARKET',
#  'NEWPORT': 'NEWPORT',
#  'NEWTHORPE': 'NEWTHORPE',
#  'NORMANTON': 'NORMANTON',
#  'NORTHFAL': 'NORTHFAL',
#  'NORTHIAM': 'NORTHIAM',
#  'NORTHWHEATLEY': 'NORTHWHEATLE',
#  'NORTHWICH': 'NORTHWICH',
#  'NORTONJUXTA': 'NORTONJUXTA',
#  'NUNEATON': 'NUNEATON',
#  'OADBY': 'OADBY',
#  'OLDBUCKENHAM': 'OLDBUCKENHAM',
#  'OLDHAM': 'OLDHAM',
#  'OLDHURST': 'OLDHURST',
#  'OSWESTRY': 'OSWESTRY',
#  'OVER': 'OVER',
#  'OVERSEAL': 'OVERSEAL',
#  'OXENHOPE': 'OXENHOPE',
#  'OXTED': 'OXTED',
#  'PADDOCKWOOD': 'PADDOCKWOOD',
#  'PANGBOURNE': 'PANGBOURNE',
#  'PAPWORTHEVERARD': 'PAPWORTHEVER',
#  'PARKROADHANDCROSS': 'PARKROADHAND',
#  'PATELEYBRIDGE': 'PATELEYBRIDG',
#  'PEGSWOOD': 'PEGSWOOD',
#  'PELYNT': 'PELYNT',
#  'PEMBURY': 'PEMBURY',
#  'PENRITH': 'PENRITH',
#  'PENYBONT': 'PENYBONT',
#  'PICKERING': 'PICKERING',
#  'PINXTON': 'PINXTON',
#  'PITTINGTON': 'PITTINGTON',
#  'PITYME': 'PITYME',
#  'POCKLINGTON': 'POCKLINGTON',
#  'POTTON': 'POTTON',
#  'PRISBOROUGH': 'PRISBOROUGH',
#  'PURTON': 'PURTON',
#  'PYE': 'PYE',
#  'RACKHEATH': 'RACKHEATH',
#  'RAINWORTH': 'RAINWORTH',
#  'RAMPTON': 'RAMPTON',
#  'RAMSEY': 'RAMSEY',
#  'RATFYN': 'RATFYN',
#  'RAUNDS': 'RAUNDS',
#  'RAWCLIFFEGOOLE': 'RAWCLIFFEGOO',
#  'RAWCLIFFEYORK': 'RAWCLIFFEYOR',
#  'RAYHALL': 'RAYHALL',
#  'RAYLEIGH': 'RAYLEIGH',
#  'READING': 'READING',
#  'REDDITCH': 'REDDITCH',
#  'REDLYNCH': 'REDLYNCH',
#  'REIGATE': 'REIGATE',
#  'RENISHAW': 'RENISHAW',
#  'RINGWOOD': 'RINGWOOD',
#  'RIPLEY': 'RIPLEY',
#  'RIPLEYTW': 'RIPLEYTW',
#  'RIPPONDEN': 'RIPPONDEN',
#  'ROBERTSBRIDGE': 'ROBERTSBRIDG',
#  'ROCHDALE': 'ROCHDALE',
#  'RODBOURNE': 'RODBOURNE',
#  'ROSSENDALE': 'ROSSENDALE',
#  'ROUNDHILL': 'ROUNDHILL',
#  'ROYALWOOTTONBASSETT': 'ROYALWOOTTON',
#  'ROYSTON': 'ROYSTON',
#  'RYEMEADS': 'RYEMEADS',
#  'SADDLEWORTH': 'SADDLEWORTH',
#  'SALFORD': 'SALFORD',
#  'SALISBURY': 'SALISBURY',
#  'SALTFORD': 'SALTFORD',
#  'SANDALL': 'SANDALL',
#  'SANDBACH': 'SANDBACH',
#  'SANDFORD': 'SANDFORD',
#  'SANDHURST': 'SANDHURST',
#  'SANDHURSTTW': 'SANDHURSTTW',
#  'SAWTRY': 'SAWTRY',
#  'SEAMER': 'SEAMER',
#  'SEDGEFIELD': 'SEDGEFIELD',
#  'SEDGELETCH': 'SEDGELETCH',
#  'SHAMLEYGREEN': 'SHAMLEYGREEN',
#  'SHENFIELD': 'SHENFIELD',
#  'SHEPTONMALLET': 'SHEPTONMALLE',
#  'SHERBORNESTJOHN': 'SHERBORNESTJ',
#  'SHERBURN': 'SHERBURN',
#  'SHERBURNINELMET': 'SHERBURNINEL',
#  'SHILLINGTON': 'SHILLINGTON',
#  'SHIREBROOK': 'SHIREBROOK',
#  'SIDLESHAM': 'SIDLESHAM',
#  'SILCHESTER': 'SILCHESTER',
#  'SISLAND(LODDON)': 'SISLAND(LODD',
#  'SKEGBY': 'SKEGBY',
#  'SKELLINGTHORPE': 'SKELLINGTHOR',
#  'SKELMERSDALE': 'SKELMERSDALE',
#  'SLEAFORD': 'SLEAFORD',
#  'SLINGSBY': 'SLINGSBY',
#  'SLOUGH': 'SLOUGH',
#  'SMALLEYBIGHT': 'SMALLEYBIGHT',
#  'SNARESTONE': 'SNARESTONE',
#  'SNITTERFIELD': 'SNITTERFIELD',
#  'SOHAM': 'SOHAM',
#  'SOMERTON': 'SOMERTON',
#  'SOUTHELMSALL': 'SOUTHELMSALL',
#  'SOUTHHYKEHAM': 'SOUTHHYKEHAM',
#  'SOUTHNORMANTON': 'SOUTHNORMANT',
#  'SPARKFORD': 'SPARKFORD',
#  'SPERNAL': 'SPERNAL',
#  'STAMFORD': 'STAMFORD',
#  'STAMFORDMD': 'STAMFORDMD',
#  'STANDON': 'STANDON',
#  'STANFORDRIVERS': 'STANFORDRIVE',
#  'STANLEYDOWNTON': 'STANLEYDOWNT',
#  'STANSTEADMOUNTFITCHET': 'STANSTEADMOU',
#  'STANTON': 'STANTON',
#  'STANTONAW': 'STANTONAW',
#  'STANTONHARCOURT': 'STANTONHARCO',
#  'STAPLEFORD': 'STAPLEFORD',
#  'STCOLUMB': 'STCOLUMB',
#  'STEYNING': 'STEYNING',
#  'STHELENS': 'STHELENS',
#  'STIVES': 'STIVES',
#  'STOCKPORT': 'STOCKPORT',
#  'STOKEBARDOLPH': 'STOKEBARDOLP',
#  'STOKEHEATH': 'STOKEHEATH',
#  'STOKEPRIOR': 'STOKEPRIOR',
#  'STOKESLEY': 'STOKESLEY',
#  'STOWMARKET': 'STOWMARKET',
#  'STRADISHALL(HMPHIGHPOINT)': 'STRADISHALL(',
#  'STRONGFORD': 'STRONGFORD',
#  'STUBBSLA(BREDE)': 'STUBBSLA(BRE',
#  'SUDBURY': 'SUDBURY',
#  'SUMMERLA(PAGHAM)': 'SUMMERLA(PAG',
#  'SUTTONBONINGTON': 'SUTTONBONING',
#  'SUTTONBP': 'SUTTONBP',
#  'SUTTONVALENCE': 'SUTTONVALENC',
#  'SWANWICK': 'SWANWICK',
#  'SWARDESTON': 'SWARDESTON',
#  'SWINESHEAD': 'SWINESHEAD',
#  'TANGMERE': 'TANGMERE',
#  'TARVIN': 'TARVIN',
#  'THAME': 'THAME',
#  'THERFIELD': 'THERFIELD',
#  'THEYDON': 'THEYDON',
#  'THINGLEY': 'THINGLEY',
#  'THORPESATCHVILLE': 'THORPESATCHV',
#  'THURSTON': 'THURSTON',
#  'TICKNALL': 'TICKNALL',
#  'TIPTREE': 'TIPTREE',
#  'TONBRIDGE': 'TONBRIDGE',
#  'TOTON': 'TOTON',
#  'TOWLAW': 'TOWLAW',
#  'TRING': 'TRING',
#  'TUDDENHAM': 'TUDDENHAM',
#  'TUDHOEMILL': 'TUDHOEMILL',
#  'TUNBRIDGES': 'TUNBRIDGES',
#  'TUNBRIDGEWELLSNORTH': 'TUNBRIDGEWEL',
#  'TYLDESLEY': 'TYLDESLEY',
#  'UCKFIELD': 'UCKFIELD',
#  'ULCEBY': 'ULCEBY',
#  'UPMINSTER(BURYFM)': 'UPMINSTER(BU',
#  'UPPINGHAM': 'UPPINGHAM',
#  'UTTONSDROVE': 'UTTONSDROVE',
#  'VINESCROSS': 'VINESCROSS',
#  'WADHURST': 'WADHURST',
#  'WADWORTH': 'WADWORTH',
#  'WALTHAMOW': 'WALTHAMOW',
#  'WANLIP': 'WANLIP',
#  'WANTAGE': 'WANTAGE',
#  'WARGRAVE': 'WARGRAVE',
#  'WARMINSTER': 'WARMINSTER',
#  'WARMSWORTH': 'WARMSWORTH',
#  'WARTON': 'WARTON',
#  'WARWICK': 'WARWICK',
#  'WASHWATER': 'WASHWATER',
#  'WATERBEACH': 'WATERBEACH',
#  'WATHONDEARNE': 'WATHONDEARNE',
#  'WATLINGTON': 'WATLINGTON',
#  'WATTON': 'WATTON',
#  'WELLS': 'WELLS',
#  'WEOODBROOK': 'WEOODBROOK',
#  'WESTBERE': 'WESTBERE',
#  'WESTFIELD': 'WESTFIELD',
#  'WETHERSFIELD': 'WETHERSFIELD',
#  'WEYBRIDGE': 'WEYBRIDGE',
#  'WHALEYBRIDGE': 'WHALEYBRIDGE',
#  'WHETSTONE': 'WHETSTONE',
#  'WHITCHURCH': 'WHITCHURCH',
#  'WHITEPARISH': 'WHITEPARISH',
#  'WHITEWALTHAM': 'WHITEWALTHAM',
#  'WHITLINGHAM(NORWICH)': 'WHITLINGHAM(',
#  'WHITWELL': 'WHITWELL',
#  'WIDNES': 'WIDNES',
#  'WIGAN': 'WIGAN',
#  'WIGSTON': 'WIGSTON',
#  'WIGTON': 'WIGTON',
#  'WILBURTON': 'WILBURTON',
#  'WILLOUGHTON': 'WILLOUGHTON',
#  'WILMSLOW': 'WILMSLOW',
#  'WINDERMERE': 'WINDERMERE',
#  'WINGHAM': 'WINGHAM',
#  'WINKLEIGH': 'WINKLEIGH',
#  'WINSFORD': 'WINSFORD',
#  'WISLEY': 'WISLEY',
#  'WITCHAM': 'WITCHAM',
#  'WITCHFORD': 'WITCHFORD',
#  'WITNEY': 'WITNEY',
#  'WOKING': 'WOKING',
#  'WOKINGHAM': 'WOKINGHAM',
#  'WOMBWELL': 'WOMBWELL',
#  'WOODHALLSPA': 'WOODHALLSPA',
#  'WOODSETTS': 'WOODSETTS',
#  'WOOLER': 'WOOLER',
#  'WOOLSTONE': 'WOOLSTONE',
#  'WOOLTON': 'WOOLTON',
#  'WORKSOP(MANTON)': 'WORKSOP(MANT',
#  'WORMINGHALL': 'WORMINGHALL',
#  'WORSLEY': 'WORSLEY',
#  'WORTHINGTON': 'WORTHINGTON',
#  'WYMONDHAM': 'WYMONDHAM',
#  'YADDLETHORPE': 'YADDLETHORPE'}

# %%
type(sites1)
# Out:
# list

# %%
sites.sort()
s_names.sort()
sites1.sort()
s_names1.sort()

# %%
#print(sites)

# %%
#Dataframe of the Treatmentplants location from the two datasets

treatment_locations = pd.DataFrame({'SWT_main' : pd.Series(sites1),
 'SWT_edited': pd.Series(s_names1),
 'mapdata_main': pd.Series(sites), 'mapdata_edited': pd.Series(s_names)})

# %%
treatment_locations['match'] = pd.Series([i for i in s_names1 if any(j in i for j in s_names)])

# %%
treatment_locations
# Out:
#       SWT_main SWT_edited                 mapdata_main mapdata_edited  \
# 0     ABINGDON   ABINGDON  ABERBAIDENBEHINDHOPYARDFARM   ABERBAIDENBE
# 1         ACLE       ACLE                    ABERFELDY      ABERFELDY
# 2       ADWICK     ADWICK                  ABERGAVENNY    ABERGAVENNY
# 3         AFAN       AFAN                     ABERYYTH       ABERYYTH
# 4     AINSDALE   AINSDALE                     ABINGDON       ABINGDON
# ...        ...        ...                          ...            ...
# 1855       NaN        NaN                      YEOFORD        YEOFORD
# 1856       NaN        NaN                       YEOVIL         YEOVIL
# 1857       NaN        NaN                 YORK(NABURN)   YORK(NABURN)
# 1858       NaN        NaN       YORK(NORTH)(RAWCLIFFE)   YORK(NORTH)(
# 1859       NaN        NaN     YSTRADGYNLAISOFFWINDROAD   YSTRADGYNLAI
#
#           match
# 0      ABINGDON
# 1          ACLE
# 2        ADWICK
# 3      AINSDALE
# 4     ALCONBURY
# ...         ...
# 1855        NaN
# 1856        NaN
# 1857        NaN
# 1858        NaN
# 1859        NaN
#
# [1860 rows x 5 columns]

# %%
len(treatment_locations['SWT_edited'])
# Out:
# 1860

# %%
match = list([i for i in s_names1 if any(j in i for j in s_names)])

# %%
match
# Out:
# ['ABINGDON',
#  'ACLE',
#  'ADWICK',
#  'AINSDALE',
#  'ALCONBURY',
#  'ALDERLEYEDGE',
#  'ALFORD',
#  'ALFRETON',
#  'ALSAGER',
#  'ALTON',
#  'ALTRINCHAM',
#  'ALVECHURCH',
#  'AMBERGATE',
#  'AMBLESIDE',
#  'AOODBANK',
#  'ARMTHORPE',
#  'ASCOT',
#  'ASHFORD',
#  'ASHTON',
#  'ASPATRIA',
#  'ATTLEBOROUGH',
#  'AYLESBURY',
#  'AYLESFORD',
#  'AYLSHAM',
#  'BALBY',
#  'BALSALLCOMMO',
#  'BARLESTONE',
#  'BARNOLDSWICK',
#  'BARTON',
#  'BARTONLECLAY',
#  'BARWICK',
#  'BASINGSTOKE',
#  'BASSINGBOURN',
#  'BEDWORTH',
#  'BENHALL',
#  'BENTLEY',
#  'BEVERLEY',
#  'BIDBOROUGH',
#  'BIDDENDEN',
#  'BIDDULPH',
#  'BILSTHORPE',
#  'BIRTLEY',
#  'BISHOPSSTORT',
#  'BLACKBURNMEA',
#  'BLACKMINSTER',
#  'BOCKING',
#  'BOLTON',
#  'BOMEREHEATH',
#  'BOTTESFORD',
#  'BOTTISHAM',
#  'BOURNE',
#  'BOWBURN',
#  'BOWERHILL',
#  'BRACKLEYNEW',
#  'BRAINTREE',
#  'BRANTON',
#  'BRIGG',
#  'BRIXWORTH',
#  'BROADHOLME',
#  'BROADWAY',
#  'BROMSGROVE',
#  'BROUGHTON',
#  'BULKINGTON',
#  'BUNGAY',
#  'BUNTINGFORD',
#  'BURNLEY',
#  'BURNTWOOD',
#  'BURSCOUGH',
#  'BURSTOW',
#  'BURWELL',
#  'BURY',
#  'CALLINGTON',
#  'CALVERTON',
#  'CAMBRIDGE',
#  'CANNOCK',
#  'CANWICK',
#  'CARLETON',
#  'CARLISLE',
#  'CASTLECARY',
#  'CASTLEDONING',
#  'CAWTHORNE',
#  'CHALTON',
#  'CHANTRY',
#  'CHERRYBURTON',
#  'CHESTERLESTR',
#  'CHEWSTOKE',
#  'CHOBHAM',
#  'CHORLEY',
#  'CHURCHHANBOR',
#  'CHURCHSTRETT',
#  'CLAYCROSS',
#  'CLEATOR',
#  'CLITHEROE',
#  'CLOWNE',
#  'COALEY',
#  'COCKERMOUTH',
#  'COGGESHALL',
#  'COLWALL',
#  'CONEYWESTON',
#  'CONGLETON',
#  'CONSETT',
#  'CORBY',
#  'COTONPARK',
#  'COTTESMORE',
#  'CRANBROOK',
#  'CRANLEIGH',
#  'CRESWELL',
#  'CREWE',
#  'CROOKHALL',
#  'CROWBOROUGH',
#  'CROWLE',
#  'CUDWORTH',
#  'DARLEY',
#  'DEEPINGS',
#  'DERBY',
#  'DEREHAM',
#  'DEVIZES',
#  'DISS',
#  'DODDINGHURST',
#  'DONISTHORPE',
#  'DORCHESTER',
#  'DRIFFIELD',
#  'DROITWICH',
#  'DRONFIELD',
#  'DUKINFIELD',
#  'DUNHOLME',
#  'DUNSTABLE',
#  'DUXFORD',
#  'EASINGWOLD',
#  'EASTBRIDGFOR',
#  'EASTHAMPSTEA',
#  'EASTHARLING',
#  'EASTMARKHAM',
#  'ECCLES',
#  'EDENBRIDGE',
#  'EDENVALEEAST',
#  'EDGMOND',
#  'EDWINSTOWE',
#  'EGGBOROUGH',
#  'ESHWINNING',
#  'ETWALL',
#  'EVERCREECH',
#  'FAILSWORTH',
#  'FARNSFIELD',
#  'FELBRIDGE',
#  'FINDERN',
#  'FLITWICK',
#  'FORMBY',
#  'FOXTONCAMBS',
#  'FRAMLINGHAM',
#  'FRAMPTON',
#  'FROME',
#  'GARSTANG',
#  'GERRARDSCROS',
#  'GLOSSOP',
#  'GREATAYTON',
#  'GREATTOTHAM',
#  'GRENDON',
#  'GRESFORD',
#  'GTWARFORD',
#  'HADDENHAM',
#  'HAILSHAMNORT',
#  'HAILSHAMSOUT',
#  'HALSTEADLANG',
#  'HANSLOPE',
#  'HARTLEYWINTN',
#  'HARVINGTON',
#  'HATFIELDHEAT',
#  'HAVERHILL',
#  'HAZELGROVE',
#  'HEACHAM',
#  'HEAGE',
#  'HEANOR',
#  'HELSTON',
#  'HEMPNALL',
#  'HENLEY',
#  'HIBALDSTOW',
#  'HILLHOUSE',
#  'HINCKLEY',
#  'HITCHIN',
#  'HIXON',
#  'HOCKFORD',
#  'HODSOCK',
#  'HOLBEACH',
#  'HOLMWOOD',
#  'HOLSWORTHY(D',
#  'HONEYBOURNE',
#  'HORNCASTLE',
#  'HORSHAMNEW',
#  'HORWICH',
#  'HUDDERSFIELD',
#  'HUDDERSFIELD',
#  'HURLEY',
#  'HUYTON',
#  'HYDE',
#  'HYNDBURN',
#  'IBSTOCK',
#  'ILCHESTER',
#  'ILKESTON',
#  'ILMINSTER',
#  'INGOLDISTHOR',
#  'IRLAM',
#  'ISLEHAM',
#  'KEELBY',
#  'KELLOE',
#  'KENDAL',
#  'KESWICK',
#  'KEYNSHAM',
#  'KIBWORTH',
#  'KIDDERMINSTE',
#  'KILSBY',
#  'KINETON',
#  'KIRTONINLIND',
#  'KNARESBOROUG',
#  'KNITSLEY',
#  'KNUTSFORD',
#  'LACEBY',
#  'LANCHESTER',
#  'LEEK',
#  'LEIGH',
#  'LETCHWORTH',
#  'LEVEN',
#  'LEYBURN',
#  'LEYLAND',
#  'LIDSEY',
#  'LIGHTWATER',
#  'LINCOLN',
#  'LISKEARD(LOD',
#  'LLANGEFNI',
#  'LONGHOPE',
#  'LONGSTRATTON',
#  'LOOE',
#  'LOUGHBOROUGH',
#  'LOUTH',
#  'LOWERGORNAL',
#  'LUTON',
#  'LYDD',
#  'LYNDHURST',
#  'MABLETHORPE',
#  'MALTBY',
#  'MANSFIELD',
#  'MARCHINGTON',
#  'MAREHAY',
#  'MARKETHARBOR',
#  'MARKETRASEN',
#  'MARKETWEIGHT',
#  'MARSTONMORET',
#  'MARTOCK',
#  'MELBOURN',
#  'MELBOURNE',
#  'MELBOURNEYW',
#  'MELTHAM',
#  'MELTONMOWBRA',
#  'MERIDEN',
#  'MERRIOTT',
#  'MERSTHAM',
#  'MIDDLETONCHE',
#  'MIDDLEWICH',
#  'MILTON',
#  'MILTONUNDERW',
#  'MOBBERLEY',
#  'MORETONINMAR',
#  'MOSSLEY',
#  'NAFFERTON',
#  'NANTWICH',
#  'NETTLEHAM',
#  'NEWBURY',
#  'NEWBURYLANEC',
#  'NEWMARKET',
#  'NEWPORT',
#  'NEWTHORPE',
#  'NORMANTON',
#  'NORTHFAL',
#  'NORTHWICH',
#  'NORTONJUXTA',
#  'NUNEATON',
#  'OADBY',
#  'OLDBUCKENHAM',
#  'OLDHAM',
#  'OLDHURST',
#  'OVER',
#  'OVERSEAL',
#  'OXENHOPE',
#  'OXTED',
#  'PADDOCKWOOD',
#  'PANGBOURNE',
#  'PAPWORTHEVER',
#  'PARKROADHAND',
#  'PATELEYBRIDG',
#  'PEGSWOOD',
#  'PELYNT',
#  'PEMBURY',
#  'PENRITH',
#  'PICKERING',
#  'PINXTON',
#  'POCKLINGTON',
#  'POTTON',
#  'PURTON',
#  'RAINWORTH',
#  'RAMPTON',
#  'RAMSEY',
#  'RATFYN',
#  'RAUNDS',
#  'RAYLEIGH',
#  'READING',
#  'REIGATE',
#  'RENISHAW',
#  'RINGWOOD',
#  'RIPLEY',
#  'RIPLEYTW',
#  'ROBERTSBRIDG',
#  'ROCHDALE',
#  'RODBOURNE',
#  'ROSSENDALE',
#  'ROYSTON',
#  'RYEMEADS',
#  'SADDLEWORTH',
#  'SALFORD',
#  'SALISBURY',
#  'SALTFORD',
#  'SANDBACH',
#  'SANDFORD',
#  'SAWTRY',
#  'SEDGEFIELD',
#  'SHAMLEYGREEN',
#  'SHENFIELD',
#  'SHEPTONMALLE',
#  'SHERBORNESTJ',
#  'SHERBURN',
#  'SHERBURNINEL',
#  'SHILLINGTON',
#  'SHIREBROOK',
#  'SIDLESHAM',
#  'SILCHESTER',
#  'SISLAND(LODD',
#  'SKEGBY',
#  'SKELLINGTHOR',
#  'SKELMERSDALE',
#  'SLEAFORD',
#  'SNARESTONE',
#  'SOHAM',
#  'SOMERTON',
#  'SOUTHELMSALL',
#  'SOUTHHYKEHAM',
#  'SOUTHNORMANT',
#  'SPARKFORD',
#  'SPERNAL',
#  'STAMFORD',
#  'STAMFORDMD',
#  'STANFORDRIVE',
#  'STANLEYDOWNT',
#  'STANTON',
#  'STANTONAW',
#  'STANTONHARCO',
#  'STAPLEFORD',
#  'STCOLUMB',
#  'STEYNING',
#  'STHELENS',
#  'STIVES',
#  'STOCKPORT',
#  'STOKEBARDOLP',
#  'STOKEHEATH',
#  'STOKEPRIOR',
#  'STOKESLEY',
#  'STOWMARKET',
#  'STRONGFORD',
#  'SUDBURY',
#  'SUTTONBONING',
#  'SWANWICK',
#  'SWARDESTON',
#  'SWINESHEAD',
#  'TANGMERE',
#  'TARVIN',
#  'THINGLEY',
#  'THURSTON',
#  'TIPTREE',
#  'TONBRIDGE',
#  'TOTON',
#  'TOWLAW',
#  'TUDDENHAM',
#  'TUNBRIDGEWEL',
#  'TYLDESLEY',
#  'UCKFIELD',
#  'ULCEBY',
#  'UPMINSTER(BU',
#  'UPPINGHAM',
#  'WALTHAMOW',
#  'WANTAGE',
#  'WARMINSTER',
#  'WARMSWORTH',
#  'WARWICK',
#  'WASHWATER',
#  'WATERBEACH',
#  'WATHONDEARNE',
#  'WATLINGTON',
#  'WATTON',
#  'WELLS',
#  'WEOODBROOK',
#  'WESTBERE',
#  'WESTFIELD',
#  'WETHERSFIELD',
#  'WHALEYBRIDGE',
#  'WHETSTONE',
#  'WHITCHURCH',
#  'WHITEPARISH',
#  'WHITEWALTHAM',
#  'WHITWELL',
#  'WIDNES',
#  'WIGSTON',
#  'WIGTON',
#  'WILMSLOW',
#  'WINDERMERE',
#  'WINKLEIGH',
#  'WINSFORD',
#  'WISLEY',
#  'WITCHAM',
#  'WITCHFORD',
#  'WITNEY',
#  'WOKING',
#  'WOKINGHAM',
#  'WOODHALLSPA',
#  'WOOLER',
#  'WOOLSTONE',
#  'WOOLTON',
#  'WORKSOP(MANT',
#  'WORSLEY',
#  'WORTHINGTON',
#  'WYMONDHAM']

# %%
#valid = []

valid = [i for i in s_names1 if(i in match)]

# %%
len(valid)
# Out:
# 428

# %%
valid
# Out:
# ['ABINGDON',
#  'ACLE',
#  'ADWICK',
#  'AINSDALE',
#  'ALCONBURY',
#  'ALDERLEYEDGE',
#  'ALFORD',
#  'ALFRETON',
#  'ALSAGER',
#  'ALTON',
#  'ALTRINCHAM',
#  'ALVECHURCH',
#  'AMBERGATE',
#  'AMBLESIDE',
#  'AOODBANK',
#  'ARMTHORPE',
#  'ASCOT',
#  'ASHFORD',
#  'ASHTON',
#  'ASPATRIA',
#  'ATTLEBOROUGH',
#  'AYLESBURY',
#  'AYLESFORD',
#  'AYLSHAM',
#  'BALBY',
#  'BALSALLCOMMO',
#  'BARLESTONE',
#  'BARNOLDSWICK',
#  'BARTON',
#  'BARTONLECLAY',
#  'BARWICK',
#  'BASINGSTOKE',
#  'BASSINGBOURN',
#  'BEDWORTH',
#  'BENHALL',
#  'BENTLEY',
#  'BEVERLEY',
#  'BIDBOROUGH',
#  'BIDDENDEN',
#  'BIDDULPH',
#  'BILSTHORPE',
#  'BIRTLEY',
#  'BISHOPSSTORT',
#  'BLACKBURNMEA',
#  'BLACKMINSTER',
#  'BOCKING',
#  'BOLTON',
#  'BOMEREHEATH',
#  'BOTTESFORD',
#  'BOTTISHAM',
#  'BOURNE',
#  'BOWBURN',
#  'BOWERHILL',
#  'BRACKLEYNEW',
#  'BRAINTREE',
#  'BRANTON',
#  'BRIGG',
#  'BRIXWORTH',
#  'BROADHOLME',
#  'BROADWAY',
#  'BROMSGROVE',
#  'BROUGHTON',
#  'BULKINGTON',
#  'BUNGAY',
#  'BUNTINGFORD',
#  'BURNLEY',
#  'BURNTWOOD',
#  'BURSCOUGH',
#  'BURSTOW',
#  'BURWELL',
#  'BURY',
#  'CALLINGTON',
#  'CALVERTON',
#  'CAMBRIDGE',
#  'CANNOCK',
#  'CANWICK',
#  'CARLETON',
#  'CARLISLE',
#  'CASTLECARY',
#  'CASTLEDONING',
#  'CAWTHORNE',
#  'CHALTON',
#  'CHANTRY',
#  'CHERRYBURTON',
#  'CHESTERLESTR',
#  'CHEWSTOKE',
#  'CHOBHAM',
#  'CHORLEY',
#  'CHURCHHANBOR',
#  'CHURCHSTRETT',
#  'CLAYCROSS',
#  'CLEATOR',
#  'CLITHEROE',
#  'CLOWNE',
#  'COALEY',
#  'COCKERMOUTH',
#  'COGGESHALL',
#  'COLWALL',
#  'CONEYWESTON',
#  'CONGLETON',
#  'CONSETT',
#  'CORBY',
#  'COTONPARK',
#  'COTTESMORE',
#  'CRANBROOK',
#  'CRANLEIGH',
#  'CRESWELL',
#  'CREWE',
#  'CROOKHALL',
#  'CROWBOROUGH',
#  'CROWLE',
#  'CUDWORTH',
#  'DARLEY',
#  'DEEPINGS',
#  'DERBY',
#  'DEREHAM',
#  'DEVIZES',
#  'DISS',
#  'DODDINGHURST',
#  'DONISTHORPE',
#  'DORCHESTER',
#  'DRIFFIELD',
#  'DROITWICH',
#  'DRONFIELD',
#  'DUKINFIELD',
#  'DUNHOLME',
#  'DUNSTABLE',
#  'DUXFORD',
#  'EASINGWOLD',
#  'EASTBRIDGFOR',
#  'EASTHAMPSTEA',
#  'EASTHARLING',
#  'EASTMARKHAM',
#  'ECCLES',
#  'EDENBRIDGE',
#  'EDENVALEEAST',
#  'EDGMOND',
#  'EDWINSTOWE',
#  'EGGBOROUGH',
#  'ESHWINNING',
#  'ETWALL',
#  'EVERCREECH',
#  'FAILSWORTH',
#  'FARNSFIELD',
#  'FELBRIDGE',
#  'FINDERN',
#  'FLITWICK',
#  'FORMBY',
#  'FOXTONCAMBS',
#  'FRAMLINGHAM',
#  'FRAMPTON',
#  'FROME',
#  'GARSTANG',
#  'GERRARDSCROS',
#  'GLOSSOP',
#  'GREATAYTON',
#  'GREATTOTHAM',
#  'GRENDON',
#  'GRESFORD',
#  'GTWARFORD',
#  'HADDENHAM',
#  'HAILSHAMNORT',
#  'HAILSHAMSOUT',
#  'HALSTEADLANG',
#  'HANSLOPE',
#  'HARTLEYWINTN',
#  'HARVINGTON',
#  'HATFIELDHEAT',
#  'HAVERHILL',
#  'HAZELGROVE',
#  'HEACHAM',
#  'HEAGE',
#  'HEANOR',
#  'HELSTON',
#  'HEMPNALL',
#  'HENLEY',
#  'HIBALDSTOW',
#  'HILLHOUSE',
#  'HINCKLEY',
#  'HITCHIN',
#  'HIXON',
#  'HOCKFORD',
#  'HODSOCK',
#  'HOLBEACH',
#  'HOLMWOOD',
#  'HOLSWORTHY(D',
#  'HONEYBOURNE',
#  'HORNCASTLE',
#  'HORSHAMNEW',
#  'HORWICH',
#  'HUDDERSFIELD',
#  'HUDDERSFIELD',
#  'HURLEY',
#  'HUYTON',
#  'HYDE',
#  'HYNDBURN',
#  'IBSTOCK',
#  'ILCHESTER',
#  'ILKESTON',
#  'ILMINSTER',
#  'INGOLDISTHOR',
#  'IRLAM',
#  'ISLEHAM',
#  'KEELBY',
#  'KELLOE',
#  'KENDAL',
#  'KESWICK',
#  'KEYNSHAM',
#  'KIBWORTH',
#  'KIDDERMINSTE',
#  'KILSBY',
#  'KINETON',
#  'KIRTONINLIND',
#  'KNARESBOROUG',
#  'KNITSLEY',
#  'KNUTSFORD',
#  'LACEBY',
#  'LANCHESTER',
#  'LEEK',
#  'LEIGH',
#  'LETCHWORTH',
#  'LEVEN',
#  'LEYBURN',
#  'LEYLAND',
#  'LIDSEY',
#  'LIGHTWATER',
#  'LINCOLN',
#  'LISKEARD(LOD',
#  'LLANGEFNI',
#  'LONGHOPE',
#  'LONGSTRATTON',
#  'LOOE',
#  'LOUGHBOROUGH',
#  'LOUTH',
#  'LOWERGORNAL',
#  'LUTON',
#  'LYDD',
#  'LYNDHURST',
#  'MABLETHORPE',
#  'MALTBY',
#  'MANSFIELD',
#  'MARCHINGTON',
#  'MAREHAY',
#  'MARKETHARBOR',
#  'MARKETRASEN',
#  'MARKETWEIGHT',
#  'MARSTONMORET',
#  'MARTOCK',
#  'MELBOURN',
#  'MELBOURNE',
#  'MELBOURNEYW',
#  'MELTHAM',
#  'MELTONMOWBRA',
#  'MERIDEN',
#  'MERRIOTT',
#  'MERSTHAM',
#  'MIDDLETONCHE',
#  'MIDDLEWICH',
#  'MILTON',
#  'MILTONUNDERW',
#  'MOBBERLEY',
#  'MORETONINMAR',
#  'MOSSLEY',
#  'NAFFERTON',
#  'NANTWICH',
#  'NETTLEHAM',
#  'NEWBURY',
#  'NEWBURYLANEC',
#  'NEWMARKET',
#  'NEWPORT',
#  'NEWTHORPE',
#  'NORMANTON',
#  'NORTHFAL',
#  'NORTHWICH',
#  'NORTONJUXTA',
#  'NUNEATON',
#  'OADBY',
#  'OLDBUCKENHAM',
#  'OLDHAM',
#  'OLDHURST',
#  'OVER',
#  'OVERSEAL',
#  'OXENHOPE',
#  'OXTED',
#  'PADDOCKWOOD',
#  'PANGBOURNE',
#  'PAPWORTHEVER',
#  'PARKROADHAND',
#  'PATELEYBRIDG',
#  'PEGSWOOD',
#  'PELYNT',
#  'PEMBURY',
#  'PENRITH',
#  'PICKERING',
#  'PINXTON',
#  'POCKLINGTON',
#  'POTTON',
#  'PURTON',
#  'RAINWORTH',
#  'RAMPTON',
#  'RAMSEY',
#  'RATFYN',
#  'RAUNDS',
#  'RAYLEIGH',
#  'READING',
#  'REIGATE',
#  'RENISHAW',
#  'RINGWOOD',
#  'RIPLEY',
#  'RIPLEYTW',
#  'ROBERTSBRIDG',
#  'ROCHDALE',
#  'RODBOURNE',
#  'ROSSENDALE',
#  'ROYSTON',
#  'RYEMEADS',
#  'SADDLEWORTH',
#  'SALFORD',
#  'SALISBURY',
#  'SALTFORD',
#  'SANDBACH',
#  'SANDFORD',
#  'SAWTRY',
#  'SEDGEFIELD',
#  'SHAMLEYGREEN',
#  'SHENFIELD',
#  'SHEPTONMALLE',
#  'SHERBORNESTJ',
#  'SHERBURN',
#  'SHERBURNINEL',
#  'SHILLINGTON',
#  'SHIREBROOK',
#  'SIDLESHAM',
#  'SILCHESTER',
#  'SISLAND(LODD',
#  'SKEGBY',
#  'SKELLINGTHOR',
#  'SKELMERSDALE',
#  'SLEAFORD',
#  'SNARESTONE',
#  'SOHAM',
#  'SOMERTON',
#  'SOUTHELMSALL',
#  'SOUTHHYKEHAM',
#  'SOUTHNORMANT',
#  'SPARKFORD',
#  'SPERNAL',
#  'STAMFORD',
#  'STAMFORDMD',
#  'STANFORDRIVE',
#  'STANLEYDOWNT',
#  'STANTON',
#  'STANTONAW',
#  'STANTONHARCO',
#  'STAPLEFORD',
#  'STCOLUMB',
#  'STEYNING',
#  'STHELENS',
#  'STIVES',
#  'STOCKPORT',
#  'STOKEBARDOLP',
#  'STOKEHEATH',
#  'STOKEPRIOR',
#  'STOKESLEY',
#  'STOWMARKET',
#  'STRONGFORD',
#  'SUDBURY',
#  'SUTTONBONING',
#  'SWANWICK',
#  'SWARDESTON',
#  'SWINESHEAD',
#  'TANGMERE',
#  'TARVIN',
#  'THINGLEY',
#  'THURSTON',
#  'TIPTREE',
#  'TONBRIDGE',
#  'TOTON',
#  'TOWLAW',
#  'TUDDENHAM',
#  'TUNBRIDGEWEL',
#  'TYLDESLEY',
#  'UCKFIELD',
#  'ULCEBY',
#  'UPMINSTER(BU',
#  'UPPINGHAM',
#  'WALTHAMOW',
#  'WANTAGE',
#  'WARMINSTER',
#  'WARMSWORTH',
#  'WARWICK',
#  'WASHWATER',
#  'WATERBEACH',
#  'WATHONDEARNE',
#  'WATLINGTON',
#  'WATTON',
#  'WELLS',
#  'WEOODBROOK',
#  'WESTBERE',
#  'WESTFIELD',
#  'WETHERSFIELD',
#  'WHALEYBRIDGE',
#  'WHETSTONE',
#  'WHITCHURCH',
#  'WHITEPARISH',
#  'WHITEWALTHAM',
#  'WHITWELL',
#  'WIDNES',
#  'WIGSTON',
#  'WIGTON',
#  'WILMSLOW',
#  'WINDERMERE',
#  'WINKLEIGH',
#  'WINSFORD',
#  'WISLEY',
#  'WITCHAM',
#  'WITCHFORD',
#  'WITNEY',
#  'WOKING',
#  'WOKINGHAM',
#  'WOODHALLSPA',
#  'WOOLER',
#  'WOOLSTONE',
#  'WOOLTON',
#  'WORKSOP(MANT',
#  'WORSLEY',
#  'WORTHINGTON',
#  'WYMONDHAM']

# %%
#treatment_locations.to_csv('location_matching.csv')

#treatment_clean = treatment_locations[treatment_locations[['SWT_edited', 'match']].isin(s_names).all(axis=1)]
#treatment_clean = treatment_locations[(~treatment_locations['mapdata_edited'].isin(pd.Series(treatment_locations['match']))) & (~treatment_locations['mapdata_edited'].isin(pd.Series(treatment_locations['SWT_edited'])))]

# %%
treatment_clean
# Out:
#          SWT_main    SWT_edited                 mapdata_main mapdata_edited  \
# 0        ABINGDON      ABINGDON  ABERBAIDENBEHINDHOPYARDFARM   ABERBAIDENBE
# 1            ACLE          ACLE                    ABERFELDY      ABERFELDY
# 4        AINSDALE      AINSDALE                     ABINGDON       ABINGDON
# 5       ALCONBURY     ALCONBURY               ABINGDON(OXON)   ABINGDON(OXO
# 6    ALDERLEYEDGE  ALDERLEYEDGE                       ABOYNE         ABOYNE
# ..            ...           ...                          ...            ...
# 416     RAINWORTH     RAINWORTH                    CONGLETON      CONGLETON
# 417       RAMPTON       RAMPTON                    CONINGSBY      CONINGSBY
# 418        RAMSEY        RAMSEY                  CONNAHSQUAY    CONNAHSQUAY
# 420        RAUNDS        RAUNDS                      CONSETT        CONSETT
# 425       READING       READING                  CORFEMULLEN    CORFEMULLEN
#
#             match
# 0        ABINGDON
# 1            ACLE
# 4       ALCONBURY
# 5    ALDERLEYEDGE
# 6          ALFORD
# ..            ...
# 416     WITCHFORD
# 417        WITNEY
# 418        WOKING
# 420   WOODHALLSPA
# 425       WORSLEY
#
# [245 rows x 5 columns]

# %%
swt_data = swt_data.replace(site_edited1)

# %%
swt_data
# Out:
#        SampleDateTime TreatmentPlant SampleDateTime.1  SampleLocationName  \
# 0          2015-11-19      DRIFFIELD       2015-11-19  Treatment Effluent
# 1          2015-04-06       PENYBONT       2015-04-06  Treatment Effluent
# 2          2015-04-06       PENYBONT       2015-04-06  Treatment Effluent
# 3          2015-04-06       PENYBONT       2015-04-06  Treatment Effluent
# 4          2015-04-06       PENYBONT       2015-04-06  Treatment Effluent
# ...               ...            ...              ...                 ...
# 638118     2020-01-28      NETTLEHAM       2020-01-28  Treatment Effluent
# 638119     2020-01-28      NETTLEHAM       2020-01-28  Treatment Effluent
# 638120     2020-01-28      NETTLEHAM       2020-01-28  Treatment Effluent
# 638121     2020-01-28      NETTLEHAM       2020-01-28  Treatment Effluent
# 638122     2020-01-30        HEACHAM       2020-01-30  Treatment Effluent
#
#         SampleValue           NameDeterminandName               UnitsName  \
# 0            0.0140                     triclosan    micrograms per litre
# 1            0.0005                        BDE 99    micrograms per litre
# 2            0.0005                       BDE 100    micrograms per litre
# 3            0.0005                       BDE 153    micrograms per litre
# 4            0.0005                       BDE 154    micrograms per litre
# ...             ...                           ...                     ...
# 638118       0.0002                   Tributyltin    micrograms per litre
# 638119       0.1000                 Octylphenols     micrograms per litre
# 638120       0.1300                   Nonylphenol    micrograms per litre
# 638121      19.3000  total oxidised nitrogen as N  milligrammes per litre
# 638122       0.0500    di nonylphenol ethoxylates    micrograms per litre
#
#        BelowMinReading  Year  Month
# 0                  Yes  2015     11
# 1                  Yes  2015      4
# 2                  Yes  2015      4
# 3                  Yes  2015      4
# 4                  Yes  2015      4
# ...                ...   ...    ...
# 638118             Yes  2020      1
# 638119             Yes  2020      1
# 638120              No  2020      1
# 638121              No  2020      1
# 638122             Yes  2020      1
#
# [638123 rows x 10 columns]

# %%
#treatment plants across UK
ukwp = location_clean.uwwName.unique()
print(ukwp)
# Out:
# ['TANDRAGEE' 'FOCHABERS' 'FORFARNEW' ... 'SHREWSBURY' 'SKEGBY'
#  'SLADEHOOTON']

# %%
#treatment plants in UKWIR dataset
trt_p = swt_data.TreatmentPlant.unique()
trt_p
# Out:
# array(['DRIFFIELD', 'PENYBONT', 'DEEPINGS', 'HEAGE', 'CANWICK', 'CANNOCK',
#        'DUXFORD', 'HILLHOUSE', 'RODBOURNE', 'OVER', 'HORNCASTLE',
#        'GARFORTH', 'LLANGEFNI', 'FARNHAM', 'EASTHARLING', 'DUNSTABLE',
#        'CHILTONW', 'AYLESBURY', 'GREATBILLING', 'MAREHAY', 'MILTON',
#        'BLAGDON', 'KNOSTROP', 'GRENDON', 'SLEAFORD', 'STOCKPORT',
#        'SEAMER', 'RENISHAW', 'SOHAM', 'STAMFORD', 'AFAN', 'WHITEPARISH',
#        'ILKESTON', 'DROITWICH', 'PURTON', 'CULHAM', 'WOODHALLSPA',
#        'SNARESTONE', 'SANDFORD', 'CHALTON', 'RAMSEY', 'AMBERGATE',
#        'ALVECHURCH', 'STAPLEFORD', 'TOTON', 'ALDERSHOT', 'SNITTERFIELD',
#        'HIXON', 'ANCASTER', 'SPERNAL', 'HAYDEN', 'GRESFORD',
#        'BILLINGHURST', 'SHERBURNINEL', 'MERIDEN', 'MELBOURNEYW',
#        'NEWTHORPE', 'MINWORTH', 'PYE', 'PINXTON', 'SUMMERLA(PAG',
#        'BOURNE', 'AYCLIFFE', 'WOOLSTONE', 'CAMBRIDGE', 'BIDDENDEN',
#        'CHEWSTOKE', 'STAMFORDMD', 'HEANOR', 'WARWICK', 'KIRKBY',
#        'DULLINGHAM', 'BARROW', 'TUNBRIDGEWEL', 'COGGESHALL', 'BODMIN',
#        'LYNDHURST', 'SHEPTONMALLE', 'CHESTERLESTR', 'KNITSLEY',
#        'CROOKHALL', 'ILMINSTER', 'HOWDON', 'KEYNSHAM', 'TOWLAW', 'DIDCOT',
#        'CONSETT', 'NORTONJUXTA', 'STRADISHALL(', 'LINCOLN', 'SHERBURN',
#        'WOKING', 'VINESCROSS', 'OXENHOPE', 'MELBOURNE', 'NEILEY',
#        'POCKLINGTON', 'APPLETON', 'PEGSWOOD', 'LEMONROYD', 'WHITCHURCH',
#        'PELYNT', 'HUSTLEDOWN', 'CHINNOR', 'WETHERSFIELD', 'HORSHAMNEW',
#        'LIDSEY', 'SIDLESHAM', 'FRADDON', 'CRAWLEY', 'EDENVALEEAST',
#        'FROME', 'KIDDERMINSTE', 'DERBY', 'IBSTOCK', 'REDLYNCH',
#        'MANSFIELD', 'FAZAKERLEY', 'NUNEATON', 'WIGAN', 'FORNHAM',
#        'SALTFORD', 'ALDERLEYEDGE', 'STHELENS', 'BIRTLEY', 'BURSCOUGH',
#        'FORMBY', 'READING', 'AINSDALE', 'LEYLAND', 'AMBLESIDE',
#        'HEMPNALL', 'CALLINGTON', 'CHILTON', 'HOLBEACH', 'HOLLOWELL',
#        'MABLETHORPE', 'MELBOURN', 'ABINGDON', 'SKELMERSDALE', 'BIDDULPH',
#        'BOCKING', 'HURLEY', 'NEWMARKET', 'MOBBERLEY', 'CROSCOMBE', 'LOOE',
#        'LUTON', 'CORBY', 'GTWARFORD', 'LANCHESTER', 'KENDAL',
#        'PRISBOROUGH', 'THAME', 'TIPTREE', 'WHITLINGHAM(', 'MARLOW',
#        'WORMINGHALL', 'WATLINGTON', 'ROYSTON', 'HENLEY', 'SUDBURY',
#        'WINDERMERE', 'WANTAGE', 'BOURTON', 'WELLS', 'RAYLEIGH', 'NEWBURY',
#        'MARKETWEIGHT', 'LEVEN', 'DARLEY', 'BEVERLEY', 'BALBY', 'CHOLSEY',
#        'FAILSWORTH', 'NAFFERTON', 'ROCHDALE', 'STANFORDRIVE', 'CARLISLE',
#        'KINGSCLERE', 'BENSON', 'CHERRYBURTON', 'SLINGSBY', 'SUTTONBONING',
#        'STEYNING', 'FERNHURST', 'RYEMEADS', 'BENTLEY', 'BUNTINGFORD',
#        'BURGHFIELD', 'OLDHAM', 'THERFIELD', 'NEWBURYLANEC', 'RATFYN',
#        'PENRITH', 'CHALGROVE', 'KINSON', 'WASHWATER', 'HUYTON', 'COLWALL',
#        'LEIGH', 'BATTLE', 'THEYDON', 'NORTHFAL', 'TRING', 'BURTONOW',
#        'IWERNEMINSTE', 'ROSSENDALE', 'NEAVESLANE', 'LONGHOPE',
#        'LOUGHBOROUGH', 'SLOUGH', 'WORSLEY', 'WILMSLOW', 'ROUNDHILL',
#        'OSWESTRY', 'WIDNES', 'TYLDESLEY', 'PICKERING', 'TARVIN',
#        'PARKROADHAND', 'RIPLEY', 'HAILSHAMNORT', 'ICKLESHAM',
#        'BALSALLCOMMO', 'STOKEBARDOLP', 'HAILSHAMSOUT', 'SOUTHNORMANT',
#        'LYDD', 'HARPENDEN', 'EPPING', 'HATFIELDHEAT', 'WHITWELL',
#        'COTONPARK', 'HODTHORPE', 'CLAVERING', 'STANSTEADMOU', 'HOGSMILL',
#        'HOGSMILLB', 'WOODSETTS', 'SHIREBROOK', 'STUBBSLA(BRE', 'SWANWICK',
#        'ROBERTSBRIDG', 'WESTFIELD', 'STANDON', 'MILLGREEN',
#        'PATELEYBRIDG', 'RAWCLIFFEYOR', 'PANGBOURNE', 'CLOWNE', 'CRESWELL',
#        'CHIEVELEY', 'ROYALWOOTTON', 'ALDERMASTON', 'IRLAM', 'RAINWORTH',
#        'THINGLEY', 'RAYHALL', 'BURY', 'WARMSWORTH', 'SALISBURY',
#        'RINGWOOD', 'BOLTON', 'BOTTESFORD', 'HODSOCK', 'BOMEREHEATH',
#        'WADWORTH', 'ALDWARKE', 'WANLIP', 'STANTON', 'KINETON', 'KILSBY',
#        'BEDDINGTON', 'LOWERGORNAL', 'SILCHESTER', 'BRENTWOOD',
#        'GWENNAP(LANN', 'WOOLTON', 'HUDDERSFIELD', 'HILLAM', 'BECKTON',
#        'FARNSFIELD', 'MARCHINGTON', 'WALTHAMOW', 'STRONGFORD',
#        'WEOODBROOK', 'WIGSTON', 'STOKEHEATH', 'RAMPTON', 'OADBY',
#        'NEWPORT', 'FINSTOCK', 'CHADLINGTON', 'MORETONINMAR', 'ASCOT',
#        'WITNEY', 'WINKLEIGH', 'WHETSTONE', 'STCOLUMB', 'REDDITCH',
#        'ETWALL', 'EDGMOND', 'CROXTONKERRI', 'COALEY', 'UTTONSDROVE',
#        'LOGGERHEADS', 'LEEK', 'HARVINGTON', 'CLAYCROSS', 'OXTED',
#        'OLDBUCKENHAM', 'LONGSTRATTON', 'FLITWICK', 'STOKESLEY', 'BOWBURN',
#        'FRAMPTON', 'HADDENHAM', 'LETCHWORTH', 'KIBWORTH', 'GREATAYTON',
#        'HIBALDSTOW', 'HANSLOPE', 'CHANTRY', 'CHEDBURGH', 'BURWELL',
#        'BASSINGBOURN', 'BENHALL', 'SEDGEFIELD', 'TUDHOEMILL', 'WILBURTON',
#        'WATERBEACH', 'STIVES', 'WITCHAM', 'BROUGHTON', 'SKELLINGTHOR',
#        'SAWTRY', 'OLDHURST', 'TUDDENHAM', 'UPPINGHAM', 'BRANTON',
#        'BLACKMINSTER', 'BILSTHORPE', 'SANDHURST', 'HARESTOCK', 'NORTHIAM',
#        'CROWBOROUGH', 'CHURCHSTRETT', 'CASTLEDONING', 'BURNTWOOD',
#        'AOODBANK', 'ALFRETON', 'PEMBURY', 'EGRINSTEAD', 'CRANBROOK',
#        'FELBRIDGE', 'GOOSEBECK', 'HORSMONDEN', 'WADHURST', 'BROADHOLME',
#        'TUNBRIDGES', 'BOTTISHAM', 'STANLEYDOWNT', 'CHURCHHANBOR', 'CLIVE',
#        'CASTLECARY', 'MERRIOTT', 'CREWKERNEE', 'DORCHESTER',
#        'CHAPELENLEFR', 'GLOSSOP', 'STANTONHARCO', 'BRACKNELL', 'ALSAGER',
#        'CONGLETON', 'SANDBACH', 'MIDDLEWICH', 'DAVYHULME', 'ECCLES',
#        'HAZELGROVE', 'NORTHWHEATLE', 'WATHONDEARNE', 'SANDALL',
#        'KNARESBOROUG', 'CLAYTONWEST', 'CARLETON', 'SUTTONBP',
#        'RAWCLIFFEGOO', 'NORMANTON', 'MELTHAM', 'BARWICK', 'EGGBOROUGH',
#        'RIPPONDEN', 'SMALLEYBIGHT', 'HYDE', 'CLITHEROE', 'SALFORD',
#        'SPARKFORD', 'BLACKBURNMEA', 'LEYBURN', 'EASINGWOLD', 'WOMBWELL',
#        'LUNDWOOD', 'MOSSLEY', 'MARTOCK', 'ILCHESTER', 'CAWTHORNE',
#        'DRONFIELD', 'CUDWORTH', 'SOUTHELMSALL', 'DUKINFIELD', 'ASHTON',
#        'KNUTSFORD', 'MILTONUNDERW', 'ADWICK', 'HAVERHILL', 'CIRENCESTER',
#        'CLEATOR', 'HORNTON', 'HITCHIN', 'KEELBY', 'LEADENHAM',
#        'EASTHAMPSTEA', 'LISKEARD(LOD', 'ULCEBY', 'HELSTON', 'ACLE',
#        'ALTRINCHAM', 'UPMINSTER(BU', 'BARNOLDSWICK', 'CONEYWESTON',
#        'MAIDENHEAD', 'WHALEYBRIDGE', 'COTTESMORE', 'MARSTONMORET',
#        'PAPWORTHEVER', 'WHITEWALTHAM', 'MIDDLETONCHE', 'CAYTHORPE',
#        'PADDOCKWOOD', 'BARNHURST', 'HOLSWORTHY(D', 'COTTONVALLEY',
#        'AYLSHAM', 'BRIXWORTH', 'BARLESTONE', 'ARMTHORPE', 'HORWICH',
#        'PITTINGTON', 'ASHFORD', 'BIDBOROUGH', 'BETHERSDEN',
#        'SUTTONVALENC', 'TANGMERE', 'AYLESFORD', 'TONBRIDGE', 'STANTONAW',
#        'THURSTON', 'SHILLINGTON', 'SHENFIELD', 'SOUTHHYKEHAM',
#        'EDENBRIDGE', 'PITYME', 'SADDLEWORTH', 'WEYBRIDGE', 'ESHWINNING',
#        'CHESHAM', 'GODDARDSGREE', 'GERRARDSCROS', 'DEVIZES', 'EVERCREECH',
#        'BOWERHILL', 'MEARE', 'WARMINSTER', 'SOMERTON', 'IVERNORTH',
#        'GREATWORTH', 'FLEET', 'GARSTANG', 'ASPATRIA', 'LIGHTWATER',
#        'LACEBY', 'HOCKFORD', 'SWINESHEAD', 'WATTON', 'SHAMLEYGREEN',
#        'RIPLEYTW', 'HALSTEADLANG', 'REIGATE', 'CRANLEIGH', 'CHOBHAM',
#        'BURSTOW', 'BARTONLECLAY', 'ALFORD', 'BRAINTREE', 'DODDINGHURST',
#        'DUNHOLME', 'ALTON', 'BORDON', 'BLACKBIRDS', 'CAMBERLEY',
#        'NANTWICH', 'CHERTSEY', 'WISLEY', 'MERSTHAM', 'HOLMWOOD',
#        'FRAMLINGHAM', 'BYFIELD', 'WITCHFORD', 'WYMONDHAM', 'SISLAND(LODD',
#        'NETTLEHAM', 'SWARDESTON', 'LOUTH', 'MARSTONGRANT', 'HEACHAM',
#        'MARKETHARBOR', 'MARKETRASEN', 'ISLEHAM', 'RACKHEATH', 'BEDWORTH',
#        'BLYTON', 'WINGHAM', 'BRAITHWELL', 'CROWLE', 'DONISTHORPE',
#        'CLAYMILLS', 'CALVERTON', 'BULKINGTON', 'UCKFIELD', 'WESTBERE',
#        'MALTBY', 'KIRTONINLIND', 'OVERSEAL', 'YADDLETHORPE',
#        'MELTONMOWBRA', 'STOKEPRIOR', 'THORPESATCHV', 'TICKNALL', 'SKEGBY',
#        'WARTON', 'WILLOUGHTON', 'WORKSOP(MANT', 'HONEYBOURNE', 'HINCKLEY',
#        'BROADWAY', 'EASTBRIDGFOR', 'EDWINSTOWE', 'FINDERN', 'RAUNDS',
#        'BRACKLEYNEW', 'GREATTOTHAM', 'ATTLEBOROUGH', 'ALCONBURY',
#        'WOOLER', 'SEDGELETCH', 'WARGRAVE', 'ARBORFIELD', 'MENAGWINS(ST',
#        'BISHOPSSTORT', 'HIGHWORTH', 'KESWICK', 'CREWE', 'HYNDBURN',
#        'BURNLEY', 'NORTHWICH', 'WINSFORD', 'WIGTON', 'COCKERMOUTH',
#        'DEREHAM', 'BUNGAY', 'STOWMARKET', 'EASTMARKHAM', 'BROMSGROVE',
#        'DISS', 'KELLOE', 'SANDHURSTTW', 'WORTHINGTON', 'SHERBORNESTJ',
#        'WOKINGHAM', 'BARTON', 'KINGSSUTTON', 'BICESTER', 'FOXTONCAMBS',
#        'POTTON', 'GTGADDESDEN', 'CHORLEY', 'INGOLDISTHOR', 'BRIGG',
#        'HARTLEYWINTN', 'ASHVALE', 'MAPLELODGE', 'BASINGSTOKE',
#        'BERKHAMSTED'], dtype=object)

# %%
print(len(location_clean.uwwName.unique()), len(swt_data.TreatmentPlant.unique()))
# Out:
# 1854 594

# %%
match = [i for i in trt_p if any(j in i for j in ukwp)]
#match_location = dict(zip(trt_p, [i for i in trt_p if any(j in i for j in ukwp)]))

# %%
len(match)
# Out:
# 427

# %%
match
# Out:
# ['DRIFFIELD',
#  'DEEPINGS',
#  'HEAGE',
#  'CANWICK',
#  'CANNOCK',
#  'DUXFORD',
#  'HILLHOUSE',
#  'RODBOURNE',
#  'OVER',
#  'HORNCASTLE',
#  'LLANGEFNI',
#  'EASTHARLING',
#  'DUNSTABLE',
#  'AYLESBURY',
#  'MAREHAY',
#  'MILTON',
#  'GRENDON',
#  'SLEAFORD',
#  'STOCKPORT',
#  'RENISHAW',
#  'SOHAM',
#  'STAMFORD',
#  'WHITEPARISH',
#  'ILKESTON',
#  'DROITWICH',
#  'PURTON',
#  'WOODHALLSPA',
#  'SNARESTONE',
#  'SANDFORD',
#  'CHALTON',
#  'RAMSEY',
#  'AMBERGATE',
#  'ALVECHURCH',
#  'STAPLEFORD',
#  'TOTON',
#  'HIXON',
#  'SPERNAL',
#  'GRESFORD',
#  'SHERBURNINEL',
#  'MERIDEN',
#  'MELBOURNEYW',
#  'NEWTHORPE',
#  'PINXTON',
#  'BOURNE',
#  'WOOLSTONE',
#  'CAMBRIDGE',
#  'BIDDENDEN',
#  'CHEWSTOKE',
#  'STAMFORDMD',
#  'HEANOR',
#  'WARWICK',
#  'TUNBRIDGEWEL',
#  'COGGESHALL',
#  'LYNDHURST',
#  'SHEPTONMALLE',
#  'CHESTERLESTR',
#  'KNITSLEY',
#  'CROOKHALL',
#  'ILMINSTER',
#  'KEYNSHAM',
#  'TOWLAW',
#  'CONSETT',
#  'NORTONJUXTA',
#  'LINCOLN',
#  'SHERBURN',
#  'WOKING',
#  'OXENHOPE',
#  'MELBOURNE',
#  'POCKLINGTON',
#  'PEGSWOOD',
#  'WHITCHURCH',
#  'PELYNT',
#  'WETHERSFIELD',
#  'HORSHAMNEW',
#  'LIDSEY',
#  'SIDLESHAM',
#  'EDENVALEEAST',
#  'FROME',
#  'KIDDERMINSTE',
#  'DERBY',
#  'IBSTOCK',
#  'MANSFIELD',
#  'NUNEATON',
#  'SALTFORD',
#  'ALDERLEYEDGE',
#  'STHELENS',
#  'BIRTLEY',
#  'BURSCOUGH',
#  'FORMBY',
#  'READING',
#  'AINSDALE',
#  'LEYLAND',
#  'AMBLESIDE',
#  'HEMPNALL',
#  'CALLINGTON',
#  'HOLBEACH',
#  'MABLETHORPE',
#  'MELBOURN',
#  'ABINGDON',
#  'SKELMERSDALE',
#  'BIDDULPH',
#  'BOCKING',
#  'HURLEY',
#  'NEWMARKET',
#  'MOBBERLEY',
#  'LOOE',
#  'LUTON',
#  'CORBY',
#  'GTWARFORD',
#  'LANCHESTER',
#  'KENDAL',
#  'TIPTREE',
#  'WATLINGTON',
#  'ROYSTON',
#  'HENLEY',
#  'SUDBURY',
#  'WINDERMERE',
#  'WANTAGE',
#  'WELLS',
#  'RAYLEIGH',
#  'NEWBURY',
#  'MARKETWEIGHT',
#  'LEVEN',
#  'DARLEY',
#  'BEVERLEY',
#  'BALBY',
#  'FAILSWORTH',
#  'NAFFERTON',
#  'ROCHDALE',
#  'STANFORDRIVE',
#  'CARLISLE',
#  'CHERRYBURTON',
#  'SUTTONBONING',
#  'STEYNING',
#  'RYEMEADS',
#  'BENTLEY',
#  'BUNTINGFORD',
#  'OLDHAM',
#  'NEWBURYLANEC',
#  'RATFYN',
#  'PENRITH',
#  'WASHWATER',
#  'HUYTON',
#  'COLWALL',
#  'LEIGH',
#  'NORTHFAL',
#  'ROSSENDALE',
#  'LONGHOPE',
#  'LOUGHBOROUGH',
#  'WORSLEY',
#  'WILMSLOW',
#  'WIDNES',
#  'TYLDESLEY',
#  'PICKERING',
#  'TARVIN',
#  'PARKROADHAND',
#  'RIPLEY',
#  'HAILSHAMNORT',
#  'BALSALLCOMMO',
#  'STOKEBARDOLP',
#  'HAILSHAMSOUT',
#  'SOUTHNORMANT',
#  'LYDD',
#  'HATFIELDHEAT',
#  'WHITWELL',
#  'COTONPARK',
#  'SHIREBROOK',
#  'SWANWICK',
#  'ROBERTSBRIDG',
#  'WESTFIELD',
#  'PATELEYBRIDG',
#  'PANGBOURNE',
#  'CLOWNE',
#  'CRESWELL',
#  'IRLAM',
#  'RAINWORTH',
#  'THINGLEY',
#  'BURY',
#  'WARMSWORTH',
#  'SALISBURY',
#  'RINGWOOD',
#  'BOLTON',
#  'BOTTESFORD',
#  'HODSOCK',
#  'BOMEREHEATH',
#  'STANTON',
#  'KINETON',
#  'KILSBY',
#  'LOWERGORNAL',
#  'SILCHESTER',
#  'WOOLTON',
#  'HUDDERSFIELD',
#  'FARNSFIELD',
#  'MARCHINGTON',
#  'WALTHAMOW',
#  'STRONGFORD',
#  'WEOODBROOK',
#  'WIGSTON',
#  'STOKEHEATH',
#  'RAMPTON',
#  'OADBY',
#  'NEWPORT',
#  'MORETONINMAR',
#  'ASCOT',
#  'WITNEY',
#  'WINKLEIGH',
#  'WHETSTONE',
#  'STCOLUMB',
#  'ETWALL',
#  'EDGMOND',
#  'COALEY',
#  'LEEK',
#  'HARVINGTON',
#  'CLAYCROSS',
#  'OXTED',
#  'OLDBUCKENHAM',
#  'LONGSTRATTON',
#  'FLITWICK',
#  'STOKESLEY',
#  'BOWBURN',
#  'FRAMPTON',
#  'HADDENHAM',
#  'LETCHWORTH',
#  'KIBWORTH',
#  'GREATAYTON',
#  'HIBALDSTOW',
#  'HANSLOPE',
#  'CHANTRY',
#  'BURWELL',
#  'BASSINGBOURN',
#  'BENHALL',
#  'SEDGEFIELD',
#  'WATERBEACH',
#  'STIVES',
#  'WITCHAM',
#  'BROUGHTON',
#  'SKELLINGTHOR',
#  'SAWTRY',
#  'OLDHURST',
#  'TUDDENHAM',
#  'UPPINGHAM',
#  'BRANTON',
#  'BLACKMINSTER',
#  'BILSTHORPE',
#  'CROWBOROUGH',
#  'CHURCHSTRETT',
#  'CASTLEDONING',
#  'BURNTWOOD',
#  'AOODBANK',
#  'ALFRETON',
#  'PEMBURY',
#  'CRANBROOK',
#  'FELBRIDGE',
#  'BROADHOLME',
#  'BOTTISHAM',
#  'STANLEYDOWNT',
#  'CHURCHHANBOR',
#  'CASTLECARY',
#  'MERRIOTT',
#  'DORCHESTER',
#  'GLOSSOP',
#  'STANTONHARCO',
#  'ALSAGER',
#  'CONGLETON',
#  'SANDBACH',
#  'MIDDLEWICH',
#  'ECCLES',
#  'HAZELGROVE',
#  'WATHONDEARNE',
#  'KNARESBOROUG',
#  'CARLETON',
#  'NORMANTON',
#  'MELTHAM',
#  'BARWICK',
#  'EGGBOROUGH',
#  'HYDE',
#  'CLITHEROE',
#  'SALFORD',
#  'SPARKFORD',
#  'BLACKBURNMEA',
#  'LEYBURN',
#  'EASINGWOLD',
#  'MOSSLEY',
#  'MARTOCK',
#  'ILCHESTER',
#  'CAWTHORNE',
#  'DRONFIELD',
#  'CUDWORTH',
#  'SOUTHELMSALL',
#  'DUKINFIELD',
#  'ASHTON',
#  'KNUTSFORD',
#  'MILTONUNDERW',
#  'ADWICK',
#  'HAVERHILL',
#  'CLEATOR',
#  'HITCHIN',
#  'KEELBY',
#  'EASTHAMPSTEA',
#  'LISKEARD(LOD',
#  'ULCEBY',
#  'HELSTON',
#  'ACLE',
#  'ALTRINCHAM',
#  'UPMINSTER(BU',
#  'BARNOLDSWICK',
#  'CONEYWESTON',
#  'WHALEYBRIDGE',
#  'COTTESMORE',
#  'MARSTONMORET',
#  'PAPWORTHEVER',
#  'WHITEWALTHAM',
#  'MIDDLETONCHE',
#  'PADDOCKWOOD',
#  'HOLSWORTHY(D',
#  'AYLSHAM',
#  'BRIXWORTH',
#  'BARLESTONE',
#  'ARMTHORPE',
#  'HORWICH',
#  'ASHFORD',
#  'BIDBOROUGH',
#  'TANGMERE',
#  'AYLESFORD',
#  'TONBRIDGE',
#  'STANTONAW',
#  'THURSTON',
#  'SHILLINGTON',
#  'SHENFIELD',
#  'SOUTHHYKEHAM',
#  'EDENBRIDGE',
#  'SADDLEWORTH',
#  'ESHWINNING',
#  'GERRARDSCROS',
#  'DEVIZES',
#  'EVERCREECH',
#  'BOWERHILL',
#  'WARMINSTER',
#  'SOMERTON',
#  'GARSTANG',
#  'ASPATRIA',
#  'LIGHTWATER',
#  'LACEBY',
#  'HOCKFORD',
#  'SWINESHEAD',
#  'WATTON',
#  'SHAMLEYGREEN',
#  'RIPLEYTW',
#  'HALSTEADLANG',
#  'REIGATE',
#  'CRANLEIGH',
#  'CHOBHAM',
#  'BURSTOW',
#  'BARTONLECLAY',
#  'ALFORD',
#  'BRAINTREE',
#  'DODDINGHURST',
#  'DUNHOLME',
#  'ALTON',
#  'NANTWICH',
#  'WISLEY',
#  'MERSTHAM',
#  'HOLMWOOD',
#  'FRAMLINGHAM',
#  'WITCHFORD',
#  'WYMONDHAM',
#  'SISLAND(LODD',
#  'NETTLEHAM',
#  'SWARDESTON',
#  'LOUTH',
#  'HEACHAM',
#  'MARKETHARBOR',
#  'MARKETRASEN',
#  'ISLEHAM',
#  'BEDWORTH',
#  'CROWLE',
#  'DONISTHORPE',
#  'CALVERTON',
#  'BULKINGTON',
#  'UCKFIELD',
#  'WESTBERE',
#  'MALTBY',
#  'KIRTONINLIND',
#  'OVERSEAL',
#  'MELTONMOWBRA',
#  'STOKEPRIOR',
#  'SKEGBY',
#  'WORKSOP(MANT',
#  'HONEYBOURNE',
#  'HINCKLEY',
#  'BROADWAY',
#  'EASTBRIDGFOR',
#  'EDWINSTOWE',
#  'FINDERN',
#  'RAUNDS',
#  'BRACKLEYNEW',
#  'GREATTOTHAM',
#  'ATTLEBOROUGH',
#  'ALCONBURY',
#  'WOOLER',
#  'BISHOPSSTORT',
#  'KESWICK',
#  'CREWE',
#  'HYNDBURN',
#  'BURNLEY',
#  'NORTHWICH',
#  'WINSFORD',
#  'WIGTON',
#  'COCKERMOUTH',
#  'DEREHAM',
#  'BUNGAY',
#  'STOWMARKET',
#  'EASTMARKHAM',
#  'BROMSGROVE',
#  'DISS',
#  'KELLOE',
#  'WORTHINGTON',
#  'SHERBORNESTJ',
#  'WOKINGHAM',
#  'BARTON',
#  'FOXTONCAMBS',
#  'POTTON',
#  'CHORLEY',
#  'INGOLDISTHOR',
#  'BRIGG',
#  'HARTLEYWINTN',
#  'BASINGSTOKE']

# %%
#match_df = pd.DataFrame({'location': match})

#match_df['uwwName'] = match

# %%
#match_df.to_csv('match_df.csv')

# %%
location_clean
# Out:
#            uwwName  ...                                        the_geom
# 0        TANDRAGEE  ...                POINT (-6.404 54.34900003475147)
# 1        FOCHABERS  ...    POINT (-3.101670000000001 57.62433003019494)
# 2        FORFARNEW  ...              POINT (-2.90993 56.64134003165175)
# 3           FORRES  ...  POINT (-3.6110400000000005 57.615410030208444)
# 4     FORTWILLIAMN  ...             POINT (-5.10111 56.828390031379726)
# ...            ...  ...                                             ...
# 1874      SHIPSTON  ...   POINT (-1.6119248140000002 52.06746196731771)
# 1875    SHIREBROOK  ...          POINT (-1.201336165 53.20002695611608)
# 1876    SHREWSBURY  ...   POINT (-2.7144183100000006 52.71772724664599)
# 1877        SKEGBY  ...         POINT (-1.262363474 53.150611586171586)
# 1878   SLADEHOOTON  ...  POINT (-1.2118635069999997 53.393080885896644)
#
# [1878 rows x 4 columns]

# %%
swt_new = swt_data.rename(columns={'TreatmentPlant' : 'uwwName'})

# %%
combo_swt = pd.merge(swt_new, location_clean, how='outer')

# %%
combo_swt
# Out:
#        SampleDateTime  ...                                        the_geom
# 0          2015-11-19  ...  POINT (-0.4353962969999999 53.997922945183134)
# 1          2015-10-09  ...  POINT (-0.4353962969999999 53.997922945183134)
# 2          2015-10-09  ...  POINT (-0.4353962969999999 53.997922945183134)
# 3          2015-10-09  ...  POINT (-0.4353962969999999 53.997922945183134)
# 4          2015-10-09  ...  POINT (-0.4353962969999999 53.997922945183134)
# ...               ...  ...                                             ...
# 632348            NaN  ...  POINT (-2.2947519310000004 54.053262325115924)
# 632349            NaN  ...   POINT (-2.9540717340000002 53.68004387556298)
# 632350            NaN  ...   POINT (-1.6119248140000002 52.06746196731771)
# 632351            NaN  ...   POINT (-2.7144183100000006 52.71772724664599)
# 632352            NaN  ...  POINT (-1.2118635069999997 53.393080885896644)
#
# [632353 rows x 13 columns]

# %%
len(match)

#match
# Out:
# 425

# %%
def rep(df):
  column = df['TreatmentPlant']
  trt = s_names
  ukwp = s_names1

  for x in column:
    for i, j in zip(trt, ukwp):
      if any(j in i for j in ukwp):
        i = j
    x=i 

  return df

#[i for i in trt_p if any(j in i for j in ukwp)]

# %%
rep(swt_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-313be6a0eeaa> in <module>()
# ----> 1 rep(swt_data)
#
# <ipython-input-39-789006714197> in rep(df)
#       6   for x in column:
#       7     for i, j in zip(trt, ukwp):
# ----> 8       if any(j in i for j in ukwp):
#       9         i = j
#      10     x=i
#
# <ipython-input-39-789006714197> in <genexpr>(.0)
#       6   for x in column:
#       7     for i, j in zip(trt, ukwp):
# ----> 8       if any(j in i for j in ukwp):
#       9         i = j
#      10     x=i
#
# KeyboardInterrupt:

# %%
matches = []

for i in trt_p:
    for j in ukwp:
        if i==j:
            matches.append(i)
print(matches)
print(len(matches))
# Out:
# ['DRIFFIELD', 'DEEPINGS', 'HEAGE', 'CANNOCK', 'HILLHOUSE', 'OVER', 'HORNCASTLE', 'LLANGEFNI', 'EASTHARLING', 'DUNSTABLE', 'MAREHAY', 'MILTON', 'GRENDON', 'SLEAFORD', 'STOCKPORT', 'RENISHAW', 'SOHAM', 'STAMFORD', 'ILKESTON', 'DROITWICH', 'PURTON', 'WOODHALLSPA', 'CHALTON', 'RAMSEY', 'AMBERGATE', 'ALVECHURCH', 'STAPLEFORD', 'TOTON', 'HIXON', 'SPERNAL', 'GRESFORD', 'SHERBURNINEL', 'MERIDEN', 'NEWTHORPE', 'PINXTON', 'BOURNE', 'CAMBRIDGE', 'BIDDENDEN', 'CHEWSTOKE', 'HEANOR', 'WARWICK', 'TUNBRIDGEWEL', 'COGGESHALL', 'LYNDHURST', 'SHEPTONMALLE', 'KNITSLEY', 'CROOKHALL', 'ILMINSTER', 'KEYNSHAM', 'TOWLAW', 'CONSETT', 'LINCOLN', 'SHERBURN', 'WOKING', 'OXENHOPE', 'MELBOURNE', 'POCKLINGTON', 'PEGSWOOD', 'WHITCHURCH', 'PELYNT', 'WETHERSFIELD', 'LIDSEY', 'SIDLESHAM', 'FROME', 'KIDDERMINSTE', 'DERBY', 'IBSTOCK', 'MANSFIELD', 'NUNEATON', 'ALDERLEYEDGE', 'STHELENS', 'BIRTLEY', 'BURSCOUGH', 'FORMBY', 'READING', 'AINSDALE', 'LEYLAND', 'AMBLESIDE', 'HEMPNALL', 'CALLINGTON', 'HOLBEACH', 'MABLETHORPE', 'MELBOURN', 'ABINGDON', 'SKELMERSDALE', 'BIDDULPH', 'BOCKING', 'HURLEY', 'NEWMARKET', 'MOBBERLEY', 'LOOE', 'LUTON', 'CORBY', 'LANCHESTER', 'KENDAL', 'TIPTREE', 'WATLINGTON', 'ROYSTON', 'HENLEY', 'SUDBURY', 'WINDERMERE', 'WANTAGE', 'WELLS', 'NEWBURY', 'MARKETWEIGHT', 'LEVEN', 'DARLEY', 'BEVERLEY', 'BALBY', 'FAILSWORTH', 'NAFFERTON', 'ROCHDALE', 'STANFORDRIVE', 'CARLISLE', 'CHERRYBURTON', 'SUTTONBONING', 'STEYNING', 'BENTLEY', 'OLDHAM', 'RATFYN', 'PENRITH', 'WASHWATER', 'HUYTON', 'COLWALL', 'LEIGH', 'NORTHFAL', 'ROSSENDALE', 'LONGHOPE', 'LOUGHBOROUGH', 'WORSLEY', 'WILMSLOW', 'WIDNES', 'TYLDESLEY', 'PICKERING', 'TARVIN', 'RIPLEY', 'HAILSHAMNORT', 'BALSALLCOMMO', 'HAILSHAMSOUT', 'SOUTHNORMANT', 'LYDD', 'HATFIELDHEAT', 'WHITWELL', 'COTONPARK', 'SHIREBROOK', 'SWANWICK', 'ROBERTSBRIDG', 'WESTFIELD', 'PATELEYBRIDG', 'PANGBOURNE', 'CLOWNE', 'CRESWELL', 'IRLAM', 'RAINWORTH', 'THINGLEY', 'BURY', 'WARMSWORTH', 'SALISBURY', 'RINGWOOD', 'BOLTON', 'BOTTESFORD', 'HODSOCK', 'STANTON', 'KINETON', 'KILSBY', 'LOWERGORNAL', 'HUDDERSFIELD', 'FARNSFIELD', 'MARCHINGTON', 'WEOODBROOK', 'WIGSTON', 'STOKEHEATH', 'RAMPTON', 'OADBY', 'MORETONINMAR', 'ASCOT', 'WITNEY', 'WHETSTONE', 'STCOLUMB', 'ETWALL', 'EDGMOND', 'COALEY', 'LEEK', 'HARVINGTON', 'CLAYCROSS', 'OXTED', 'OLDBUCKENHAM', 'LONGSTRATTON', 'FLITWICK', 'STOKESLEY', 'BOWBURN', 'FRAMPTON', 'HADDENHAM', 'LETCHWORTH', 'KIBWORTH', 'GREATAYTON', 'HIBALDSTOW', 'HANSLOPE', 'CHANTRY', 'BURWELL', 'BASSINGBOURN', 'BENHALL', 'SEDGEFIELD', 'WATERBEACH', 'WITCHAM', 'BROUGHTON', 'SKELLINGTHOR', 'SAWTRY', 'OLDHURST', 'TUDDENHAM', 'UPPINGHAM', 'BRANTON', 'BLACKMINSTER', 'BILSTHORPE', 'CROWBOROUGH', 'CHURCHSTRETT', 'CASTLEDONING', 'BURNTWOOD', 'AOODBANK', 'ALFRETON', 'PEMBURY', 'CRANBROOK', 'FELBRIDGE', 'BOTTISHAM', 'CHURCHHANBOR', 'CASTLECARY', 'MERRIOTT', 'DORCHESTER', 'GLOSSOP', 'ALSAGER', 'CONGLETON', 'SANDBACH', 'MIDDLEWICH', 'ECCLES', 'HAZELGROVE', 'WATHONDEARNE', 'KNARESBOROUG', 'CARLETON', 'NORMANTON', 'MELTHAM', 'BARWICK', 'EGGBOROUGH', 'HYDE', 'CLITHEROE', 'SALFORD', 'LEYBURN', 'EASINGWOLD', 'MOSSLEY', 'MARTOCK', 'ILCHESTER', 'DRONFIELD', 'CUDWORTH', 'SOUTHELMSALL', 'DUKINFIELD', 'ASHTON', 'KNUTSFORD', 'MILTONUNDERW', 'HAVERHILL', 'CLEATOR', 'HITCHIN', 'KEELBY', 'EASTHAMPSTEA', 'ULCEBY', 'HELSTON', 'ACLE', 'ALTRINCHAM', 'BARNOLDSWICK', 'CONEYWESTON', 'WHALEYBRIDGE', 'COTTESMORE', 'MARSTONMORET', 'PAPWORTHEVER', 'WHITEWALTHAM', 'MIDDLETONCHE', 'PADDOCKWOOD', 'AYLSHAM', 'BRIXWORTH', 'BARLESTONE', 'ARMTHORPE', 'HORWICH', 'ASHFORD', 'BIDBOROUGH', 'TANGMERE', 'TONBRIDGE', 'THURSTON', 'SHILLINGTON', 'SHENFIELD', 'SOUTHHYKEHAM', 'EDENBRIDGE', 'SADDLEWORTH', 'ESHWINNING', 'GERRARDSCROS', 'DEVIZES', 'EVERCREECH', 'BOWERHILL', 'WARMINSTER', 'SOMERTON', 'GARSTANG', 'ASPATRIA', 'LIGHTWATER', 'LACEBY', 'SWINESHEAD', 'WATTON', 'SHAMLEYGREEN', 'REIGATE', 'CHOBHAM', 'BURSTOW', 'BARTONLECLAY', 'ALFORD', 'BRAINTREE', 'DODDINGHURST', 'DUNHOLME', 'ALTON', 'NANTWICH', 'WISLEY', 'MERSTHAM', 'HOLMWOOD', 'FRAMLINGHAM', 'WITCHFORD', 'WYMONDHAM', 'NETTLEH ...
# 375

# %%
#show null values in combined dataframe
#df[df['Col2'].isnull()]
missing_combo = combo_swt[combo_swt['SampleDateTime'].isnull()]

# %%
len(missing_combo.uwwName.unique())
# Out:
# 1476

# %%
missing_combo.uwwName.unique()
# Out:
# array(['TANDRAGEE', 'FOCHABERS', 'FORFARNEW', ..., 'SHIPSTON',
#        'SHREWSBURY', 'SLADEHOOTON'], dtype=object)

# %%
missing_combo
# Out:
#        SampleDateTime  ...                                        the_geom
# 630860            NaN  ...                POINT (-6.404 54.34900003475147)
# 630861            NaN  ...    POINT (-3.101670000000001 57.62433003019494)
# 630862            NaN  ...              POINT (-2.90993 56.64134003165175)
# 630863            NaN  ...  POINT (-3.6110400000000005 57.615410030208444)
# 630864            NaN  ...             POINT (-5.10111 56.828390031379726)
# ...               ...  ...                                             ...
# 632349            NaN  ...  POINT (-2.2947519310000004 54.053262325115924)
# 632350            NaN  ...   POINT (-2.9540717340000002 53.68004387556298)
# 632351            NaN  ...   POINT (-1.6119248140000002 52.06746196731771)
# 632352            NaN  ...   POINT (-2.7144183100000006 52.71772724664599)
# 632353            NaN  ...  POINT (-1.2118635069999997 53.393080885896644)
#
# [1494 rows x 13 columns]

# %%
good_combo = combo_swt[combo_swt['NameDeterminandName'].notnull()]
#good_combo = good_combo[good_combo['the_geom'].notnull()]

# %%
len(good_combo.uwwName.unique())
# Out:
# 594

# %%
good_missing=good_combo[good_combo['uwwLatitude'].isnull()]

# %%
good_missing
# Out:
#        SampleDateTime      uwwName  ... uwwLongitude the_geom
# 999        2015-04-06     PENYBONT  ...          NaN      NaN
# 1000       2015-04-06     PENYBONT  ...          NaN      NaN
# 1001       2015-04-06     PENYBONT  ...          NaN      NaN
# 1002       2015-04-06     PENYBONT  ...          NaN      NaN
# 1003       2015-04-06     PENYBONT  ...          NaN      NaN
# ...               ...          ...  ...          ...      ...
# 630855     2019-07-10  BERKHAMSTED  ...          NaN      NaN
# 630856     2019-09-25  BERKHAMSTED  ...          NaN      NaN
# 630857     2019-09-25  BERKHAMSTED  ...          NaN      NaN
# 630858     2019-09-25  BERKHAMSTED  ...          NaN      NaN
# 630859     2019-09-25  BERKHAMSTED  ...          NaN      NaN
#
# [229762 rows x 13 columns]

# %%
good_missing.uwwName.unique()
# Out:
# array(['PENYBONT', 'CANWICK', 'DUXFORD', 'RODBOURNE', 'GARFORTH',
#        'FARNHAM', 'CHILTONW', 'AYLESBURY', 'GREATBILLING', 'BLAGDON',
#        'KNOSTROP', 'SEAMER', 'AFAN', 'WHITEPARISH', 'CULHAM',
#        'SNARESTONE', 'SANDFORD', 'ALDERSHOT', 'SNITTERFIELD', 'ANCASTER',
#        'HAYDEN', 'BILLINGHURST', 'MELBOURNEYW', 'MINWORTH', 'PYE',
#        'SUMMERLA(PAG', 'AYCLIFFE', 'WOOLSTONE', 'STAMFORDMD', 'KIRKBY',
#        'DULLINGHAM', 'BARROW', 'BODMIN', 'CHESTERLESTR', 'HOWDON',
#        'DIDCOT', 'NORTONJUXTA', 'STRADISHALL(', 'VINESCROSS', 'NEILEY',
#        'APPLETON', 'LEMONROYD', 'HUSTLEDOWN', 'CHINNOR', 'HORSHAMNEW',
#        'FRADDON', 'CRAWLEY', 'EDENVALEEAST', 'REDLYNCH', 'FAZAKERLEY',
#        'WIGAN', 'FORNHAM', 'SALTFORD', 'CHILTON', 'HOLLOWELL',
#        'CROSCOMBE', 'GTWARFORD', 'PRISBOROUGH', 'THAME', 'WHITLINGHAM(',
#        'MARLOW', 'WORMINGHALL', 'BOURTON', 'RAYLEIGH', 'CHOLSEY',
#        'KINGSCLERE', 'BENSON', 'SLINGSBY', 'FERNHURST', 'RYEMEADS',
#        'BUNTINGFORD', 'BURGHFIELD', 'THERFIELD', 'NEWBURYLANEC',
#        'CHALGROVE', 'KINSON', 'BATTLE', 'THEYDON', 'TRING', 'BURTONOW',
#        'IWERNEMINSTE', 'NEAVESLANE', 'SLOUGH', 'ROUNDHILL', 'OSWESTRY',
#        'PARKROADHAND', 'ICKLESHAM', 'STOKEBARDOLP', 'HARPENDEN', 'EPPING',
#        'HODTHORPE', 'CLAVERING', 'STANSTEADMOU', 'HOGSMILL', 'HOGSMILLB',
#        'WOODSETTS', 'STUBBSLA(BRE', 'STANDON', 'MILLGREEN',
#        'RAWCLIFFEYOR', 'CHIEVELEY', 'ROYALWOOTTON', 'ALDERMASTON',
#        'RAYHALL', 'BOMEREHEATH', 'WADWORTH', 'ALDWARKE', 'WANLIP',
#        'BEDDINGTON', 'SILCHESTER', 'BRENTWOOD', 'GWENNAP(LANN', 'WOOLTON',
#        'HILLAM', 'BECKTON', 'WALTHAMOW', 'STRONGFORD', 'NEWPORT',
#        'FINSTOCK', 'CHADLINGTON', 'WINKLEIGH', 'REDDITCH', 'CROXTONKERRI',
#        'UTTONSDROVE', 'LOGGERHEADS', 'CHEDBURGH', 'TUDHOEMILL',
#        'WILBURTON', 'STIVES', 'SANDHURST', 'HARESTOCK', 'NORTHIAM',
#        'EGRINSTEAD', 'GOOSEBECK', 'HORSMONDEN', 'WADHURST', 'BROADHOLME',
#        'TUNBRIDGES', 'STANLEYDOWNT', 'CLIVE', 'CREWKERNEE',
#        'CHAPELENLEFR', 'STANTONHARCO', 'BRACKNELL', 'DAVYHULME',
#        'NORTHWHEATLE', 'SANDALL', 'CLAYTONWEST', 'SUTTONBP',
#        'RAWCLIFFEGOO', 'RIPPONDEN', 'SMALLEYBIGHT', 'SPARKFORD',
#        'BLACKBURNMEA', 'WOMBWELL', 'LUNDWOOD', 'CAWTHORNE', 'ADWICK',
#        'CIRENCESTER', 'HORNTON', 'LEADENHAM', 'LISKEARD(LOD',
#        'UPMINSTER(BU', 'MAIDENHEAD', 'CAYTHORPE', 'BARNHURST',
#        'HOLSWORTHY(D', 'COTTONVALLEY', 'PITTINGTON', 'BETHERSDEN',
#        'SUTTONVALENC', 'AYLESFORD', 'STANTONAW', 'PITYME', 'WEYBRIDGE',
#        'CHESHAM', 'GODDARDSGREE', 'MEARE', 'IVERNORTH', 'GREATWORTH',
#        'FLEET', 'HOCKFORD', 'RIPLEYTW', 'HALSTEADLANG', 'CRANLEIGH',
#        'BORDON', 'BLACKBIRDS', 'CAMBERLEY', 'CHERTSEY', 'BYFIELD',
#        'SISLAND(LODD', 'MARSTONGRANT', 'RACKHEATH', 'BLYTON', 'WINGHAM',
#        'BRAITHWELL', 'CLAYMILLS', 'YADDLETHORPE', 'THORPESATCHV',
#        'TICKNALL', 'WARTON', 'WILLOUGHTON', 'WORKSOP(MANT', 'BRACKLEYNEW',
#        'SEDGELETCH', 'WARGRAVE', 'ARBORFIELD', 'MENAGWINS(ST',
#        'HIGHWORTH', 'SANDHURSTTW', 'WOKINGHAM', 'KINGSSUTTON', 'BICESTER',
#        'FOXTONCAMBS', 'GTGADDESDEN', 'ASHVALE', 'MAPLELODGE',
#        'BASINGSTOKE', 'BERKHAMSTED'], dtype=object)

# %%
swt_data.SampleDateTime = pd.to_datetime(swt_data.SampleDateTime)
swt_data.SampleDateTime = pd.to_datetime(swt_data.SampleDateTime, format='%m/%d/%Y')

# %%
swt_data.SampleDateTime.max()
# Out:
# Timestamp('2020-12-03 00:00:00')

# %%
import plotly.graph_objs as go
import plotly.express as px

# %%
print (len(swt_data.TreatmentPlant.unique()))
# Out:
# 595

# %%
df_mc = swt_data[swt_data['UnitsName']=='micrograms per litre']

# %%
df_mg = swt_data[swt_data['UnitsName']!='micrograms per litre']

# %%
df_mg.head()
# Out:
#    SampleDateTime  TreatmentPlant SampleDateTime.1  SampleLocationName  \
# 33     2015-04-06  Pen-y-bont STW       2015-04-06  Treatment Effluent
# 54     2015-05-14       Heage STW       2015-05-14  Treatment Effluent
# 56     2015-05-14       Heage STW       2015-05-14  Treatment Effluent
# 58     2015-05-14       Heage STW       2015-05-14  Treatment Effluent
# 59     2015-05-14       Heage STW       2015-05-14  Treatment Effluent
#
#     SampleValue              NameDeterminandName               UnitsName  \
# 33         0.01                         sulphide  milligrammes per litre
# 54         8.07         dissolved organic carbon  milligrammes per litre
# 56         4.39            total phosphorus as P  milligrammes per litre
# 58         3.61  soluble reactive phosphate as P  milligrammes per litre
# 59         1.84         ammoniacal nitrogen as N  milligrammes per litre
#
#    BelowMinReading  Year  Month
# 33             Yes  2015      4
# 54              No  2015      5
# 56              No  2015      5
# 58              No  2015      5
# 59              No  2015      5

# %% [markdown]
# **Steps for Geo Spatial Map Viz**
#
# 1. Obtain Data on location of TreatmentPlant - Long/Lat
# 2. Plot location of TreatmentPlant
# 3. Plot Parameters values on the Map
# 4. Create a slider to change the year of the Data (Timeline)
# 5. Create a Table from the displayed Data.
#
#
# **Steps for Time Series**
#
# 1. Separate data by their units i.e, micro and milli and then;
# 2. Separate data by quality parameters i.e by 'NameDeterminandName' column and
# 3. Create dataFrame for each unique item in 'NameDeterminandName' column
# 4. Plot Time Series line graph for each Parameter and name of lines as all(or selected) unique values in 'TreatmentPlants'
# 5. Fix the x-axis as a time Range from 2015 - 2020
#
# **Other Plot** -
# after (1) above;
#
# 1. Plot Time Series line graph for all (or selected) TreatmentPlant with all the parameters as lines

# %%
#print (len(df_mg.SampleDateTime.unique()))
# Out:
# 1306

# %%
print(len(df_mc.NameDeterminandName.unique()), len(df_mg.NameDeterminandName.unique()))
# Out:
# 65 13

# %%
#Function to name the DataFrames automatically 
def name_df(data_frame):
    
    parameters = data_frame.NameDeterminandName.unique()

    name = []

    for parameter in parameters:
        if len(parameter) >= 10:
            parameter = parameter [:-6]
        else:
            parameter = parameter[:6]
    
        name.append(parameter)

    name = [i.replace(" ", "_")  for i in name]

    name = [i + '_df' for i in name]

              
    return name, parameters #dictionary of name and parameters

# %%
#function to generate DataFrames based on the quality parameters

def generate_df(df, parameter):
    dataf = df[df['NameDeterminandName'] == parameter]
    dataf = dataf[['SampleDateTime', 'TreatmentPlant', 'SampleValue', 'NameDeterminandName', 'UnitsName','BelowMinReading' ]]

    return dataf

# %%
def create_df(dataF):
    name, parameters = name_df(dataF)     
    
    dict_name = dict(zip(name, parameters))

    dfs = [i for i in dict_name.keys()]
    
    for i in range(len(dfs)):
        dfs[i] = generate_df(dataF, parameters[i])

    comb = dict(zip(name, dfs)) #combine name and dataframes into dictionary
    
    return comb

# %%
#Function to return individual DataFrames with appropraite names

def separated_df(dframe):
    i_dfs = create_df(dframe)
    for key, val in i_dfs.items():
        exec(key + '=val')

# %%
separated_df(df_mc)

# %%
triclo_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-190-6d48724ed517> in <module>
# ----> 1 triclo_df
#
# NameError: name 'triclo_df' is not defined

# %%
create_df(df_mc)
# Out:
# {'triclo_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  0          2015-11-19     Driffield STW        0.014           triclosan
#  53         2015-09-29      Deepings STW        0.130           triclosan
#  74         2015-05-14         Heage STW        0.100           triclosan
#  105        2015-04-06    Pen-y-bont STW        0.062           triclosan
#  149        2015-12-15       Canwick STW        0.080           triclosan
#  ...               ...               ...          ...                 ...
#  637923     2020-02-24         Brigg STW        0.019           triclosan
#  637962     2020-06-02          Diss STW        0.020           triclosan
#  637999     2020-02-19     Nettleham STW        0.010           triclosan
#  638072     2020-02-18  Brackley New STW        0.010           triclosan
#  638115     2020-01-28     Nettleham STW        0.010           triclosan
#
#                     UnitsName BelowMinReading
#  0       micrograms per litre             Yes
#  53      micrograms per litre              No
#  74      micrograms per litre             Yes
#  105     micrograms per litre              No
#  149     micrograms per litre              No
#  ...                      ...             ...
#  637923  micrograms per litre              No
#  637962  micrograms per litre              No
#  637999  micrograms per litre             Yes
#  638072  micrograms per litre             Yes
#  638115  micrograms per litre             Yes
#
#  [12363 rows x 6 columns],
#  'BDE_99_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  1          2015-04-06    Pen-y-bont STW       0.0005              BDE 99
#  14         2015-09-29      Deepings STW       0.0000              BDE 99
#  137        2015-12-15       Canwick STW       0.0000              BDE 99
#  277        2015-07-07       Duxford STW       0.0000              BDE 99
#  302        2015-06-18       Cannock STW       0.0000              BDE 99
#  ...               ...               ...          ...                 ...
#  637854     2020-04-02         Brigg STW       0.0005              BDE 99
#  637881     2020-02-01         Brigg STW       0.0005              BDE 99
#  637974     2020-06-02          Diss STW       0.0005              BDE 99
#  638037     2020-02-18  Brackley New STW       0.0005              BDE 99
#  638080     2020-01-28     Nettleham STW       0.0005              BDE 99
#
#                     UnitsName BelowMinReading
#  1       micrograms per litre             Yes
#  14      micrograms per litre             Yes
#  137     micrograms per litre             Yes
#  277     micrograms per litre             Yes
#  302     micrograms per litre             Yes
#  ...                      ...             ...
#  637854  micrograms per litre             Yes
#  637881  micrograms per litre             Yes
#  637974  micrograms per litre             Yes
#  638037  micrograms per litre             Yes
#  638080  micrograms per litre             Yes
#
#  [12324 rows x 6 columns],
#  'BDE_10_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  2          2015-04-06    Pen-y-bont STW       0.0005             BDE 100
#  15         2015-09-29      Deepings STW       0.0000             BDE 100
#  138        2015-12-15       Canwick STW       0.0000             BDE 100
#  288        2015-07-07       Duxford STW       0.0000             BDE 100
#  303        2015-06-18       Cannock STW       0.0000             BDE 100
#  ...               ...               ...          ...                 ...
#  637855     2020-04-02         Brigg STW       0.0005             BDE 100
#  637880     2020-02-01         Brigg STW       0.0005             BDE 100
#  637973     2020-06-02          Diss STW       0.0005             BDE 100
#  638036     2020-02-18  Brackley New STW       0.0005             BDE 100
#  638079     2020-01-28     Nettleham STW       0.0005             BDE 100
#
#                     UnitsName BelowMinReading
#  2       micrograms per litre             Yes
#  15      micrograms per litre             Yes
#  138     micrograms per litre             Yes
#  288     micrograms per litre             Yes
#  303     micrograms per litre             Yes
#  ...                      ...             ...
#  637855  micrograms per litre             Yes
#  637880  micrograms per litre             Yes
#  637973  micrograms per litre             Yes
#  638036  micrograms per litre             Yes
#  638079  micrograms per litre             Yes
#
#  [12331 rows x 6 columns],
#  'BDE_15_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  4          2015-04-06    Pen-y-bont STW       0.0005             BDE 154
#  17         2015-09-29      Deepings STW       0.0000             BDE 154
#  140        2015-12-15       Canwick STW       0.0000             BDE 154
#  279        2015-07-07       Duxford STW       0.0000             BDE 154
#  305        2015-06-18       Cannock STW       0.0000             BDE 154
#  ...               ...               ...          ...                 ...
#  637857     2020-04-02         Brigg STW       0.0005             BDE 154
#  637878     2020-02-01         Brigg STW       0.0005             BDE 154
#  637971     2020-06-02          Diss STW       0.0005             BDE 154
#  638034     2020-02-18  Brackley New STW       0.0005             BDE 154
#  638097     2020-01-28     Nettleham STW       0.0005             BDE 154
#
#                     UnitsName BelowMinReading
#  4       micrograms per litre             Yes
#  17      micrograms per litre             Yes
#  140     micrograms per litre             Yes
#  279     micrograms per litre             Yes
#  305     micrograms per litre             Yes
#  ...                      ...             ...
#  637857  micrograms per litre             Yes
#  637878  micrograms per litre             Yes
#  637971  micrograms per litre             Yes
#  638034  micrograms per litre             Yes
#  638097  micrograms per litre             Yes
#
#  [12331 rows x 6 columns],
#  'ethinyloestradi_df':        SampleDateTime  TreatmentPlant  SampleValue    NameDeterminandName  \
#  5          2015-04-06  Pen-y-bont STW     0.000030  ethinyloestradiol 17a
#  111        2015-12-15     Canwick STW     0.000000  ethinyloestradiol 17a
#  545        2015-03-31    Garforth STW     0.000490  ethinyloestradiol 17a
#  675        2015-11-12  Horncastle STW     0.000000  ethinyloestradiol 17a
#  802        2015-11-17     Farnham STW     0.001430  ethinyloestradiol 17a
#  ...               ...             ...          ...                    ...
#  384550     2017-10-17   Rye Meads STW     0.000060  ethinyloestradiol 17a
#  396838     2017-01-30       Corby STW     0.000015  ethinyloestradiol 17a
#  398428     2017-01-17   Dunstable STW     0.000000  ethinyloestradiol 17a
#  497290     2018-03-13      Wisley STW     0.000330  ethinyloestradiol 17a
#  510598     2018-03-13   Weybridge STW     0.000400  ethinyloestradiol 17a
#
#                     UnitsName BelowMinReading
#  5       micrograms per litre             Yes
#  111     micrograms per litre              No
#  545     micrograms per litre              No
#  675     micrograms per litre              No
#  802     micrograms per litre              No
#  ...                      ...             ...
#  384550  micrograms per litre              No
#  396838  micrograms per litre             Yes
#  398428  micrograms per litre              No
#  497290  micrograms per litre              No
#  510598  micrograms per litre              No
#
#  [991 rows x 6 columns],
#  'cyperm_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  6          2015-04-06    Pen-y-bont STW     0.000010        cypermethrin
#  80         2015-09-29      Deepings STW     0.000000        cypermethrin
#  150        2015-12-15       Canwick STW     0.000000        cypermethrin
#  306        2015-06-18       Cannock STW     0.000000        cypermethrin
#  350        2015-05-14         Heage STW     0.000000        cypermethrin
#  ...               ...               ...          ...                 ...
#  637910     2020-02-04       Dereham STW     0.000097        cypermethrin
#  637961     2020-06-02          Diss STW     0.000080        cypermethrin
#  637998     2020-02-19     Nettleham STW     0.000080        cypermethrin
#  638071     2020-02-18  Brackley New STW     0.000080        cypermethrin
#  638114     2020-01-28     Nettleham STW     0.000080        cypermethrin
#
#                     UnitsName BelowMinReading
#  6       micrograms per litre             Yes
#  80      micrograms per litre              No
#  150     micrograms per litre              No
#  306     micrograms per litre             Yes
#  350     micrograms per litre              No
#  ...                      ...             ...
#  637910  micrograms per litre              No
#  637961  micrograms per litre             Yes
#  637998  micrograms per litre             Yes
#  638071  micrograms per litre             Yes
#  638114  micrograms per litre             Yes
#
#  [12279 rows x 6 columns],
#  'aluminium_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  7          2015-09-29    Deepings STW        34.00     aluminium total
#  96         2015-05-14       Heage STW        62.80     aluminium total
#  203        2015-04-06  Pen-y-bont STW        10.00     aluminium total
#  238        2015-06-18     Cannock STW        44.60     aluminium total
#  251        2015-04-29     Cannock STW        46.70     aluminium total
#  ...               ...             ...          ...                 ...
#  637821     2020-02-04     Dereham STW         6.63     aluminium total
#  637847     2020-04-02       Brigg STW        70.30     aluminium total
#  637887     2020-02-01       Brigg STW        49.90     aluminium total
#  637980     2020-06-02        Diss STW        34.50     aluminium total
#  638011     2020-01-28   Nettleham STW        22.30     aluminium total
#
#                     UnitsName BelowMinReading
#  7       micrograms per litre              No
#  96      micrograms per litre              No
#  203     micrograms per litre             Yes
#  238     micrograms per litre              No
#  251     micrograms per litre              No
#  ...                      ...             ...
#  637821  micrograms per litre             Yes
#  637847  micrograms per litre              No
#  637887  micrograms per litre              No
#  637980  micrograms per litre              No
#  638011  micrograms per litre              No
#
#  [12365 rows x 6 columns],
#  'aluminium_re_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  8          2015-09-29      Deepings STW          6.0  aluminium reactive
#  57         2015-05-14         Heage STW          4.0  aluminium reactive
#  184        2015-04-06    Pen-y-bont STW          3.0  aluminium reactive
#  215        2015-06-18       Cannock STW         16.9  aluminium reactive
#  246        2015-04-29       Cannock STW         14.4  aluminium reactive
#  ...               ...               ...          ...                 ...
#  637807     2020-02-18  Brackley New STW          4.0  aluminium reactive
#  637848     2020-04-02         Brigg STW         10.0  aluminium reactive
#  637867     2020-02-01         Brigg STW         13.0  aluminium reactive
#  637960     2020-06-02          Diss STW          6.0  aluminium reactive
#  638086     2020-01-28     Nettleham STW          4.0  aluminium reactive
#
#                     UnitsName BelowMinReading
#  8       micrograms per litre              No
#  57      micrograms per litre             Yes
#  184     micrograms per litre             Yes
#  215     micrograms per litre              No
#  246     micrograms per litre              No
#  ...                      ...             ...
#  637807  micrograms per litre             Yes
#  637848  micrograms per litre              No
#  637867  micrograms per litre              No
#  637960  micrograms per litre              No
#  638086  micrograms per litre             Yes
#
#  [12351 rows x 6 columns],
#  'chromium_dis_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  9          2015-09-29      Deepings STW        0.520  chromium dissolved
#  67         2015-05-14         Heage STW        0.500  chromium dissolved
#  171        2015-04-06    Pen-y-bont STW        0.400  chromium dissolved
#  235        2015-06-18       Cannock STW        2.110  chromium dissolved
#  271        2015-07-07       Duxford STW        0.620  chromium dissolved
#  ...               ...               ...          ...                 ...
#  637806     2020-02-18  Brackley New STW        0.515  chromium dissolved
#  637849     2020-04-02         Brigg STW        0.515  chromium dissolved
#  637886     2020-02-01         Brigg STW        0.515  chromium dissolved
#  637979     2020-06-02          Diss STW        0.540  chromium dissolved
#  638085     2020-01-28     Nettleham STW        0.515  chromium dissolved
#
#                     UnitsName BelowMinReading
#  9       micrograms per litre             Yes
#  67      micrograms per litre             Yes
#  171     micrograms per litre              No
#  235     micrograms per litre              No
#  271     micrograms per litre              No
#  ...                      ...             ...
#  637806  micrograms per litre             Yes
#  637849  micrograms per litre             Yes
#  637886  micrograms per litre             Yes
#  637979  micrograms per litre              No
#  638085  micrograms per litre             Yes
#
#  [12315 rows x 6 columns],
#  'chromium_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  10         2015-09-29      Deepings STW        0.550      chromium total
#  68         2015-05-14         Heage STW        0.500      chromium total
#  133        2015-12-15       Canwick STW        0.520      chromium total
#  182        2015-04-06    Pen-y-bont STW        0.400      chromium total
#  224        2015-06-18       Cannock STW        2.780      chromium total
#  ...               ...               ...          ...                 ...
#  637850     2020-04-02         Brigg STW        0.515      chromium total
#  637885     2020-02-01         Brigg STW        0.515      chromium total
#  637978     2020-06-02          Diss STW        0.515      chromium total
#  638041     2020-02-18  Brackley New STW        0.515      chromium total
#  638084     2020-01-28     Nettleham STW        0.515      chromium total
#
#                     UnitsName BelowMinReading
#  10      micrograms per litre              No
#  68      micrograms per litre             Yes
#  133     micrograms per litre             Yes
#  182     micrograms per litre              No
#  224     micrograms per litre              No
#  ...                      ...             ...
#  637850  micrograms per litre             Yes
#  637885  micrograms per litre             Yes
#  637978  micrograms per litre             Yes
#  638041  micrograms per litre             Yes
#  638084  micrograms per litre             Yes
#
#  [12370 rows x 6 columns],
#  'BDE_47_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  11         2015-04-06    Pen-y-bont STW     0.000500              BDE 47
#  13         2015-09-29      Deepings STW     0.000000              BDE 47
#  136        2015-12-15       Canwick STW     0.000000              BDE 47
#  275        2015-07-07       Duxford STW     0.000000              BDE 47
#  301        2015-06-18       Cannock STW     0.000000              BDE 47
#  ...               ...               ...          ...                 ...
#  637853     2020-04-02         Brigg STW     0.000640              BDE 47
#  637882     2020-02-01         Brigg STW     0.000500              BDE 47
#  637975     2020-06-02          Diss STW     0.000500              BDE 47
#  638038     2020-02-18  Brackley New STW     0.000500              BDE 47
#  638081     2020-01-28     Nettleham STW     0.000509              BDE 47
#
#                     UnitsName BelowMinReading
#  11      micrograms per litre             Yes
#  13      micrograms per litre             Yes
#  136     micrograms per litre             Yes
#  275     micrograms per litre             Yes
#  301     micrograms per litre             Yes
#  ...                      ...             ...
#  637853  micrograms per litre              No
#  637882  micrograms per litre             Yes
#  637975  micrograms per litre             Yes
#  638038  micrograms per litre             Yes
#  638081  micrograms per litre              No
#
#  [12273 rows x 6 columns],
#  'diethylhexylpht_df':        SampleDateTime    TreatmentPlant  SampleValue    NameDeterminandName  \
#  12         2015-09-29      Deepings STW        0.750  diethylhexylphthalate
#  63         2015-05-14         Heage STW        1.290  diethylhexylphthalate
#  134        2015-12-15       Canwick STW        0.940  diethylhexylphthalate
#  168        2015-04-06    Pen-y-bont STW        0.800  diethylhexylphthalate
#  229        2015-06-18       Cannock STW        0.300  diethylhexylphthalate
#  ...               ...               ...          ...                    ...
#  637851     2020-04-02         Brigg STW        1.170  diethylhexylphthalate
#  637884     2020-02-01         Brigg STW        0.561  diethylhexylphthalate
#  637977     2020-06-02          Diss STW        0.454  diethylhexylphthalate
#  638040     2020-02-18  Brackley New STW        0.200  diethylhexylphthalate
#  638083     2020-01-28     Nettleham STW        0.200  diethylhexylphthalate
#
#                     UnitsName BelowMinReading
#  12      micrograms per litre              No
#  63      micrograms per litre              No
#  134     micrograms per litre              No
#  168     micrograms per litre              No
#  229     micrograms per litre             Yes
#  ...                      ...             ...
#  637851  micrograms per litre              No
#  637884  micrograms per litre              No
#  637977  micrograms per litre              No
#  638040  micrograms per litre             Yes
#  638083  micrograms per litre             Yes
#
#  [12310 rows x 6 columns],
#  'PFOS_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  18         2015-09-29      Deepings STW      0.01000                PFOS
#  44         2015-04-06    Pen-y-bont STW      0.00408                PFOS
#  141        2015-12-15       Canwick STW      0.02000                PFOS
#  264        2015-06-18       Cannock STW      0.01000                PFOS
#  280        2015-07-07       Duxford STW      9.81000                PFOS
#  ...               ...               ...          ...                 ...
#  637858     2020-04-02         Brigg STW      0.00789                PFOS
#  637877     2020-02-01         Brigg STW      0.00999                PFOS
#  637970     2020-06-02          Diss STW      0.00253                PFOS
#  638033     2020-02-18  Brackley New STW      0.00221                PFOS
#  638098     2020-01-28     Nettleham STW      0.00176                PFOS
#
#                     UnitsName BelowMinReading
#  18      micrograms per litre              No
#  44      micrograms per litre              No
#  141     micrograms per litre              No
#  264     micrograms per litre              No
#  280     micrograms per litre              No
#  ...                      ...             ...
#  637858  micrograms per litre              No
#  637877  micrograms per litre              No
#  637970  micrograms per litre              No
#  638033  micrograms per litre              No
#  638098  micrograms per litre              No
#
#  [12347 rows x 6 columns],
#  'PFOA_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  19         2015-09-29      Deepings STW      0.00000                PFOA
#  45         2015-04-06    Pen-y-bont STW      0.00298                PFOA
#  142        2015-12-15       Canwick STW      0.01000                PFOA
#  212        2015-05-14         Heage STW      0.00000                PFOA
#  281        2015-07-07       Duxford STW      0.24000                PFOA
#  ...               ...               ...          ...                 ...
#  637859     2020-04-02         Brigg STW      0.00426                PFOA
#  637876     2020-02-01         Brigg STW      0.00694                PFOA
#  637969     2020-06-02          Diss STW      0.00257                PFOA
#  638032     2020-02-18  Brackley New STW      0.00172                PFOA
#  638099     2020-01-28     Nettleham STW      0.00113                PFOA
#
#                     UnitsName BelowMinReading
#  19      micrograms per litre              No
#  45      micrograms per litre              No
#  142     micrograms per litre              No
#  212     micrograms per litre              No
#  281     micrograms per litre              No
#  ...                      ...             ...
#  637859  micrograms per litre              No
#  637876  micrograms per litre              No
#  637969  micrograms per litre              No
#  638032  micrograms per litre              No
#  638099  micrograms per litre              No
#
#  [12342 rows x 6 columns],
#  'HCBDD_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  20         2015-09-29      Deepings STW      0.01000               HCBDD
#  25         2015-04-06    Pen-y-bont STW      0.00023               HCBDD
#  72         2015-05-14         Heage STW      0.03000               HCBDD
#  143        2015-12-15       Canwick STW      0.01000               HCBDD
#  265        2015-06-18       Cannock STW      0.01000               HCBDD
#  ...               ...               ...          ...                 ...
#  637860     2020-04-02         Brigg STW      0.00775               HCBDD
#  637875     2020-02-01         Brigg STW      0.00960               HCBDD
#  637968     2020-06-02          Diss STW      0.00197               HCBDD
#  638031     2020-02-18  Brackley New STW      0.00575               HCBDD
#  638100     2020-01-28     Nettleham STW      0.00222               HCBDD
#
#                     UnitsName BelowMinReading
#  20      micrograms per litre              No
#  25      micrograms per litre             Yes
#  72      micrograms per litre              No
#  143     micrograms per litre              No
#  265     micrograms per litre              No
#  ...                      ...             ...
#  637860  micrograms per litre              No
#  637875  micrograms per litre              No
#  637968  micrograms per litre              No
#  638031  micrograms per litre              No
#  638100  micrograms per litre              No
#
#  [12340 rows x 6 columns],
#  'Nonyl_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  21         2015-09-29      Deepings STW         0.17         Nonylphenol
#  76         2015-05-14         Heage STW         0.26         Nonylphenol
#  144        2015-12-15       Canwick STW         0.10         Nonylphenol
#  174        2015-04-06    Pen-y-bont STW         0.21         Nonylphenol
#  230        2015-06-18       Cannock STW         0.10         Nonylphenol
#  ...               ...               ...          ...                 ...
#  637874     2020-02-01         Brigg STW         0.10         Nonylphenol
#  637967     2020-06-02          Diss STW         0.12         Nonylphenol
#  638050     2020-02-18  Brackley New STW         0.10         Nonylphenol
#  638075     2020-02-19     Nettleham STW         0.10         Nonylphenol
#  638120     2020-01-28     Nettleham STW         0.13         Nonylphenol
#
#                     UnitsName BelowMinReading
#  21      micrograms per litre              No
#  76      micrograms per litre              No
#  144     micrograms per litre             Yes
#  174     micrograms per litre              No
#  230     micrograms per litre             Yes
#  ...                      ...             ...
#  637874  micrograms per litre             Yes
#  637967  micrograms per litre              No
#  638050  micrograms per litre             Yes
#  638075  micrograms per litre             Yes
#  638120  micrograms per litre              No
#
#  [12321 rows x 6 columns],
#  'Octylph_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  22         2015-09-29      Deepings STW        0.100       Octylphenols
#  106        2015-04-06    Pen-y-bont STW        0.074       Octylphenols
#  145        2015-12-15       Canwick STW        0.100       Octylphenols
#  231        2015-06-18       Cannock STW        0.100       Octylphenols
#  284        2015-07-07       Duxford STW        0.100       Octylphenols
#  ...               ...               ...          ...                 ...
#  637873     2020-02-01         Brigg STW        0.100       Octylphenols
#  637895     2020-02-04       Dereham STW        0.100       Octylphenols
#  637966     2020-06-02          Diss STW        0.100       Octylphenols
#  638051     2020-02-18  Brackley New STW        0.100       Octylphenols
#  638119     2020-01-28     Nettleham STW        0.100       Octylphenols
#
#                     UnitsName BelowMinReading
#  22      micrograms per litre             Yes
#  106     micrograms per litre              No
#  145     micrograms per litre             Yes
#  231     micrograms per litre             Yes
#  284     micrograms per litre             Yes
#  ...                      ...             ...
#  637873  micrograms per litre             Yes
#  637895  micrograms per litre             Yes
#  637966  micrograms per litre             Yes
#  638051  micrograms per litre             Yes
#  638119  micrograms per litre             Yes
#
#  [12305 rows x 6 columns],
#  'BDE28_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  23         2015-09-29      Deepings STW       0.0000               BDE28
#  24         2015-04-06    Pen-y-bont STW       0.0005               BDE28
#  135        2015-12-15       Canwick STW       0.0000               BDE28
#  274        2015-07-07       Duxford STW       0.0000               BDE28
#  300        2015-06-18       Cannock STW       0.0000               BDE28
#  ...               ...               ...          ...                 ...
#  637852     2020-04-02         Brigg STW       0.0005               BDE28
#  637883     2020-02-01         Brigg STW       0.0005               BDE28
#  637976     2020-06-02          Diss STW       0.0005               BDE28
#  638039     2020-02-18  Brackley New STW       0.0005               BDE28
#  638082     2020-01-28     Nettleham STW       0.0005               BDE28
#
#                     UnitsName BelowMinReading
#  23      micrograms per litre             Yes
#  24      micrograms per litre             Yes
#  135     micrograms per litre             Yes
#  274     micrograms per litre             Yes
#  300     micrograms per litre             Yes
#  ...                      ...             ...
#  637852  micrograms per litre             Yes
#  637883  micrograms per litre             Yes
#  637976  micrograms per litre             Yes
#  638039  micrograms per litre             Yes
#  638082  micrograms per litre             Yes
#
#  [12330 rows x 6 columns],
#  'oestradi_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  26         2015-04-06  Pen-y-bont STW      0.00030      oestradiol 17b
#  110        2015-12-15     Canwick STW      0.00000      oestradiol 17b
#  544        2015-03-31    Garforth STW      0.00490      oestradiol 17b
#  674        2015-11-12  Horncastle STW      0.00000      oestradiol 17b
#  801        2015-11-17     Farnham STW      0.00030      oestradiol 17b
#  ...               ...             ...          ...                 ...
#  384549     2017-10-17   Rye Meads STW      0.00090      oestradiol 17b
#  396837     2017-01-30       Corby STW      0.00138      oestradiol 17b
#  398429     2017-01-17   Dunstable STW      0.00000      oestradiol 17b
#  497291     2018-03-13      Wisley STW      0.00280      oestradiol 17b
#  510597     2018-03-13   Weybridge STW      0.00440      oestradiol 17b
#
#                     UnitsName BelowMinReading
#  26      micrograms per litre             Yes
#  110     micrograms per litre              No
#  544     micrograms per litre              No
#  674     micrograms per litre              No
#  801     micrograms per litre              No
#  ...                      ...             ...
#  384549  micrograms per litre              No
#  396837  micrograms per litre              No
#  398429  micrograms per litre              No
#  497291  micrograms per litre              No
#  510597  micrograms per litre              No
#
#  [992 rows x 6 columns],
#  'azithr_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  27         2015-04-06  Pen-y-bont STW       0.0560        azithromycin
#  121        2015-12-15     Canwick STW       0.2200        azithromycin
#  583        2015-03-31    Garforth STW       0.0692        azithromycin
#  685        2015-11-12  Horncastle STW       0.5500        azithromycin
#  812        2015-11-17     Farnham STW       0.1870        azithromycin
#  ...               ...             ...          ...                 ...
#  396774     2017-01-30       Corby STW       0.3580        azithromycin
#  398336     2017-01-17   Dunstable STW       0.7600        azithromycin
#  497260     2018-03-13      Wisley STW       0.1270        azithromycin
#  510608     2018-03-13   Weybridge STW       0.2190        azithromycin
#  527970     2018-03-13   Ripley Tw STW       0.1700        azithromycin
#
#                     UnitsName BelowMinReading
#  27      micrograms per litre              No
#  121     micrograms per litre              No
#  583     micrograms per litre              No
#  685     micrograms per litre              No
#  812     micrograms per litre              No
#  ...                      ...             ...
#  396774  micrograms per litre              No
#  398336  micrograms per litre              No
#  497260  micrograms per litre              No
#  510608  micrograms per litre              No
#  527970  micrograms per litre              No
#
#  [1015 rows x 6 columns],
#  'prop_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  28         2015-04-06  Pen-y-bont STW        0.050          propanolol
#  118        2015-12-15     Canwick STW        0.220          propanolol
#  551        2015-03-31    Garforth STW        0.271          propanolol
#  681        2015-11-12  Horncastle STW        0.150          propanolol
#  808        2015-11-17     Farnham STW        0.190          propanolol
#  ...               ...             ...          ...                 ...
#  396731     2017-01-30       Corby STW        0.224          propanolol
#  398340     2017-01-17   Dunstable STW        0.360          propanolol
#  497284     2018-03-13      Wisley STW        0.130          propanolol
#  510604     2018-03-13   Weybridge STW        0.110          propanolol
#  527974     2018-03-13   Ripley Tw STW        0.080          propanolol
#
#                     UnitsName BelowMinReading
#  28      micrograms per litre              No
#  118     micrograms per litre              No
#  551     micrograms per litre              No
#  681     micrograms per litre              No
#  808     micrograms per litre              No
#  ...                      ...             ...
#  396731  micrograms per litre              No
#  398340  micrograms per litre              No
#  497284  micrograms per litre              No
#  510604  micrograms per litre              No
#  527974  micrograms per litre              No
#
#  [1015 rows x 6 columns],
#  'cadmium_dis_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  29         2015-04-06    Pen-y-bont STW        0.040   cadmium dissolved
#  70         2015-05-14         Heage STW        0.120   cadmium dissolved
#  291        2015-07-07       Duxford STW        0.090   cadmium dissolved
#  315        2015-06-18       Cannock STW        0.010   cadmium dissolved
#  323        2015-07-07         Heage STW        0.110   cadmium dissolved
#  ...               ...               ...          ...                 ...
#  637815     2020-02-18  Brackley New STW        0.022   cadmium dissolved
#  637828     2020-02-04       Dereham STW        0.022   cadmium dissolved
#  637942     2020-06-02          Diss STW        0.022   cadmium dissolved
#  638018     2020-01-28     Nettleham STW        0.022   cadmium dissolved
#  638044     2020-07-02     Nettleham STW        0.022   cadmium dissolved
#
#                     UnitsName BelowMinReading
#  29      micrograms per litre              No
#  70      micrograms per litre              No
#  291     micrograms per litre              No
#  315     micrograms per litre              No
#  323     micrograms per litre              No
#  ...                      ...             ...
#  637815  micrograms per litre             Yes
#  637828  micrograms per litre             Yes
#  637942  micrograms per litre             Yes
#  638018  micrograms per litre             Yes
#  638044  micrograms per litre             Yes
#
#  [12370 rows x 6 columns],
#  'cadmium_df':        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
#  30         2015-04-06    Pen-y-bont STW        0.040       cadmium total
#  66         2015-05-14         Heage STW        0.190       cadmium total
#  290        2015-07-07       Duxford STW        0.140       cadmium total
#  292        2015-06-18       Cannock STW        0.010       cadmium total
#  326        2015-07-07         Heage STW        0.130       cadmium total
#  ...               ...               ...          ...                 ...
#  637814     2020-02-18  Brackley New STW        0.022       cadmium total
#  637827     2020-02-04       Dereham STW        0.022       cadmium total
#  637941     2020-06-02          Diss STW        0.025       cadmium total
#  638027     2020-01-28     Nettleham STW        0.022       cadmium total
#  638043     2020-07-02     Nettleham STW        0.041       cadmium total
#
#                     UnitsName BelowMinReading
#  30      micrograms per litre              No
#  66      micrograms per litre              No
#  290     micrograms per litre              No
#  292     micrograms per litre              No
#  326     micrograms per litre              No
#  ...                      ...             ...
#  637814  micrograms per litre             Yes
#  637827  micrograms per litre              No
#  637941  micrograms per litre              No
#  638027  micrograms per litre             Yes
#  638043  micrograms per litre              No
#
#  [12374 rows x 6 columns],
#  'tri_nonylphenol_ethox_df':        SampleDateTime    TreatmentPlant  SampleValue  \
#  31         2015-04-06    Pen-y-bont STW         0.02
#  75         2015-05-14         Heage STW         0.10
#  93         2015-09-29      Deepings STW         0.06
#  190        2015-12-15       Canwick STW         0.09
#  262        2015-06-18       Cannock STW         0.10
#  ...               ...               ...          ...
#  637951     2020-05-03          Diss STW         0.05
#  637984     2020-02-19     Nettleham STW         0.05
#  638057     2020-02-18  Brackley New STW         0.05
#  638077     2020-01-28     Nettleham STW         0.05
#  638087     2020-06-02          Diss STW         0.05
#
#                  NameDeterminandName             UnitsName BelowMinReading
#  31      tri nonylphenol ethoxylates  micrograms per litre             Yes
#  75      tri nonylphenol ethoxylates  micrograms per litre             Yes
#  93      tri nonylphenol ethoxylates  micrograms per litre              No
#  190     tri nonylphenol ethoxylates  micrograms per litre              No
#  262     tri nonylphenol ethoxylates  micrograms per litre             Yes
#  ...                             ...                   ...             ...
#  637951  tri nonylphenol ethoxylates  micrograms per litre             Yes
#  637984  tri nonylphenol ethoxylates  micrograms per litre             Yes
#  638057  tri nonylphenol ethoxylates  micrograms per litre             Yes
#  638077  tri nonylphenol ethoxylates  micrograms per litre             Yes
#  638087  tri nonylphenol ethoxylates  micrograms per litre             Yes
#
#  [10966 rows x 6 columns],
#  'di_nonylphenol_ethox_df':        SampleDateTime    TreatmentPlant  SampleValue  \
#  32         2015-04-06    Pen-y-bont STW         0.02
#  69         2015-05-14         Heage STW         0.14
#  92         2015-09-29      Deepings STW         0.11
#  189        2015-12-15       Canwick STW         0.10
#  234        2015-06-18       Cannock STW         0.10
#  ...               ...               ...          ...
#  637985     2020-02-19     Nettleham STW         0.05
#  638058     2020-02-18  Brackley New STW         0.05
#  638088     2020-06-02          Diss STW         0.05
#  638101     2020-01-28     Nettleham STW         0.05
#  638122     2020-01-30       Heacham STW         0.05
#
#                 NameDeterminandName             UnitsName BelowMinReading
#  32      di nonylphenol ethoxylates  micrograms per litre              No
#  69      di nonylphenol ethoxylates  micrograms per litre              No
#  92      di nonylphenol ethoxylates  micrograms per litre              No
#  189     di nonylphenol ethoxylates  micrograms per litre              No
#  234     di nonylphenol ethoxylates  micrograms per litre             Yes
#  ...                            ...                   ...             ...
#  637985  di nonylphenol ethoxylates  micrograms per litre             Yes
#  638058  di nonylphenol ethoxylates  micrograms per litre             Yes
#  638088  di nonylphenol ethoxylates  micrograms per litre             Yes
#  638101  di nonylphenol ethoxylates  micrograms per litre             Yes
#  638122  di nonylphenol ethoxylates  micrograms per litre             Yes
#
#  [10981 rows x 6 columns],
#  'ibupro_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  34         2015-04-06  Pen-y-bont STW        0.010           ibuprofen
#  113        2015-12-15     Canwick STW        0.030           ibuprofen
#  547        2015-03-31    Garforth STW        0.092           ibuprofen
#  677        2015-11-12  Horncastle STW        0.390           ibuprofen
#  804        2015-11-17     Farnham STW        0.010           ibuprofen
#  ...               ...             ...          ...                 ...
#  396726     2017-01-30       Corby STW        0.054           ibuprofen
#  398344     2017-01-17   Dunstable STW        0.010           ibuprofen
#  497289     2018-03-13      Wisley STW        0.300           ibuprofen
#  510601     2018-03-13   Weybridge STW        0.910           ibuprofen
#  527997     2018-03-13   Ripley Tw STW        0.010           ibuprofen
#
#                     UnitsName BelowMinReading
#  34      micrograms per litre             Yes
#  113     micrograms per litre              No
#  547     micrograms per litre              No
#  677     micrograms per litre              No
#  804     micrograms per litre             Yes
#  ...                      ...             ...
#  396726  micrograms per litre              No
#  398344  micrograms per litre             Yes
#  497289  micrograms per litre              No
#  510601  micrograms per litre              No
#  527997  micrograms per litre              No
#
#  [1010 rows x 6 columns],
#  'atorva_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  35         2015-04-06  Pen-y-bont STW        0.010        atorvastatin
#  114        2015-12-15     Canwick STW        0.120        atorvastatin
#  548        2015-03-31    Garforth STW        0.181        atorvastatin
#  678        2015-11-12  Horncastle STW        0.080        atorvastatin
#  805        2015-11-17     Farnham STW        0.010        atorvastatin
#  ...               ...             ...          ...                 ...
#  396727     2017-01-30       Corby STW        0.674        atorvastatin
#  398343     2017-01-17   Dunstable STW        0.400        atorvastatin
#  497287     2018-03-13      Wisley STW        0.120        atorvastatin
#  510609     2018-03-13   Weybridge STW        0.220        atorvastatin
#  527978     2018-03-13   Ripley Tw STW        0.030        atorvastatin
#
#                     UnitsName BelowMinReading
#  35      micrograms per litre             Yes
#  114     micrograms per litre              No
#  548     micrograms per litre              No
#  678     micrograms per litre              No
#  805     micrograms per litre              No
#  ...                      ...             ...
#  396727  micrograms per litre              No
#  398343  micrograms per litre              No
#  497287  micrograms per litre              No
#  510609  micrograms per litre              No
#  527978  micrograms per litre              No
#
#  [1013 rows x 6 columns],
#  'ortho_hydroxyatorva_df':        SampleDateTime  TreatmentPlant  SampleValue        NameDeterminandName  \
#  36         2015-04-06  Pen-y-bont STW        0.010  ortho hydroxyatorvastatin
#  115        2015-12-15     Canwick STW        0.230  ortho hydroxyatorvastatin
#  549        2015-03-31    Garforth STW        0.276  ortho hydroxyatorvastatin
#  679        2015-11-12  Horncastle STW        0.160  ortho hydroxyatorvastatin
#  806        2015-11-17     Farnham STW        0.020  ortho hydroxyatorvastatin
#  ...               ...             ...          ...                        ...
#  396728     2017-01-30       Corby STW        0.631  ortho hydroxyatorvastatin
#  398342     2017-01-17   Dunstable STW        0.380  ortho hydroxyatorvastatin
#  497286     2018-03-13      Wisley STW        0.180  ortho hydroxyatorvastatin
#  510602     2018-03-13   Weybridge STW        0.280  ortho hydroxyatorvastatin
#  527976     2018-03-13   Ripley Tw STW        0.060  ortho hydroxyatorvastatin
#
#                     UnitsName BelowMinReading
#  36      micrograms per litre             Yes
#  115     micrograms per litre              No
#  549     micrograms per litre              No
#  679     micrograms per litre              No
#  806     micrograms per litre              No
#  ...                      ...             ...
#  396728  micrograms per litre              No
#  398342  micrograms per litre              No
#  497286  micrograms per litre              No
#  510602  micrograms per litre              No
#  527976  micrograms per litre              No
#
#  [1013 rows x 6 columns],
#  'para_hydroxyatorva_df':        SampleDateTime  TreatmentPlant  SampleValue       NameDeterminandName  \
#  37         2015-04-06  Pen-y-bont STW        0.010  para hydroxyatorvastatin
#  116        2015-12-15     Canwick STW        0.170  para hydroxyatorvastatin
#  550        2015-03-31    Garforth STW        0.659  para hydroxyatorvastatin
#  680        2015-11-12  Horncastle STW        0.100  para hydroxyatorvastatin
#  807        2015-11-17     Farnham STW        0.020  para hydroxyatorvastatin
#  ...               ...             ...          ...                       ...
#  396729     2017-01-30       Corby STW        0.976  para hydroxyatorvastatin
#  398341     2017-01-17   Dunstable STW        0.410  para hydroxyatorvastatin
#  497285     2018-03-13      Wisley STW        0.310  para hydroxyatorvastatin
#  510603     2018-03-13   Weybridge STW        0.450  para hydroxyatorvastatin
#  527975     2018-03-13   Ripley Tw STW        0.080  para hydroxyatorvastatin
#
#                     UnitsName BelowMinReading
#  37      micrograms per litre             Yes
#  116     micrograms per litre              No
#  550     micrograms per litre              No
#  680     micrograms per litre              No
#  807     micrograms per litre              No
#  ...                      ...             ...
#  396729  micrograms per litre              No
#  398341  micrograms per litre              No
#  497285  micrograms per litre              No
#  510603  micrograms per litre              No
#  527975  micrograms per litre              No
#
#  [1013 rows x 6 columns],
#  'sert_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  38         2015-04-06  Pen-y-bont STW       0.0100          sertraline
#  128        2015-12-15     Canwick STW       0.0700          sertraline
#  615        2015-03-31    Garforth STW       0.0534          sertraline
#  639        2015-11-12  Horncastle STW       0.0300          sertraline
#  819        2015-11-17     Farnham STW       0.0800          sertraline
#  ...               ...             ...          ...                 ...
#  396781     2017-01-30       Corby STW       0.0470          sertraline
#  398329     2017-01-17   Dunstable STW       0.0500          sertraline
#  498071     2018-03-13      Wisley STW       0.0600          sertraline
#  510578     2018-03-13   Weybridge STW       0.0400          sertraline
#  527963     2018-03-13   Ripley Tw STW       0.0300          sertraline
#
#                     UnitsName BelowMinReading
#  38      micrograms per litre             Yes
#  128     micrograms per litre              No
#  615     micrograms per litre              No
#  639     micrograms per litre              No
#  819     micrograms per litre              No
#  ...                      ...             ...
#  396781  micrograms per litre              No
#  398329  micrograms per litre              No
#  498071  micrograms per litre              No
#  510578  micrograms per litre              No
#  527963  micrograms per litre              No
#
#  [1014 rows x 6 columns],
#  'norsert_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  39         2015-04-06  Pen-y-bont STW        0.010       norsertraline
#  156        2015-12-15     Canwick STW        0.040       norsertraline
#  616        2015-03-31    Garforth STW        0.034       norsertraline
#  640        2015-11-12  Horncastle STW        0.020       norsertraline
#  743        2015-11-17     Farnham STW        0.010       norsertraline
#  ...               ...             ...          ...                 ...
#  396782     2017-01-30       Corby STW        0.020       norsertraline
#  398328     2017-01-17   Dunstable STW        0.020       norsertraline
#  498070     2018-03-13      Wisley STW        0.020       norsertraline
#  510579     2018-03-13   Weybridge STW        0.030       norsertraline
#  527962     2018-03-13   Ripley Tw STW        0.010       norsertraline
#
#                     UnitsName BelowMinReading
#  39      micrograms per litre             Yes
#  156     micrograms per litre              No
#  616     micrograms per litre              No
#  640     micrograms per litre              No
#  743     micrograms per litre             Yes
#  ...                      ...             ...
#  396782  micrograms per litre              No
#  398328  micrograms per litre              No
#  498070  micrograms per litre              No
# ...
#  527998     2018-03-13   Ripley Tw STW        0.190          diclofenac
#
#                     UnitsName BelowMinReading
#  112     micrograms per litre              No
#  157     micrograms per litre              No
#  546     micrograms per litre              No
#  676     micrograms per litre              No
#  803     micrograms per litre              No
#  ...                      ...             ...
#  396839  micrograms per litre              No
#  398345  micrograms per litre              No
#  497297  micrograms per litre              No
#  510599  micrograms per litre              No
#  527998  micrograms per litre              No
#
#  [1014 rows x 6 columns],
#  'erythr_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  119        2015-12-15     Canwick STW        0.720        erythromycin
#  172        2015-04-06  Pen-y-bont STW        0.320        erythromycin
#  553        2015-03-31    Garforth STW        0.430        erythromycin
#  683        2015-11-12  Horncastle STW        0.860        erythromycin
#  810        2015-11-17     Farnham STW        0.100        erythromycin
#  ...               ...             ...          ...                 ...
#  396752     2017-01-30       Corby STW        0.351        erythromycin
#  398338     2017-01-17   Dunstable STW        0.120        erythromycin
#  497282     2018-03-13      Wisley STW        0.250        erythromycin
#  510606     2018-03-13   Weybridge STW        0.360        erythromycin
#  527972     2018-03-13   Ripley Tw STW        0.140        erythromycin
#
#                     UnitsName BelowMinReading
#  119     micrograms per litre              No
#  172     micrograms per litre              No
#  553     micrograms per litre              No
#  683     micrograms per litre              No
#  810     micrograms per litre             Yes
#  ...                      ...             ...
#  396752  micrograms per litre              No
#  398338  micrograms per litre              No
#  497282  micrograms per litre              No
#  510606  micrograms per litre              No
#  527972  micrograms per litre              No
#
#  [1012 rows x 6 columns],
#  'norerythr_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  120        2015-12-15     Canwick STW        0.100     norerythromycin
#  176        2015-04-06  Pen-y-bont STW        0.100     norerythromycin
#  581        2015-03-31    Garforth STW        0.039     norerythromycin
#  684        2015-11-12  Horncastle STW        0.100     norerythromycin
#  811        2015-11-17     Farnham STW        0.100     norerythromycin
#  ...               ...             ...          ...                 ...
#  396753     2017-01-30       Corby STW        0.024     norerythromycin
#  398337     2017-01-17   Dunstable STW        0.010     norerythromycin
#  497281     2018-03-13      Wisley STW        0.100     norerythromycin
#  510607     2018-03-13   Weybridge STW        0.100     norerythromycin
#  527971     2018-03-13   Ripley Tw STW        0.100     norerythromycin
#
#                     UnitsName BelowMinReading
#  120     micrograms per litre             Yes
#  176     micrograms per litre             Yes
#  581     micrograms per litre              No
#  684     micrograms per litre             Yes
#  811     micrograms per litre             Yes
#  ...                      ...             ...
#  396753  micrograms per litre              No
#  398337  micrograms per litre              No
#  497281  micrograms per litre             Yes
#  510607  micrograms per litre             Yes
#  527971  micrograms per litre             Yes
#
#  [1013 rows x 6 columns],
#  'clarithr_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  122        2015-12-15     Canwick STW        0.660      clarithromycin
#  173        2015-04-06  Pen-y-bont STW        0.220      clarithromycin
#  634        2015-03-31    Garforth STW        0.352      clarithromycin
#  686        2015-11-12  Horncastle STW        0.380      clarithromycin
#  813        2015-11-17     Farnham STW        0.120      clarithromycin
#  ...               ...             ...          ...                 ...
#  396775     2017-01-30       Corby STW        0.136      clarithromycin
#  398335     2017-01-17   Dunstable STW        0.280      clarithromycin
#  497259     2018-03-13      Wisley STW        0.600      clarithromycin
#  510630     2018-03-13   Weybridge STW        0.370      clarithromycin
#  527969     2018-03-13   Ripley Tw STW        0.340      clarithromycin
#
#                     UnitsName BelowMinReading
#  122     micrograms per litre              No
#  173     micrograms per litre              No
#  634     micrograms per litre              No
#  686     micrograms per litre              No
#  813     micrograms per litre              No
#  ...                      ...             ...
#  396775  micrograms per litre              No
#  398335  micrograms per litre              No
#  497259  micrograms per litre              No
#  510630  micrograms per litre              No
#  527969  micrograms per litre              No
#
#  [1015 rows x 6 columns],
#  'ciprofl_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  123        2015-12-15     Canwick STW        1.040       ciprofloxacin
#  178        2015-04-06  Pen-y-bont STW        0.110       ciprofloxacin
#  584        2015-03-31    Garforth STW        0.226       ciprofloxacin
#  663        2015-11-12  Horncastle STW        1.420       ciprofloxacin
#  814        2015-11-17     Farnham STW        1.220       ciprofloxacin
#  ...               ...             ...          ...                 ...
#  396776     2017-01-30       Corby STW        0.165       ciprofloxacin
#  398334     2017-01-17   Dunstable STW        0.240       ciprofloxacin
#  497258     2018-03-13      Wisley STW        0.030       ciprofloxacin
#  510710     2018-03-13   Weybridge STW        0.100       ciprofloxacin
#  527968     2018-03-13   Ripley Tw STW        0.030       ciprofloxacin
#
#                     UnitsName BelowMinReading
#  123     micrograms per litre              No
#  178     micrograms per litre              No
#  584     micrograms per litre              No
#  663     micrograms per litre              No
#  814     micrograms per litre              No
#  ...                      ...             ...
#  396776  micrograms per litre              No
#  398334  micrograms per litre              No
#  497258  micrograms per litre              No
#  510710  micrograms per litre              No
#  527968  micrograms per litre              No
#
#  [1003 rows x 6 columns],
#  'metfor_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  124        2015-12-15     Canwick STW         3.77           metformin
#  164        2015-04-06  Pen-y-bont STW         1.18           metformin
#  611        2015-03-31    Garforth STW        15.80           metformin
#  662        2015-11-12  Horncastle STW         5.66           metformin
#  815        2015-11-17     Farnham STW         2.43           metformin
#  ...               ...             ...          ...                 ...
#  396777     2017-01-30       Corby STW         5.23           metformin
#  398333     2017-01-17   Dunstable STW         2.20           metformin
#  497248     2018-03-13      Wisley STW        12.70           metformin
#  510788     2018-03-13   Weybridge STW        13.00           metformin
#  527967     2018-03-13   Ripley Tw STW         1.28           metformin
#
#                     UnitsName BelowMinReading
#  124     micrograms per litre              No
#  164     micrograms per litre              No
#  611     micrograms per litre              No
#  662     micrograms per litre              No
#  815     micrograms per litre              No
#  ...                      ...             ...
#  396777  micrograms per litre              No
#  398333  micrograms per litre              No
#  497248  micrograms per litre              No
#  510788  micrograms per litre              No
#  527967  micrograms per litre              No
#
#  [1014 rows x 6 columns],
#  'rani_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  125        2015-12-15     Canwick STW        0.980          ranitidine
#  180        2015-04-06  Pen-y-bont STW        0.090          ranitidine
#  612        2015-03-31    Garforth STW        1.280          ranitidine
#  661        2015-11-12  Horncastle STW        0.670          ranitidine
#  816        2015-11-17     Farnham STW        0.240          ranitidine
#  ...               ...             ...          ...                 ...
#  396778     2017-01-30       Corby STW        0.429          ranitidine
#  398332     2017-01-17   Dunstable STW        1.270          ranitidine
#  498074     2018-03-13      Wisley STW        0.740          ranitidine
#  510711     2018-03-13   Weybridge STW        0.850          ranitidine
#  527966     2018-03-13   Ripley Tw STW        0.200          ranitidine
#
#                     UnitsName BelowMinReading
#  125     micrograms per litre              No
#  180     micrograms per litre              No
#  612     micrograms per litre              No
#  661     micrograms per litre              No
#  816     micrograms per litre              No
#  ...                      ...             ...
#  396778  micrograms per litre              No
#  398332  micrograms per litre              No
#  498074  micrograms per litre              No
#  510711  micrograms per litre              No
#  527966  micrograms per litre              No
#
#  [1014 rows x 6 columns],
#  'carbama_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  126        2015-12-15     Canwick STW         0.79       carbamazepine
#  175        2015-04-06  Pen-y-bont STW         0.16       carbamazepine
#  613        2015-03-31    Garforth STW         0.53       carbamazepine
#  648        2015-11-12  Horncastle STW         0.71       carbamazepine
#  817        2015-11-17     Farnham STW         1.01       carbamazepine
#  ...               ...             ...          ...                 ...
#  396779     2017-01-30       Corby STW         2.11       carbamazepine
#  398331     2017-01-17   Dunstable STW         1.08       carbamazepine
#  498073     2018-03-13      Wisley STW         0.28       carbamazepine
#  510576     2018-03-13   Weybridge STW         0.35       carbamazepine
#  527965     2018-03-13   Ripley Tw STW         0.16       carbamazepine
#
#                     UnitsName BelowMinReading
#  126     micrograms per litre              No
#  175     micrograms per litre              No
#  613     micrograms per litre              No
#  648     micrograms per litre              No
#  817     micrograms per litre              No
#  ...                      ...             ...
#  396779  micrograms per litre              No
#  398331  micrograms per litre              No
#  498073  micrograms per litre              No
#  510576  micrograms per litre              No
#  527965  micrograms per litre              No
#
#  [1015 rows x 6 columns],
#  'epoxycarbamazepine_df':        SampleDateTime  TreatmentPlant  SampleValue       NameDeterminandName  \
#  127        2015-12-15     Canwick STW        0.120  epoxycarbamazepine 10 11
#  177        2015-04-06  Pen-y-bont STW        0.100  epoxycarbamazepine 10 11
#  614        2015-03-31    Garforth STW        0.432  epoxycarbamazepine 10 11
#  638        2015-11-12  Horncastle STW        0.120  epoxycarbamazepine 10 11
#  818        2015-11-17     Farnham STW        0.300  epoxycarbamazepine 10 11
#  ...               ...             ...          ...                       ...
#  396780     2017-01-30       Corby STW        0.061  epoxycarbamazepine 10 11
#  398330     2017-01-17   Dunstable STW        0.090  epoxycarbamazepine 10 11
#  498072     2018-03-13      Wisley STW        0.100  epoxycarbamazepine 10 11
#  510577     2018-03-13   Weybridge STW        0.100  epoxycarbamazepine 10 11
#  527964     2018-03-13   Ripley Tw STW        0.100  epoxycarbamazepine 10 11
#
#                     UnitsName BelowMinReading
#  127     micrograms per litre              No
#  177     micrograms per litre             Yes
#  614     micrograms per litre              No
#  638     micrograms per litre              No
#  818     micrograms per litre              No
#  ...                      ...             ...
#  396780  micrograms per litre              No
#  398330  micrograms per litre              No
#  498072  micrograms per litre             Yes
#  510577  micrograms per litre             Yes
#  527964  micrograms per litre             Yes
#
#  [1014 rows x 6 columns],
#  'atenol_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  129        2015-12-15     Canwick STW        0.350            atenolol
#  181        2015-04-06  Pen-y-bont STW        0.080            atenolol
#  552        2015-03-31    Garforth STW        0.876            atenolol
#  682        2015-11-12  Horncastle STW        0.160            atenolol
#  809        2015-11-17     Farnham STW        0.280            atenolol
#  ...               ...             ...          ...                 ...
#  396751     2017-01-30       Corby STW        0.265            atenolol
#  398339     2017-01-17   Dunstable STW        0.360            atenolol
#  497283     2018-03-13      Wisley STW        0.200            atenolol
#  510605     2018-03-13   Weybridge STW        0.210            atenolol
#  527973     2018-03-13   Ripley Tw STW        0.060            atenolol
#
#                     UnitsName BelowMinReading
#  129     micrograms per litre              No
#  181     micrograms per litre              No
#  552     micrograms per litre              No
#  682     micrograms per litre              No
#  809     micrograms per litre              No
#  ...                      ...             ...
#  396751  micrograms per litre              No
#  398339  micrograms per litre              No
#  497283  micrograms per litre              No
#  510605  micrograms per litre              No
#  527973  micrograms per litre              No
#
#  [1014 rows x 6 columns],
#  'tolyltr_df':        SampleDateTime  TreatmentPlant  SampleValue NameDeterminandName  \
#  183        2015-04-06  Pen-y-bont STW        2.440       tolyltriazole
#  187        2015-12-15     Canwick STW        0.610       tolyltriazole
#  621        2015-03-31    Garforth STW        1.270       tolyltriazole
#  645        2015-11-12  Horncastle STW        0.850       tolyltriazole
#  665        2015-11-17     Farnham STW        2.432       tolyltriazole
#  ...               ...             ...          ...                 ...
#  396787     2017-01-30       Corby STW        0.790       tolyltriazole
#  398379     2017-01-17   Dunstable STW        0.850       tolyltriazole
#  498025     2018-03-13      Wisley STW        1.690       tolyltriazole
#  510584     2018-03-13   Weybridge STW        2.530       tolyltriazole
#  527995     2018-03-13   Ripley Tw STW        0.877       tolyltriazole
#
#                     UnitsName BelowMinReading
#  183     micrograms per litre              No
#  187     micrograms per litre              No
#  621     micrograms per litre              No
#  645     micrograms per litre              No
#  665     micrograms per litre              No
#  ...                      ...             ...
#  396787  micrograms per litre              No
#  398379  micrograms per litre              No
#  498025  micrograms per litre              No
#  510584  micrograms per litre              No
#  527995  micrograms per litre              No
#
#  [1012 rows x 6 columns]}

# %%
BDE_99_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-187-e8ecbf59941c> in <module>
# ----> 1 BDE_99_df
#
# NameError: name 'BDE_99_df' is not defined

# %%
ibup_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-2e415a3fcea8> in <module>
# ----> 1 ibup_df
#
# NameError: name 'ibup_df' is not defined

# %%
sulp_df
# Out:
#        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
# 33         2015-04-06    Pen-y-bont STW         0.01            sulphide
# 90         2015-09-29      Deepings STW         0.04            sulphide
# 108        2015-12-15       Canwick STW         0.02            sulphide
# 211        2015-05-14         Heage STW         0.01            sulphide
# 293        2015-06-18       Cannock STW         0.01            sulphide
# ...               ...               ...          ...                 ...
# 637954     2020-05-03          Diss STW         0.02            sulphide
# 637987     2020-02-19     Nettleham STW         0.02            sulphide
# 638060     2020-02-18  Brackley New STW         0.02            sulphide
# 638090     2020-06-02          Diss STW         0.04            sulphide
# 638103     2020-01-28     Nettleham STW         0.03            sulphide
#
#                      UnitsName BelowMinReading
# 33      milligrammes per litre             Yes
# 90      milligrammes per litre              No
# 108     milligrammes per litre             Yes
# 211     milligrammes per litre             Yes
# 293     milligrammes per litre             Yes
# ...                        ...             ...
# 637954  milligrammes per litre             Yes
# 637987  milligrammes per litre             Yes
# 638060  milligrammes per litre             Yes
# 638090  milligrammes per litre              No
# 638103  milligrammes per litre              No
#
# [12242 rows x 6 columns]

# %%
parameters = df_mg.NameDeterminandName.unique()

name = []
 
for parameter in parameters:
    if len(parameter) >= 10:
        parameter = parameter [:-7]
    else:
        parameter = parameter[:4]
    
    name.append(parameter)

name = [i.replace(" ", "_")  for i in name]

name = [i + '_df' for i in name]

dict_name = dict(zip(name, parameters))

dfs = [i for i in dict_name.keys()] 

for i in range(len(dfs)):
    dfs[i] = generate_df(parameters[i])

for i in name:
    name = dfs

# %%
#a = iter(name)

# %%
#sulp_df, dissolved_organic_df, total_phosphor_df, soluble_reactive_phospha_df, ammoniacal_nitrog_df, Biochemical_Oxygen_df, total_organic_df, total_suspended_df, total_oxidised_nitrog_df, Chemical_Oxygen_df, calc_df, pH_df, nickel_di_df = dfs

# %%
sulp_df
# Out:
#        SampleDateTime    TreatmentPlant  SampleValue NameDeterminandName  \
# 33         2015-04-06    Pen-y-bont STW         0.01            sulphide
# 90         2015-09-29      Deepings STW         0.04            sulphide
# 108        2015-12-15       Canwick STW         0.02            sulphide
# 211        2015-05-14         Heage STW         0.01            sulphide
# 293        2015-06-18       Cannock STW         0.01            sulphide
# ...               ...               ...          ...                 ...
# 637954     2020-05-03          Diss STW         0.02            sulphide
# 637987     2020-02-19     Nettleham STW         0.02            sulphide
# 638060     2020-02-18  Brackley New STW         0.02            sulphide
# 638090     2020-06-02          Diss STW         0.04            sulphide
# 638103     2020-01-28     Nettleham STW         0.03            sulphide
#
#                      UnitsName BelowMinReading
# 33      milligrammes per litre             Yes
# 90      milligrammes per litre              No
# 108     milligrammes per litre             Yes
# 211     milligrammes per litre             Yes
# 293     milligrammes per litre             Yes
# ...                        ...             ...
# 637954  milligrammes per litre             Yes
# 637987  milligrammes per litre             Yes
# 638060  milligrammes per litre             Yes
# 638090  milligrammes per litre              No
# 638103  milligrammes per litre              No
#
# [12242 rows x 6 columns]

# %%
plot1 = total_phosphor_df[total_phosphor_df['TreatmentPlant'] == 'Heage STW']

plot1.SampleDateTime = pd.to_datetime(plot1.SampleDateTime, format='%Y/%m/%d')

plot1.sort_values('SampleDateTime', inplace=True)
# Out:
# /opt/venv/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
plot1
# Out:
#        SampleDateTime TreatmentPlant  SampleValue    NameDeterminandName  \
# 46481      2015-01-06      Heage STW         3.71  total phosphorus as P
# 61593      2015-01-10      Heage STW         6.37  total phosphorus as P
# 11649      2015-01-12      Heage STW         1.34  total phosphorus as P
# 35361      2015-02-09      Heage STW         4.59  total phosphorus as P
# 53933      2015-03-08      Heage STW         5.09  total phosphorus as P
# 56         2015-05-14      Heage STW         4.39  total phosphorus as P
# 53142      2015-06-05      Heage STW         3.11  total phosphorus as P
# 53055      2015-06-16      Heage STW         3.94  total phosphorus as P
# 338        2015-07-07      Heage STW         4.33  total phosphorus as P
# 9718       2015-07-21      Heage STW         4.97  total phosphorus as P
# 11526      2015-08-10      Heage STW         3.89  total phosphorus as P
# 9845       2015-09-25      Heage STW         5.46  total phosphorus as P
# 8568       2015-10-16      Heage STW         6.06  total phosphorus as P
# 61380      2015-11-20      Heage STW         2.10  total phosphorus as P
# 163631     2016-01-14      Heage STW         1.69  total phosphorus as P
# 123810     2016-01-20      Heage STW         2.86  total phosphorus as P
# 163361     2016-02-26      Heage STW         3.28  total phosphorus as P
# 249235     2016-03-15      Heage STW         2.75  total phosphorus as P
# 128909     2016-04-02      Heage STW         2.57  total phosphorus as P
# 128776     2016-08-01      Heage STW         1.07  total phosphorus as P
#
#                      UnitsName BelowMinReading
# 46481   milligrammes per litre              No
# 61593   milligrammes per litre              No
# 11649   milligrammes per litre              No
# 35361   milligrammes per litre              No
# 53933   milligrammes per litre              No
# 56      milligrammes per litre              No
# 53142   milligrammes per litre              No
# 53055   milligrammes per litre              No
# 338     milligrammes per litre              No
# 9718    milligrammes per litre              No
# 11526   milligrammes per litre              No
# 9845    milligrammes per litre              No
# 8568    milligrammes per litre              No
# 61380   milligrammes per litre              No
# 163631  milligrammes per litre              No
# 123810  milligrammes per litre              No
# 163361  milligrammes per litre              No
# 249235  milligrammes per litre              No
# 128909  milligrammes per litre              No
# 128776  milligrammes per litre              No

# %%
quality = dict(
    x = plot1.SampleDateTime,
    y = plot1['SampleValue'],
    name =  'Diss STW',
    mode = 'lines+markers',
    type = 'scatter',
    #line = dict(shape = 'spline', color = 'rgb(205, 12, 24)', width= 2) #dash = 'dash'),
    #marker = dict(symbol = "star-diamond", color = 'rgb(17, 157, 255)',size = 8),
    #connectgaps = True

)


layout = go.Layout(title='BOD values in selected Treatment sites')
data = [quality]
fig = go.Figure (data=data, layout=layout)

fig.show()

#fig = go.Figure( x = plot1['SampleDateTime'], y =plot1['SampleValue']) #range_x=['2015-01-01','2020-12-31'], 

#fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="84e81240-d409-46f7-894e-015099aaa8e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84e81240-d409-46f7-894e-015099aaa8e9")) {                    Plotly.newPlot(                        "84e81240-d409-46f7-894e-015099aaa8e9",                        [{"mode": "lines+markers", "name": "Diss STW", "type": "scatter", "x": ["2015-01-06T00:00:00", "2015-01-10T00:00:00", "2015-01-12T00:00:00", "2015-02-09T00:00:00", "2015-03-08T00:00:00", "2015-05-14T00:00:00", "2015-06-05T00:00:00", "2015-06-16T00:00:00", "2015-07-07T00:00:00", "2015-07-21T00:00:00", "2015-08-10T00:00:00", "2015-09-25T00:00:00", "2015-10-16T00:00:00", "2015-11-20T00:00:00", "2016-01-14T00:00:00", "2016-01-20T00:00:00", "2016-02-26T00:00:00", "2016-03-15T00:00:00", "2016-04-02T00:00:00", "2016-08-01T00:00:00"], "y": [3.71, 6.37, 1.34, 4.59, 5.09, 4.39, 3.11, 3.94, 4.33, 4.97, 3.89, 5.46, 6.06, 2.1, 1.69, 2.86, 3.28, 2.75, 2.57, 1.07]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f ...
